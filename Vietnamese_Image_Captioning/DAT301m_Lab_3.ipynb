# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import re
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers
from keras.applications import efficientnet
from keras.layers import TextVectorization

keras.utils.set_random_seed(111)

# %% [markdown]
# **Download dataet**

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)

# %%
# !mkdir ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# Download Dataset
# !kaggle datasets download -d vitngquang/uit-viic-v1-0-vietnamese-image-captioning
# Out:
# Downloading uit-viic-v1-0-vietnamese-image-captioning.zip to /content
# 100% 1.23G/1.23G [00:56<00:00, 25.0MB/s]
# 100% 1.23G/1.23G [00:56<00:00, 23.3MB/s]

# %%
import shutil
import os

def delete_folder_and_contents(folder_path):
    try:
        # Deleting all files and subdirectories
        for item in os.listdir(folder_path):
            item_path = os.path.join(folder_path, item)
            if os.path.isfile(item_path):
                os.unlink(item_path)
            else:
                shutil.rmtree(item_path)

        # Deleting the folder itself
        shutil.rmtree(folder_path)

        print(f"{folder_path} and its contents are successfully deleted.")

    except Exception as e:
        print(f"An error occurred: {e}")

# Replace 'folder_path' with the path to the folder you want to delete
# folder_path = "/content/dataset"

# delete_folder_and_contents(folder_path)

# %%
# !unzip /content/uit-viic-v1-0-vietnamese-image-captioning.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/train/images/000000534373.jpg
#   inflating: /content/dataset/train/images/000000534513.jpg
#   inflating: /content/dataset/train/images/000000534694.jpg
#   inflating: /content/dataset/train/images/000000534734.jpg
#   inflating: /content/dataset/train/images/000000534876.jpg
#   inflating: /content/dataset/train/images/000000535325.jpg
#   inflating: /content/dataset/train/images/000000535467.jpg
#   inflating: /content/dataset/train/images/000000535668.jpg
#   inflating: /content/dataset/train/images/000000536419.jpg
#   inflating: /content/dataset/train/images/000000536653.jpg
#   inflating: /content/dataset/train/images/000000537069.jpg
#   inflating: /content/dataset/train/images/000000537097.jpg
#   inflating: /content/dataset/train/images/000000537631.jpg
#   inflating: /content/dataset/train/images/000000538113.jpg
#   inflating: /content/dataset/train/images/000000538454.jpg
#   inflating: /content/dataset/train/images/000000538615.jpg
#   inflating: /content/dataset/train/images/000000538858.jpg
#   inflating: /content/dataset/train/images/000000539140.jpg
#   inflating: /content/dataset/train/images/000000539930.jpg
#   inflating: /content/dataset/train/images/000000540092.jpg
#   inflating: /content/dataset/train/images/000000540287.jpg
#   inflating: /content/dataset/train/images/000000540317.jpg
#   inflating: /content/dataset/train/images/000000540681.jpg
#   inflating: /content/dataset/train/images/000000540864.jpg
#   inflating: /content/dataset/train/images/000000541010.jpg
#   inflating: /content/dataset/train/images/000000541197.jpg
#   inflating: /content/dataset/train/images/000000541202.jpg
#   inflating: /content/dataset/train/images/000000541209.jpg
#   inflating: /content/dataset/train/images/000000541351.jpg
#   inflating: /content/dataset/train/images/000000542260.jpg
#   inflating: /content/dataset/train/images/000000542630.jpg
#   inflating: /content/dataset/train/images/000000542681.jpg
#   inflating: /content/dataset/train/images/000000542799.jpg
#   inflating: /content/dataset/train/images/000000543347.jpg
#   inflating: /content/dataset/train/images/000000543570.jpg
#   inflating: /content/dataset/train/images/000000543585.jpg
#   inflating: /content/dataset/train/images/000000543769.jpg
#   inflating: /content/dataset/train/images/000000543817.jpg
#   inflating: /content/dataset/train/images/000000544065.jpg
#   inflating: /content/dataset/train/images/000000544502.jpg
#   inflating: /content/dataset/train/images/000000544695.jpg
#   inflating: /content/dataset/train/images/000000544913.jpg
#   inflating: /content/dataset/train/images/000000545334.jpg
#   inflating: /content/dataset/train/images/000000546020.jpg
#   inflating: /content/dataset/train/images/000000546538.jpg
#   inflating: /content/dataset/train/images/000000547099.jpg
#   inflating: /content/dataset/train/images/000000547267.jpg
#   inflating: /content/dataset/train/images/000000547300.jpg
#   inflating: /content/dataset/train/images/000000547617.jpg
#   inflating: /content/dataset/train/images/000000547730.jpg
#   inflating: /content/dataset/train/images/000000547798.jpg
#   inflating: /content/dataset/train/images/000000547859.jpg
#   inflating: /content/dataset/train/images/000000548361.jpg
#   inflating: /content/dataset/train/images/000000548548.jpg
#   inflating: /content/dataset/train/images/000000549237.jpg
#   inflating: /content/dataset/train/images/000000549915.jpg
#   inflating: /content/dataset/train/images/000000550444.jpg
#   inflating: /content/dataset/train/images/000000550955.jpg
#   inflating: /content/dataset/train/images/000000551001.jpg
#   inflating: /content/dataset/train/images/000000551372.jpg
#   inflating: /content/dataset/train/images/000000551466.jpg
#   inflating: /content/dataset/train/images/000000551633.jpg
#   inflating: /content/dataset/train/images/000000551752.jpg
#   inflating: /content/dataset/train/images/000000552001.jpg
#   inflating: /content/dataset/train/images/000000552247.jpg
#   inflating: /content/dataset/train/images/000000552254.jpg
#   inflating: /content/dataset/train/images/000000552304.jpg
#   inflating: /content/dataset/train/images/000000552510.jpg
#   inflating: /content/dataset/train/images/000000552829.jpg
#   inflating: /content/dataset/train/images/000000553025.jpg
#   inflating: /content/dataset/train/images/000000553760.jpg
#   inflating: /content/dataset/train/images/000000553815.jpg
#   inflating: /content/dataset/train/images/000000553997.jpg
#   inflating: /content/dataset/train/images/000000554664.jpg
#   inflating: /content/dataset/train/images/000000554886.jpg
#   inflating: /content/dataset/train/images/000000554943.jpg
#   inflating: /content/dataset/train/images/000000555131.jpg
#   inflating: /content/dataset/train/images/000000555271.jpg
#   inflating: /content/dataset/train/images/000000555282.jpg
#   inflating: /content/dataset/train/images/000000555534.jpg
#   inflating: /content/dataset/train/images/000000555537.jpg
#   inflating: /content/dataset/train/images/000000555683.jpg
#   inflating: /content/dataset/train/images/000000555696.jpg
#   inflating: /content/dataset/train/images/000000555781.jpg
#   inflating: /content/dataset/train/images/000000555794.jpg
#   inflating: /content/dataset/train/images/000000556130.jpg
#   inflating: /content/dataset/train/images/000000556216.jpg
#   inflating: /content/dataset/train/images/000000556537.jpg
#   inflating: /content/dataset/train/images/000000556669.jpg
#   inflating: /content/dataset/train/images/000000557323.jpg
#   inflating: /content/dataset/train/images/000000557586.jpg
#   inflating: /content/dataset/train/images/000000557709.jpg
#   inflating: /content/dataset/train/images/000000557811.jpg
#   inflating: /content/dataset/train/images/000000557830.jpg
#   inflating: /content/dataset/train/images/000000558089.jpg
#   inflating: /content/dataset/train/images/000000558221.jpg
#   inflating: /content/dataset/train/images/000000558570.jpg
#   inflating: /content/dataset/train/images/000000558808.jpg
#   inflating: /content/dataset/train/images/000000558900.jpg
#   inflating: /content/dataset/train/images/000000558955.jpg
#   inflating: /content/dataset/train/images/000000558983.jpg
#   inflating: /content/dataset/train/images/000000559261.jpg
#   inflating: /content/dataset/train/images/000000559522.jpg
#   inflating: /content/dataset/train/images/000000559762.jpg
#   inflating: /content/dataset/train/images/000000559908.jpg
#   inflating: /content/dataset/train/images/000000560143.jpg
#   inflating: /content/dataset/train/images/000000560384.jpg
#   inflating: /content/dataset/train/images/000000560662.jpg
#   inflating: /content/dataset/train/images/000000560787.jpg
#   inflating: /content/dataset/train/images/000000560797.jpg
#   inflating: /content/dataset/train/images/000000560902.jpg
#   inflating: /content/dataset/train/images/000000561156.jpg
#   inflating: /content/dataset/train/images/000000561488.jpg
#   inflating: /content/dataset/train/images/000000561745.jpg
#   inflating: /content/dataset/train/images/000000561746.jpg
#   inflating: /content/dataset/train/images/000000561864.jpg
#   inflating: /content/dataset/train/images/000000561901.jpg
#   inflating: /content/dataset/train/images/000000561913.jpg
#   inflating: /content/dataset/train/images/000000562196.jpg
#   inflating: /content/dataset/train/images/000000562381.jpg
#   inflating: /content/dataset/train/images/000000562614.jpg
#   inflating: /content/dataset/train/images/000000562778.jpg
#   inflating: /content/dataset/train/images/000000564489.jpg
#   inflating: /content/dataset/train/images/000000564496.jpg
#   inflating: /content/dataset/train/images/000000564745.jpg
#   inflating: /content/dataset/train/images/000000565115.jpg
#   inflating: /content/dataset/train/images/000000565203.jpg
#   inflating: /content/dataset/train/images/000000565341.jpg
#   inflating: /content/dataset/train/images/000000565522.jpg
#   inflating: /content/dataset/train/images/000000565570.jpg
#   inflating: /content/dataset/train/images/000000565571.jpg
#   inflating: /content/dataset/train/images/000000565625.jpg
#   inflating: /content/dataset/train/images/000000565675.jpg
#   inflating: /content/dataset/train/images/000000566083.jpg
#   inflating: /content/dataset/train/images/000000566088.jpg
#   inflating: /content/dataset/train/images/000000566324.jpg
#   inflating: /content/dataset/train/images/000000566448.jpg
#   inflating: /content/dataset/train/images/000000566543.jpg
#   inflating: /content/dataset/train/images/000000566651.jpg
#   inflating: /content/dataset/train/images/000000566908.jpg
#   inflating: /content/dataset/train/images/000000566975.jpg
#   inflating: /content/dataset/train/images/000000567121.jpg
#   inflating: /content/dataset/train/images/000000567208.jpg
#   inflating: /content/dataset/train/images/000000567276.jpg
#   inflating: /content/dataset/train/images/000000567304.jpg
#   inflating: /content/dataset/train/images/000000567308.jpg
#   inflating: /content/dataset/train/images/000000567357.jpg
#   inflating: /content/dataset/train/images/000000567494.jpg
#   inflating: /content/dataset/train/images/000000567713.jpg
#   inflating: /content/dataset/train/images/000000567717.jpg
#   inflating: /content/dataset/train/images/000000567793.jpg
#   inflating: /content/dataset/train/images/000000567827.jpg
#   inflating: /content/dataset/train/images/000000567881.jpg
#   inflating: /content/dataset/train/images/000000568009.jpg
#   inflating: /content/dataset/train/images/000000568132.jpg
#   inflating: /content/dataset/train/images/000000568471.jpg
#   inflating: /content/dataset/train/images/000000569069.jpg
#   inflating: /content/dataset/train/images/000000569272.jpg
#   inflating: /content/dataset/train/images/000000569511.jpg
#   inflating: /content/dataset/train/images/000000569526.jpg
#   inflating: /content/dataset/train/images/000000569535.jpg
#   inflating: /content/dataset/train/images/000000569723.jpg
#   inflating: /content/dataset/train/images/000000569758.jpg
#   inflating: /content/dataset/train/images/000000569768.jpg
#   inflating: /content/dataset/train/images/000000570116.jpg
#   inflating: /content/dataset/train/images/000000570440.jpg
#   inflating: /content/dataset/train/images/000000570542.jpg
#   inflating: /content/dataset/train/images/000000570601.jpg
#   inflating: /content/dataset/train/images/000000570628.jpg
#   inflating: /content/dataset/train/images/000000570848.jpg
#   inflating: /content/dataset/train/images/000000571160.jpg
#   inflating: /content/dataset/train/images/000000571219.jpg
#   inflating: /content/dataset/train/images/000000571389.jpg
#   inflating: /content/dataset/train/images/000000571648.jpg
#   inflating: /content/dataset/train/images/000000571805.jpg
#   inflating: /content/dataset/train/images/000000572081.jpg
#   inflating: /content/dataset/train/images/000000572477.jpg
#   inflating: /content/dataset/train/images/000000572505.jpg
#   inflating: /content/dataset/train/images/000000572561.jpg
#   inflating: /content/dataset/train/images/000000572571.jpg
#   inflating: /content/dataset/train/images/000000572907.jpg
#   inflating: /content/dataset/train/images/000000573065.jpg
#   inflating: /content/dataset/train/images/000000573107.jpg
#   inflating: /content/dataset/train/images/000000573248.jpg
#   inflating: /content/dataset/train/images/000000573647.jpg
#   inflating: /content/dataset/train/images/000000574034.jpg
#   inflating: /content/dataset/train/images/000000574154.jpg
#   inflating: /content/dataset/train/images/000000574155.jpg
#   inflating: /content/dataset/train/images/000000574236.jpg
#   inflating: /content/dataset/train/images/000000574282.jpg
#   inflating: /content/dataset/train/images/000000574368.jpg
#   inflating: /content/dataset/train/images/000000574404.jpg
#   inflating: /content/dataset/train/images/000000574455.jpg
#   inflating: /content/dataset/train/images/000000574775.jpg
#   inflating: /content/dataset/train/images/000000574977.jpg
#   inflating: /content/dataset/train/images/000000575135.jpg
#   inflating: /content/dataset/train/images/000000575174.jpg
#   inflating: /content/dataset/train/images/000000575490.jpg
#   inflating: /content/dataset/train/images/000000575594.jpg
#   inflating: /content/dataset/train/images/000000575901.jpg
#   inflating: /content/dataset/train/images/000000576089.jpg
#   inflating: /content/dataset/train/images/000000576286.jpg
#   inflating: /content/dataset/train/images/000000576463.jpg
#   inflating: /content/dataset/train/images/000000576630.jpg
#   inflating: /content/dataset/train/images/000000576652.jpg
#   inflating: /content/dataset/train/images/000000576963.jpg
#   inflating: /content/dataset/train/images/000000577207.jpg
#   inflating: /content/dataset/train/images/000000578226.jpg
#   inflating: /content/dataset/train/images/000000578307.jpg
#   inflating: /content/dataset/train/images/000000578525.jpg
#   inflating: /content/dataset/train/images/000000578888.jpg
#   inflating: /content/dataset/train/images/000000578918.jpg
#   inflating: /content/dataset/train/images/000000579060.jpg
#   inflating: /content/dataset/train/images/000000579179.jpg
#   inflating: /content/dataset/train/images/000000579414.jpg
#   inflating: /content/dataset/train/images/000000579758.jpg
#   inflating: /content/dataset/train/images/000000579925.jpg
#   inflating: /content/dataset/train/images/000000580778.jpg
#   inflating: /content/dataset/train/images/000000581018.jpg
#   inflating: /content/dataset/train/images/000000581495.jpg
#   inflating: /content/dataset/train/images/000000581827.jpg
#   inflating: /content/dataset/train/images/000000581831.jpg
#   inflating: /content/dataset/val/captions.txt
#   inflating: /content/dataset/val/images/000000002445.jpg
#   inflating: /content/dataset/val/images/000000002446.jpg
#   inflating: /content/dataset/val/images/000000002849.jpg
#   inflating: /content/dataset/val/images/000000005152.jpg
#   inflating: /content/dataset/val/images/000000006107.jpg
#   inflating: /content/dataset/val/images/000000007503.jpg
#   inflating: /content/dataset/val/images/000000008305.jpg
#   inflating: /content/dataset/val/images/000000008519.jpg
#   inflating: /content/dataset/val/images/000000009846.jpg
#   inflating: /content/dataset/val/images/000000009960.jpg
#   inflating: /content/dataset/val/images/000000010230.jpg
#   inflating: /content/dataset/val/images/000000010817.jpg
#   inflating: /content/dataset/val/images/000000011107.jpg
#   inflating: /content/dataset/val/images/000000012810.jpg
#   inflating: /content/dataset/val/images/000000013670.jpg
#   inflating: /content/dataset/val/images/000000014938.jpg
#   inflating: /content/dataset/val/images/000000015153.jpg
#   inflating: /content/dataset/val/images/000000016659.jpg
#   inflating: /content/dataset/val/images/000000017320.jpg
#   inflating: /content/dataset/val/images/000000018270.jpg
#   inflating: /content/dataset/val/images/000000018290.jpg
#   inflating: /content/dataset/val/images/000000019320.jpg
#   inflating: /content/dataset/val/images/000000019472.jpg
#   inflating: /content/dataset/val/images/000000020012.jpg
#   inflating: /content/dataset/val/images/000000020090.jpg
#   inflating: /content/dataset/val/images/000000021194.jpg
#   inflating: /content/dataset/val/images/000000022811.jpg
#   inflating: /content/dataset/val/images/000000023603.jpg
#   inflating: /content/dataset/val/images/000000023639.jpg
#   inflating: /content/dataset/val/images/000000023676.jpg
#   inflating: /content/dataset/val/images/000000024571.jpg
#   inflating: /content/dataset/val/images/000000026498.jpg
#   inflating: /content/dataset/val/images/000000026570.jpg
#   inflating: /content/dataset/val/images/000000027241.jpg
#   inflating: /content/dataset/val/images/000000028072.jpg
#   inflating: /content/dataset/val/images/000000028595.jpg
#   inflating: /content/dataset/val/images/000000028961.jpg
#   inflating: /content/dataset/val/images/000000029894.jpg
#   inflating: /content/dataset/val/images/000000031641.jpg
#   inflating: /content/dataset/val/images/000000032804.jpg
#   inflating: /content/dataset/val/images/000000032984.jpg
#   inflating: /content/dataset/val/images/000000033488.jpg
#   inflating: /content/dataset/val/images/000000033756.jpg
#   inflating: /content/dataset/val/images/000000033773.jpg
#   inflating: /content/dataset/val/images/000000033840.jpg
#   inflating: /content/dataset/val/images/000000033897.jpg
#   inflating: /content/dataset/val/images/000000034074.jpg
#   inflating: /content/dataset/val/images/000000034409.jpg
#   inflating: /content/dataset/val/images/000000035552.jpg
#   inflating: /content/dataset/val/images/000000036351.jpg
#   inflating: /content/dataset/val/images/000000036373.jpg
#   inflating: /content/dataset/val/images/000000039467.jpg
#   inflating: /content/dataset/val/images/000000040771.jpg
#   inflating: /content/dataset/val/images/000000040987.jpg
#   inflating: /content/dataset/val/images/000000041231.jpg
#   inflating: /content/dataset/val/images/000000041343.jpg
#   inflating: /content/dataset/val/images/000000042429.jpg
#   inflating: /content/dataset/val/images/000000043431.jpg
#   inflating: /content/dataset/val/images/000000044901.jpg
#   inflating: /content/dataset/val/images/000000045284.jpg
#   inflating: /content/dataset/val/images/000000046927.jpg
#   inflating: /content/dataset/val/images/000000046981.jpg
#   inflating: /content/dataset/val/images/000000047550.jpg
#   inflating: /content/dataset/val/images/000000048289.jpg
#   inflating: /content/dataset/val/images/000000048489.jpg
#   inflating: /content/dataset/val/images/000000048548.jpg
#   inflating: /content/dataset/val/images/000000048789.jpg
#   inflating: /content/dataset/val/images/000000049363.jpg
#   inflating: /content/dataset/val/images/000000049508.jpg
#   inflating: /content/dataset/val/images/000000050429.jpg
#   inflating: /content/dataset/val/images/000000050849.jpg
#   inflating: /content/dataset/val/images/000000052094.jpg
#   inflating: /content/dataset/val/images/000000052543.jpg
#   inflating: /content/dataset/val/images/000000053672.jpg
#   inflating: /content/dataset/val/images/000000053825.jpg
#   inflating: /content/dataset/val/images/000000054314.jpg
#   inflating: /content/dataset/val/images/000000054402.jpg
#   inflating: /content/dataset/val/images/000000054868.jpg
#   inflating: /content/dataset/val/images/000000055747.jpg
#   inflating: /content/dataset/val/images/000000055764.jpg
#   inflating: /content/dataset/val/images/000000056848.jpg
#   inflating: /content/dataset/val/images/000000057864.jpg
#   inflating: /content/dataset/val/images/000000058073.jpg
#   inflating: /content/dataset/val/images/000000058268.jpg
#   inflating: /content/dataset/val/images/000000058343.jpg
#   inflating: /content/dataset/val/images/000000058601.jpg
#   inflating: /content/dataset/val/images/000000058714.jpg
#   inflating: /content/dataset/val/images/000000059262.jpg
#   inflating: /content/dataset/val/images/000000059489.jpg
#   inflating: /content/dataset/val/images/000000059542.jpg
#   inflating: /content/dataset/val/images/000000060158.jpg
#   inflating: /content/dataset/val/images/000000060171.jpg
#   inflating: /content/dataset/val/images/000000060904.jpg
#   inflating: /content/dataset/val/images/000000061260.jpg
#   inflating: /content/dataset/val/images/000000061809.jpg
#   inflating: /content/dataset/val/images/000000064314.jpg
#   inflating: /content/dataset/val/images/000000064827.jpg
#   inflating: /content/dataset/val/images/000000064933.jpg
#   inflating: /content/dataset/val/images/000000065012.jpg
#   inflating: /content/dataset/val/images/000000065206.jpg
#   inflating: /content/dataset/val/images/000000065440.jpg
#   inflating: /content/dataset/val/images/000000065518.jpg
#   inflating: /content/dataset/val/images/000000066246.jpg
#   inflating: /content/dataset/val/images/000000066266.jpg
#   inflating: /content/dataset/val/images/000000068211.jpg
#   inflating: /content/dataset/val/images/000000068252.jpg
#   inflating: /content/dataset/val/images/000000068367.jpg
#   inflating: /content/dataset/val/images/000000068701.jpg
#   inflating: /content/dataset/val/images/000000068797.jpg
#   inflating: /content/dataset/val/images/000000068895.jpg
#   inflating: /content/dataset/val/images/000000069148.jpg
#   inflating: /content/dataset/val/images/000000069320.jpg
#   inflating: /content/dataset/val/images/000000070161.jpg
#   inflating: /content/dataset/val/images/000000070257.jpg
#   inflating: /content/dataset/val/images/000000070288.jpg
#   inflating: /content/dataset/val/images/000000070812.jpg
#   inflating: /content/dataset/val/images/000000070975.jpg
#   inflating: /content/dataset/val/images/000000071339.jpg
#   inflating: /content/dataset/val/images/000000072850.jpg
#   inflating: /content/dataset/val/images/000000074923.jpg
#   inflating: /content/dataset/val/images/000000075901.jpg
#   inflating: /content/dataset/val/images/000000075982.jpg
#   inflating: /content/dataset/val/images/000000076364.jpg
#   inflating: /content/dataset/val/images/000000076762.jpg
#   inflating: /content/dataset/val/images/000000077602.jpg
#   inflating: /content/dataset/val/images/000000078065.jpg
#   inflating: /content/dataset/val/images/000000078225.jpg
#   inflating: /content/dataset/val/images/000000078466.jpg
#   inflating: /content/dataset/val/images/000000080279.jpg
#   inflating: /content/dataset/val/images/000000081748.jpg
#   inflating: /content/dataset/val/images/000000083204.jpg
#   inflating: /content/dataset/val/images/000000083626.jpg
#   inflating: /content/dataset/val/images/000000083635.jpg
#   inflating: /content/dataset/val/images/000000084089.jpg
#   inflating: /content/dataset/val/images/000000084829.jpg
#   inflating: /content/dataset/val/images/000000084938.jpg
#   inflating: /content/dataset/val/images/000000086292.jpg
#   inflating: /content/dataset/val/images/000000086514.jpg
#   inflating: /content/dataset/val/images/000000086526.jpg
#   inflating: /content/dataset/val/images/000000087225.jpg
#   inflating: /content/dataset/val/images/000000087987.jpg
#   inflating: /content/dataset/val/images/000000088730.jpg
#   inflating: /content/dataset/val/images/000000088757.jpg
#   inflating: /content/dataset/val/images/000000089147.jpg
#   inflating: /content/dataset/val/images/000000090084.jpg
#   inflating: /content/dataset/val/images/000000091041.jpg
#   inflating: /content/dataset/val/images/000000091394.jpg
#   inflating: /content/dataset/val/images/000000091595.jpg
#   inflating: /content/dataset/val/images/000000091604.jpg
#   inflating: /content/dataset/val/images/000000093789.jpg
#   inflating: /content/dataset/val/images/000000095321.jpg
#   inflating: /content/dataset/val/images/000000096670.jpg
#   inflating: /content/dataset/val/images/000000097296.jpg
#   inflating: /content/dataset/val/images/000000099229.jpg
#   inflating: /content/dataset/val/images/000000099476.jpg
#   inflating: /content/dataset/val/images/000000100095.jpg
#   inflating: /content/dataset/val/images/000000100222.jpg
#   inflating: /content/dataset/val/images/000000100277.jpg
#   inflating: /content/dataset/val/images/000000100448.jpg
#   inflating: /content/dataset/val/images/000000100516.jpg
#   inflating: /content/dataset/val/images/000000100519.jpg
#   inflating: /content/dataset/val/images/000000101569.jpg
#   inflating: /content/dataset/val/images/000000101842.jpg
#   inflating: /content/dataset/val/images/000000102024.jpg
#   inflating: /content/dataset/val/images/000000102225.jpg
#   inflating: /content/dataset/val/images/000000102473.jpg
#   inflating: /content/dataset/val/images/000000103137.jpg
#   inflating: /content/dataset/val/images/000000103512.jpg
#   inflating: /content/dataset/val/images/000000103822.jpg
#   inflating: /content/dataset/val/images/000000103966.jpg
#   inflating: /content/dataset/val/images/000000104097.jpg
#   inflating: /content/dataset/val/images/000000104689.jpg
#   inflating: /content/dataset/val/images/000000105075.jpg
#   inflating: /content/dataset/val/images/000000105590.jpg
#   inflating: /content/dataset/val/images/000000107097.jpg
#   inflating: /content/dataset/val/images/000000108123.jpg
#   inflating: /content/dataset/val/images/000000108670.jpg
#   inflating: /content/dataset/val/images/000000109199.jpg
#   inflating: /content/dataset/val/images/000000109522.jpg
#   inflating: /content/dataset/val/images/000000110006.jpg
#   inflating: /content/dataset/val/images/000000111277.jpg
#   inflating: /content/dataset/val/images/000000111649.jpg
#   inflating: /content/dataset/val/images/000000112272.jpg
#   inflating: /content/dataset/val/images/000000112793.jpg
#   inflating: /content/dataset/val/images/000000113857.jpg
#   inflating: /content/dataset/val/images/000000114705.jpg
#   inflating: /content/dataset/val/images/000000114954.jpg
#   inflating: /content/dataset/val/images/000000115854.jpg
#   inflating: /content/dataset/val/images/000000115992.jpg
#   inflating: /content/dataset/val/images/000000116339.jpg
#   inflating: /content/dataset/val/images/000000117377.jpg
#   inflating: /content/dataset/val/images/000000117941.jpg
#   inflating: /content/dataset/val/images/000000118186.jpg
#   inflating: /content/dataset/val/images/000000118745.jpg
#   inflating: /content/dataset/val/images/000000119693.jpg
#   inflating: /content/dataset/val/images/000000120407.jpg
#   inflating: /content/dataset/val/images/000000123172.jpg
#   inflating: /content/dataset/val/images/000000123544.jpg
#   inflating: /content/dataset/val/images/000000123614.jpg
#   inflating: /content/dataset/val/images/000000124571.jpg
#   inflating: /content/dataset/val/images/000000124841.jpg
#   inflating: /content/dataset/val/images/000000125098.jpg
#   inflating: /content/dataset/val/images/000000125464.jpg
#   inflating: /content/dataset/val/images/000000125769.jpg
#   inflating: /content/dataset/val/images/000000126612.jpg
#   inflating: /content/dataset/val/images/000000126628.jpg
#   inflating: /content/dataset/val/images/000000127986.jpg
#   inflating: /content/dataset/val/images/000000128557.jpg
#   inflating: /content/dataset/val/images/000000128963.jpg
#   inflating: /content/dataset/val/images/000000129722.jpg
#   inflating: /content/dataset/val/images/000000130607.jpg
#   inflating: /content/dataset/val/images/000000132476.jpg
#   inflating: /content/dataset/val/images/000000133580.jpg
#   inflating: /content/dataset/val/images/000000134479.jpg
#   inflating: /content/dataset/val/images/000000134705.jpg
#   inflating: /content/dataset/val/images/000000134858.jpg
#   inflating: /content/dataset/val/images/000000136886.jpg
#   inflating: /content/dataset/val/images/000000138299.jpg
#   inflating: /content/dataset/val/images/000000138830.jpg
#   inflating: /content/dataset/val/images/000000139095.jpg
#   inflating: /content/dataset/val/images/000000139109.jpg
#   inflating: /content/dataset/val/images/000000140693.jpg
#   inflating: /content/dataset/val/images/000000141923.jpg
#   inflating: /content/dataset/val/images/000000142352.jpg
#   inflating: /content/dataset/val/images/000000143158.jpg
#   inflating: /content/dataset/val/images/000000143811.jpg
#   inflating: /content/dataset/val/images/000000143944.jpg
#   inflating: /content/dataset/val/images/000000144353.jpg
#   inflating: /content/dataset/val/images/000000146294.jpg
#   inflating: /content/dataset/val/images/000000146420.jpg
#   inflating: /content/dataset/val/images/000000146560.jpg
#   inflating: /content/dataset/val/images/000000147012.jpg
#   inflating: /content/dataset/val/images/000000148297.jpg
#   inflating: /content/dataset/val/images/000000148639.jpg
#   inflating: /content/dataset/val/images/000000150858.jpg
#   inflating: /content/dataset/val/images/000000151351.jpg
#   inflating: /content/dataset/val/images/000000151777.jpg
#   inflating: /content/dataset/val/images/000000152425.jpg
#   inflating: /content/dataset/val/images/000000152573.jpg
#   inflating: /content/dataset/val/images/000000153080.jpg
#   inflating: /content/dataset/val/images/000000153204.jpg
#   inflating: /content/dataset/val/images/000000153920.jpg
#   inflating: /content/dataset/val/images/000000154124.jpg
#   inflating: /content/dataset/val/images/000000154754.jpg
#   inflating: /content/dataset/val/images/000000155450.jpg
#   inflating: /content/dataset/val/images/000000155823.jpg
#   inflating: /content/dataset/val/images/000000155862.jpg
#   inflating: /content/dataset/val/images/000000156312.jpg
#   inflating: /content/dataset/val/images/000000156425.jpg
#   inflating: /content/dataset/val/images/000000156593.jpg
#   inflating: /content/dataset/val/images/000000156763.jpg
#   inflating: /content/dataset/val/images/000000159424.jpg
#   inflating: /content/dataset/val/images/000000160694.jpg
#   inflating: /content/dataset/val/images/000000161028.jpg
#   inflating: /content/dataset/val/images/000000161157.jpg
#   inflating: /content/dataset/val/images/000000161328.jpg
#   inflating: /content/dataset/val/images/000000162319.jpg
#   inflating: /content/dataset/val/images/000000162578.jpg
#   inflating: /content/dataset/val/images/000000162753.jpg
#   inflating: /content/dataset/val/images/000000162757.jpg
#   inflating: /content/dataset/val/images/000000162930.jpg
#   inflating: /content/dataset/val/images/000000163281.jpg
#   inflating: /content/dataset/val/images/000000163435.jpg
#   inflating: /content/dataset/val/images/000000163553.jpg
#   inflating: /content/dataset/val/images/000000163617.jpg
#   inflating: /content/dataset/val/images/000000163991.jpg
#   inflating: /content/dataset/val/images/000000163992.jpg
#   inflating: /content/dataset/val/images/000000164262.jpg
#   inflating: /content/dataset/val/images/000000164598.jpg
#   inflating: /content/dataset/val/images/000000165199.jpg
#   inflating: /content/dataset/val/images/000000165658.jpg
#   inflating: /content/dataset/val/images/000000166310.jpg
#   inflating: /content/dataset/val/images/000000166386.jpg
#   inflating: /content/dataset/val/images/000000167006.jpg
#   inflating: /content/dataset/val/images/000000167348.jpg
#   inflating: /content/dataset/val/images/000000167903.jpg
#   inflating: /content/dataset/val/images/000000168097.jpg
#   inflating: /content/dataset/val/images/000000168151.jpg
#   inflating: /content/dataset/val/images/000000168218.jpg
#   inflating: /content/dataset/val/images/000000168569.jpg
#   inflating: /content/dataset/val/images/000000168833.jpg
#   inflating: /content/dataset/val/images/000000170040.jpg
#   inflating: /content/dataset/val/images/000000170695.jpg
#   inflating: /content/dataset/val/images/000000171126.jpg
#   inflating: /content/dataset/val/images/000000173482.jpg
#   inflating: /content/dataset/val/images/000000173546.jpg
#   inflating: /content/dataset/val/images/000000174375.jpg
#   inflating: /content/dataset/val/images/000000174391.jpg
#   inflating: /content/dataset/val/images/000000174605.jpg
#   inflating: /content/dataset/val/images/000000177948.jpg
#   inflating: /content/dataset/val/images/000000178052.jpg
#   inflating: /content/dataset/val/images/000000178112.jpg
#   inflating: /content/dataset/val/images/000000178566.jpg
#   inflating: /content/dataset/val/images/000000180436.jpg
#   inflating: /content/dataset/val/images/000000182634.jpg
#   inflating: /content/dataset/val/images/000000183007.jpg
#   inflating: /content/dataset/val/images/000000183401.jpg
#   inflating: /content/dataset/val/images/000000183807.jpg
#   inflating: /content/dataset/val/images/000000184275.jpg
#   inflating: /content/dataset/val/images/000000184463.jpg
#   inflating: /content/dataset/val/images/000000184877.jpg
#   inflating: /content/dataset/val/images/000000185945.jpg
#   inflating: /content/dataset/val/images/000000186109.jpg
#   inflating: /content/dataset/val/images/000000186544.jpg
#   inflating: /content/dataset/val/images/000000186611.jpg
#   inflating: /content/dataset/val/images/000000187709.jpg
#   inflating: /content/dataset/val/images/000000188085.jpg
#   inflating: /content/dataset/val/images/000000188757.jpg
#   inflating: /content/dataset/val/images/000000189614.jpg
#   inflating: /content/dataset/val/images/000000190645.jpg
#   inflating: /content/dataset/val/images/000000190732.jpg
#   inflating: /content/dataset/val/images/000000193677.jpg
#   inflating: /content/dataset/val/images/000000194299.jpg
#   inflating: /content/dataset/val/images/000000194600.jpg
#   inflating: /content/dataset/val/images/000000194941.jpg
#   inflating: /content/dataset/val/images/000000194975.jpg
#   inflating: /content/dataset/val/images/000000195124.jpg
#   inflating: /content/dataset/val/images/000000195978.jpg
#   inflating: /content/dataset/val/images/000000196529.jpg
#   inflating: /content/dataset/val/images/000000196785.jpg
#   inflating: /content/dataset/val/images/000000196931.jpg
#   inflating: /content/dataset/val/images/000000197195.jpg
#   inflating: /content/dataset/val/images/000000197246.jpg
#   inflating: /content/dataset/val/images/000000197307.jpg
#   inflating: /content/dataset/val/images/000000197584.jpg
#   inflating: /content/dataset/val/images/000000197827.jpg
#   inflating: /content/dataset/val/images/000000198323.jpg
#   inflating: /content/dataset/val/images/000000198423.jpg
#   inflating: /content/dataset/val/images/000000199326.jpg
#   inflating: /content/dataset/val/images/000000199720.jpg
#   inflating: /content/dataset/val/images/000000200132.jpg
#   inflating: /content/dataset/val/images/000000200611.jpg
#   inflating: /content/dataset/val/images/000000202914.jpg
#   inflating: /content/dataset/val/images/000000203891.jpg
#   inflating: /content/dataset/val/images/000000203986.jpg
#   inflating: /content/dataset/val/images/000000205297.jpg
#   inflating: /content/dataset/val/images/000000205313.jpg
#   inflating: /content/dataset/val/images/000000206861.jpg
#   inflating: /content/dataset/val/images/000000207223.jpg
#   inflating: /content/dataset/val/images/000000207349.jpg
#   inflating: /content/dataset/val/images/000000207647.jpg
#   inflating: /content/dataset/val/images/000000207668.jpg
#   inflating: /content/dataset/val/images/000000207943.jpg
#   inflating: /content/dataset/val/images/000000208978.jpg
#   inflating: /content/dataset/val/images/000000209027.jpg
#   inflating: /content/dataset/val/images/000000209353.jpg
#   inflating: /content/dataset/val/images/000000210286.jpg
#   inflating: /content/dataset/val/images/000000211079.jpg
#   inflating: /content/dataset/val/images/000000211283.jpg
#   inflating: /content/dataset/val/images/000000214213.jpg
#   inflating: /content/dataset/val/images/000000214254.jpg
#   inflating: /content/dataset/val/images/000000214371.jpg
#   inflating: /content/dataset/val/images/000000215077.jpg
#   inflating: /content/dataset/val/images/000000215273.jpg
#   inflating: /content/dataset/val/images/000000215719.jpg
#   inflating: /content/dataset/val/images/000000216771.jpg
#   inflating: /content/dataset/val/images/000000216802.jpg
#   inflating: /content/dataset/val/images/000000217486.jpg
#   inflating: /content/dataset/val/images/000000219294.jpg
#   inflating: /content/dataset/val/images/000000219385.jpg
#   inflating: /content/dataset/val/images/000000220972.jpg
#   inflating: /content/dataset/val/images/000000221748.jpg
#   inflating: /content/dataset/val/images/000000222751.jpg
#   inflating: /content/dataset/val/images/000000223014.jpg
#   inflating: /content/dataset/val/images/000000223084.jpg
#   inflating: /content/dataset/val/images/000000223442.jpg
#   inflating: /content/dataset/val/images/000000223928.jpg
#   inflating: /content/dataset/val/images/000000225241.jpg
#   inflating: /content/dataset/val/images/000000225372.jpg
#   inflating: /content/dataset/val/images/000000225607.jpg
#   inflating: /content/dataset/val/images/000000226298.jpg
#   inflating: /content/dataset/val/images/000000227109.jpg
#   inflating: /content/dataset/val/images/000000228413.jpg
#   inflating: /content/dataset/val/images/000000228664.jpg
#   inflating: /content/dataset/val/images/000000230404.jpg
#   inflating: /content/dataset/val/images/000000230707.jpg
#   inflating: /content/dataset/val/images/000000230863.jpg
#   inflating: /content/dataset/val/images/000000232049.jpg
#   inflating: /content/dataset/val/images/000000233904.jpg
#   inflating: /content/dataset/val/images/000000234006.jpg
#   inflating: /content/dataset/val/images/000000234616.jpg
#   inflating: /content/dataset/val/images/000000234848.jpg
#   inflating: /content/dataset/val/images/000000235409.jpg
#   inflating: /content/dataset/val/images/000000236078.jpg
#   inflating: /content/dataset/val/images/000000236222.jpg
#   inflating: /content/dataset/val/images/000000236385.jpg
#   inflating: /content/dataset/val/images/000000236650.jpg
#   inflating: /content/dataset/val/images/000000236840.jpg
#   inflating: /content/dataset/val/images/000000237129.jpg
#   inflating: /content/dataset/val/images/000000237798.jpg
#   inflating: /content/dataset/val/images/000000237850.jpg
#   inflating: /content/dataset/val/images/000000238591.jpg
#   inflating: /content/dataset/val/images/000000238712.jpg
#   inflating: /content/dataset/val/images/000000238963.jpg
#   inflating: /content/dataset/val/images/000000240490.jpg
#   inflating: /content/dataset/val/images/000000241305.jpg
#   inflating: /content/dataset/val/images/000000241643.jpg
#   inflating: /content/dataset/val/images/000000242213.jpg
#   inflating: /content/dataset/val/images/000000242453.jpg
#   inflating: /content/dataset/val/images/000000242716.jpg
#   inflating: /content/dataset/val/images/000000243268.jpg
#   inflating: /content/dataset/val/images/000000246390.jpg
#   inflating: /content/dataset/val/images/000000246980.jpg
#   inflating: /content/dataset/val/images/000000247126.jpg
#   inflating: /content/dataset/val/images/000000249531.jpg
#   inflating: /content/dataset/val/images/000000250941.jpg
#   inflating: /content/dataset/val/images/000000252036.jpg
#   inflating: /content/dataset/val/images/000000254327.jpg
#   inflating: /content/dataset/val/images/000000254387.jpg
#   inflating: /content/dataset/val/images/000000254801.jpg
#   inflating: /content/dataset/val/images/000000255941.jpg
#   inflating: /content/dataset/val/images/000000257387.jpg
#   inflating: /content/dataset/val/images/000000257498.jpg
#   inflating: /content/dataset/val/images/000000258222.jpg
#   inflating: /content/dataset/val/images/000000258544.jpg
#   inflating: /content/dataset/val/images/000000259187.jpg
#   inflating: /content/dataset/val/images/000000260702.jpg
#   inflating: /content/dataset/val/images/000000260852.jpg
#   inflating: /content/dataset/val/images/000000261280.jpg
#   inflating: /content/dataset/val/images/000000261477.jpg
#   inflating: /content/dataset/val/images/000000262884.jpg
#   inflating: /content/dataset/val/images/000000262893.jpg
#   inflating: /content/dataset/val/images/000000264695.jpg
#   inflating: /content/dataset/val/images/000000264846.jpg
#   inflating: /content/dataset/val/images/000000265889.jpg
#   inflating: /content/dataset/val/images/000000267457.jpg
#   inflating: /content/dataset/val/images/000000267499.jpg
#   inflating: /content/dataset/val/images/000000267848.jpg
#   inflating: /content/dataset/val/images/000000269079.jpg
#   inflating: /content/dataset/val/images/000000269229.jpg
#   inflating: /content/dataset/val/images/000000269863.jpg
#   inflating: /content/dataset/val/images/000000270740.jpg
#   inflating: /content/dataset/val/images/000000272365.jpg
#   inflating: /content/dataset/val/images/000000273207.jpg
#   inflating: /content/dataset/val/images/000000273363.jpg
#   inflating: /content/dataset/val/images/000000274047.jpg
#   inflating: /content/dataset/val/images/000000274688.jpg
#   inflating: /content/dataset/val/images/000000274949.jpg
#   inflating: /content/dataset/val/images/000000275775.jpg
#   inflating: /content/dataset/val/images/000000276417.jpg
#   inflating: /content/dataset/val/images/000000276686.jpg
#   inflating: /content/dataset/val/images/000000278297.jpg
#   inflating: /content/dataset/val/images/000000279385.jpg
#   inflating: /content/dataset/val/images/000000280307.jpg
#   inflating: /content/dataset/val/images/000000280876.jpg
#   inflating: /content/dataset/val/images/000000281105.jpg
#   inflating: /content/dataset/val/images/000000281293.jpg
#   inflating: /content/dataset/val/images/000000282482.jpg
#   inflating: /content/dataset/val/images/000000282564.jpg
#   inflating: /content/dataset/val/images/000000283859.jpg
#   inflating: /content/dataset/val/images/000000284150.jpg
#   inflating: /content/dataset/val/images/000000284366.jpg
#   inflating: /content/dataset/val/images/000000284770.jpg
#   inflating: /content/dataset/val/images/000000286064.jpg
#   inflating: /content/dataset/val/images/000000286129.jpg
#   inflating: /content/dataset/val/images/000000287831.jpg
#   inflating: /content/dataset/val/images/000000288180.jpg
#   inflating: /content/dataset/val/images/000000288761.jpg
#   inflating: /content/dataset/val/images/000000289342.jpg
#   inflating: /content/dataset/val/images/000000289684.jpg
#   inflating: /content/dataset/val/images/000000291540.jpg
#   inflating: /content/dataset/val/images/000000292510.jpg
#   inflating: /content/dataset/val/images/000000294498.jpg
#   inflating: /content/dataset/val/images/000000294912.jpg
#   inflating: /content/dataset/val/images/000000295082.jpg
#   inflating: /content/dataset/val/images/000000295578.jpg
#   inflating: /content/dataset/val/images/000000295961.jpg
#   inflating: /content/dataset/val/images/000000296385.jpg
#   inflating: /content/dataset/val/images/000000298306.jpg
#   inflating: /content/dataset/val/images/000000298878.jpg
#   inflating: /content/dataset/val/images/000000298917.jpg
#   inflating: /content/dataset/val/images/000000299394.jpg
#   inflating: /content/dataset/val/images/000000299662.jpg
#   inflating: /content/dataset/val/images/000000299679.jpg
#   inflating: /content/dataset/val/images/000000299932.jpg
#   inflating: /content/dataset/val/images/000000300383.jpg
#   inflating: /content/dataset/val/images/000000302168.jpg
#   inflating: /content/dataset/val/images/000000308694.jpg
#   inflating: /content/dataset/val/images/000000308783.jpg
#   inflating: /content/dataset/val/images/000000310588.jpg
#   inflating: /content/dataset/val/images/000000311244.jpg
#   inflating: /content/dataset/val/images/000000311436.jpg
#   inflating: /content/dataset/val/images/000000313020.jpg
#   inflating: /content/dataset/val/images/000000313234.jpg
#   inflating: /content/dataset/val/images/000000313313.jpg
#   inflating: /content/dataset/val/images/000000313532.jpg
#   inflating: /content/dataset/val/images/000000314357.jpg
#   inflating: /content/dataset/val/images/000000315339.jpg
#   inflating: /content/dataset/val/images/000000315487.jpg
#   inflating: /content/dataset/val/images/000000316012.jpg
#   inflating: /content/dataset/val/images/000000317149.jpg
#   inflating: /content/dataset/val/images/000000317186.jpg
#   inflating: /content/dataset/val/images/000000318241.jpg
#   inflating: /content/dataset/val/images/000000318637.jpg
#   inflating: /content/dataset/val/images/000000318733.jpg
#   inflating: /content/dataset/val/images/000000319031.jpg
#   inflating: /content/dataset/val/images/000000320349.jpg
#   inflating: /content/dataset/val/images/000000320523.jpg
#   inflating: /content/dataset/val/images/000000321030.jpg
#   inflating: /content/dataset/val/images/000000321318.jpg
#   inflating: /content/dataset/val/images/000000321389.jpg
#   inflating: /content/dataset/val/images/000000321991.jpg
#   inflating: /content/dataset/val/images/000000323746.jpg
#   inflating: /content/dataset/val/images/000000324904.jpg
#   inflating: /content/dataset/val/images/000000324943.jpg
#   inflating: /content/dataset/val/images/000000325482.jpg
#   inflating: /content/dataset/val/images/000000325495.jpg
#   inflating: /content/dataset/val/images/000000326190.jpg
#   inflating: /content/dataset/val/images/000000326350.jpg
#   inflating: /content/dataset/val/images/000000327063.jpg
#   inflating: /content/dataset/val/images/000000327217.jpg
#   inflating: /content/dataset/val/images/000000327299.jpg
#   inflating: /content/dataset/val/images/000000327818.jpg
#   inflating: /content/dataset/val/images/000000327935.jpg
#   inflating: /content/dataset/val/images/000000328203.jpg
#   inflating: /content/dataset/val/images/000000328743.jpg
#   inflating: /content/dataset/val/images/000000329817.jpg
#   inflating: /content/dataset/val/images/000000330256.jpg
#   inflating: /content/dataset/val/images/000000330341.jpg
#   inflating: /content/dataset/val/images/000000330806.jpg
#   inflating: /content/dataset/val/images/000000331023.jpg
#   inflating: /content/dataset/val/images/000000331474.jpg
#   inflating: /content/dataset/val/images/000000332591.jpg
#   inflating: /content/dataset/val/images/000000332792.jpg
#   inflating: /content/dataset/val/images/000000333258.jpg
#   inflating: /content/dataset/val/images/000000333749.jpg
#   inflating: /content/dataset/val/images/000000333946.jpg
#   inflating: /content/dataset/val/images/000000334703.jpg
#   inflating: /content/dataset/val/images/000000334723.jpg
#   inflating: /content/dataset/val/images/000000334837.jpg
#   inflating: /content/dataset/val/images/000000335231.jpg
#   inflating: /content/dataset/val/images/000000335709.jpg
#   inflating: /content/dataset/val/images/000000337038.jpg
#   inflating: /content/dataset/val/images/000000338501.jpg
#   inflating: /content/dataset/val/images/000000339283.jpg
#   inflating: /content/dataset/val/images/000000339611.jpg
#   inflating: /content/dataset/val/images/000000341186.jpg
#   inflating: /content/dataset/val/images/000000342017.jpg
#   inflating: /content/dataset/val/images/000000342019.jpg
#   inflating: /content/dataset/val/images/000000343227.jpg
#   inflating: /content/dataset/val/images/000000344491.jpg
#   inflating: /content/dataset/val/images/000000345882.jpg
#   inflating: /content/dataset/val/images/000000346168.jpg
#   inflating: /content/dataset/val/images/000000346196.jpg
#   inflating: /content/dataset/val/images/000000348636.jpg
#   inflating: /content/dataset/val/images/000000348684.jpg
#   inflating: /content/dataset/val/images/000000350339.jpg
#   inflating: /content/dataset/val/images/000000351451.jpg
#   inflating: /content/dataset/val/images/000000354846.jpg
#   inflating: /content/dataset/val/images/000000355902.jpg
#   inflating: /content/dataset/val/images/000000357015.jpg
#   inflating: /content/dataset/val/images/000000358789.jpg
#   inflating: /content/dataset/val/images/000000359414.jpg
#   inflating: /content/dataset/val/images/000000359497.jpg
#   inflating: /content/dataset/val/images/000000359686.jpg
#   inflating: /content/dataset/val/images/000000359872.jpg
#   inflating: /content/dataset/val/images/000000359996.jpg
#   inflating: /content/dataset/val/images/000000360736.jpg
#   inflating: /content/dataset/val/images/000000360813.jpg
#   inflating: /content/dataset/val/images/000000360857.jpg
#   inflating: /content/dataset/val/images/000000361291.jpg
#   inflating: /content/dataset/val/images/000000362065.jpg
#   inflating: /content/dataset/val/images/000000362591.jpg
#   inflating: /content/dataset/val/images/000000363333.jpg
#   inflating: /content/dataset/val/images/000000363504.jpg
#   inflating: /content/dataset/val/images/000000363987.jpg
#   inflating: /content/dataset/val/images/000000364135.jpg
#   inflating: /content/dataset/val/images/000000364934.jpg
# ...
#   inflating: /content/file/dataset/val/images/000000439084.jpg
#   inflating: /content/file/dataset/val/images/000000440389.jpg
#   inflating: /content/file/dataset/val/images/000000440592.jpg
#   inflating: /content/file/dataset/val/images/000000440652.jpg
#   inflating: /content/file/dataset/val/images/000000441032.jpg
#   inflating: /content/file/dataset/val/images/000000443319.jpg
#   inflating: /content/file/dataset/val/images/000000443618.jpg
#   inflating: /content/file/dataset/val/images/000000443684.jpg
#   inflating: /content/file/dataset/val/images/000000444692.jpg
#   inflating: /content/file/dataset/val/images/000000445454.jpg
#   inflating: /content/file/dataset/val/images/000000445493.jpg
#   inflating: /content/file/dataset/val/images/000000445754.jpg
#   inflating: /content/file/dataset/val/images/000000447118.jpg
#   inflating: /content/file/dataset/val/images/000000447224.jpg
#   inflating: /content/file/dataset/val/images/000000447464.jpg
#   inflating: /content/file/dataset/val/images/000000448130.jpg
#   inflating: /content/file/dataset/val/images/000000448824.jpg
#   inflating: /content/file/dataset/val/images/000000448969.jpg
#   inflating: /content/file/dataset/val/images/000000449119.jpg
#   inflating: /content/file/dataset/val/images/000000449179.jpg
#   inflating: /content/file/dataset/val/images/000000449705.jpg
#   inflating: /content/file/dataset/val/images/000000449914.jpg
#   inflating: /content/file/dataset/val/images/000000450597.jpg
#   inflating: /content/file/dataset/val/images/000000450800.jpg
#   inflating: /content/file/dataset/val/images/000000451166.jpg
#   inflating: /content/file/dataset/val/images/000000451184.jpg
#   inflating: /content/file/dataset/val/images/000000451389.jpg
#   inflating: /content/file/dataset/val/images/000000451580.jpg
#   inflating: /content/file/dataset/val/images/000000452545.jpg
#   inflating: /content/file/dataset/val/images/000000453689.jpg
#   inflating: /content/file/dataset/val/images/000000454158.jpg
#   inflating: /content/file/dataset/val/images/000000454291.jpg
#   inflating: /content/file/dataset/val/images/000000454541.jpg
#   inflating: /content/file/dataset/val/images/000000455791.jpg
#   inflating: /content/file/dataset/val/images/000000457207.jpg
#   inflating: /content/file/dataset/val/images/000000457274.jpg
#   inflating: /content/file/dataset/val/images/000000458752.jpg
#   inflating: /content/file/dataset/val/images/000000459653.jpg
#   inflating: /content/file/dataset/val/images/000000459951.jpg
#   inflating: /content/file/dataset/val/images/000000460115.jpg
#   inflating: /content/file/dataset/val/images/000000462132.jpg
#   inflating: /content/file/dataset/val/images/000000462530.jpg
#   inflating: /content/file/dataset/val/images/000000463308.jpg
#   inflating: /content/file/dataset/val/images/000000464603.jpg
#   inflating: /content/file/dataset/val/images/000000464789.jpg
#   inflating: /content/file/dataset/val/images/000000465181.jpg
#   inflating: /content/file/dataset/val/images/000000465702.jpg
#   inflating: /content/file/dataset/val/images/000000466505.jpg
#   inflating: /content/file/dataset/val/images/000000466544.jpg
#   inflating: /content/file/dataset/val/images/000000467182.jpg
#   inflating: /content/file/dataset/val/images/000000467461.jpg
#   inflating: /content/file/dataset/val/images/000000468137.jpg
#   inflating: /content/file/dataset/val/images/000000468319.jpg
#   inflating: /content/file/dataset/val/images/000000468626.jpg
#   inflating: /content/file/dataset/val/images/000000468662.jpg
#   inflating: /content/file/dataset/val/images/000000468789.jpg
#   inflating: /content/file/dataset/val/images/000000469559.jpg
#   inflating: /content/file/dataset/val/images/000000470053.jpg
#   inflating: /content/file/dataset/val/images/000000470097.jpg
#   inflating: /content/file/dataset/val/images/000000471113.jpg
#   inflating: /content/file/dataset/val/images/000000471470.jpg
#   inflating: /content/file/dataset/val/images/000000471966.jpg
#   inflating: /content/file/dataset/val/images/000000472329.jpg
#   inflating: /content/file/dataset/val/images/000000473281.jpg
#   inflating: /content/file/dataset/val/images/000000474168.jpg
#   inflating: /content/file/dataset/val/images/000000474255.jpg
#   inflating: /content/file/dataset/val/images/000000474777.jpg
#   inflating: /content/file/dataset/val/images/000000475588.jpg
#   inflating: /content/file/dataset/val/images/000000475915.jpg
#   inflating: /content/file/dataset/val/images/000000477120.jpg
#   inflating: /content/file/dataset/val/images/000000478052.jpg
#   inflating: /content/file/dataset/val/images/000000483261.jpg
#   inflating: /content/file/dataset/val/images/000000483378.jpg
#   inflating: /content/file/dataset/val/images/000000484186.jpg
#   inflating: /content/file/dataset/val/images/000000484338.jpg
#   inflating: /content/file/dataset/val/images/000000485016.jpg
#   inflating: /content/file/dataset/val/images/000000485267.jpg
#   inflating: /content/file/dataset/val/images/000000485689.jpg
#   inflating: /content/file/dataset/val/images/000000485829.jpg
#   inflating: /content/file/dataset/val/images/000000486471.jpg
#   inflating: /content/file/dataset/val/images/000000488634.jpg
#   inflating: /content/file/dataset/val/images/000000489121.jpg
#   inflating: /content/file/dataset/val/images/000000490336.jpg
#   inflating: /content/file/dataset/val/images/000000490541.jpg
#   inflating: /content/file/dataset/val/images/000000490875.jpg
#   inflating: /content/file/dataset/val/images/000000490940.jpg
#   inflating: /content/file/dataset/val/images/000000491053.jpg
#   inflating: /content/file/dataset/val/images/000000491287.jpg
#   inflating: /content/file/dataset/val/images/000000491430.jpg
#   inflating: /content/file/dataset/val/images/000000491467.jpg
#   inflating: /content/file/dataset/val/images/000000491581.jpg
#   inflating: /content/file/dataset/val/images/000000491823.jpg
#   inflating: /content/file/dataset/val/images/000000492489.jpg
#   inflating: /content/file/dataset/val/images/000000492943.jpg
#   inflating: /content/file/dataset/val/images/000000493110.jpg
#   inflating: /content/file/dataset/val/images/000000493294.jpg
#   inflating: /content/file/dataset/val/images/000000493484.jpg
#   inflating: /content/file/dataset/val/images/000000494462.jpg
#   inflating: /content/file/dataset/val/images/000000494711.jpg
#   inflating: /content/file/dataset/val/images/000000495905.jpg
#   inflating: /content/file/dataset/val/images/000000496322.jpg
#   inflating: /content/file/dataset/val/images/000000497177.jpg
#   inflating: /content/file/dataset/val/images/000000498173.jpg
#   inflating: /content/file/dataset/val/images/000000498204.jpg
#   inflating: /content/file/dataset/val/images/000000498337.jpg
#   inflating: /content/file/dataset/val/images/000000499523.jpg
#   inflating: /content/file/dataset/val/images/000000500390.jpg
#   inflating: /content/file/dataset/val/images/000000501263.jpg
#   inflating: /content/file/dataset/val/images/000000501293.jpg
#   inflating: /content/file/dataset/val/images/000000502632.jpg
#   inflating: /content/file/dataset/val/images/000000503806.jpg
#   inflating: /content/file/dataset/val/images/000000504170.jpg
#   inflating: /content/file/dataset/val/images/000000504318.jpg
#   inflating: /content/file/dataset/val/images/000000504807.jpg
#   inflating: /content/file/dataset/val/images/000000505701.jpg
#   inflating: /content/file/dataset/val/images/000000505924.jpg
#   inflating: /content/file/dataset/val/images/000000505936.jpg
#   inflating: /content/file/dataset/val/images/000000506209.jpg
#   inflating: /content/file/dataset/val/images/000000506232.jpg
#   inflating: /content/file/dataset/val/images/000000507665.jpg
#   inflating: /content/file/dataset/val/images/000000508053.jpg
#   inflating: /content/file/dataset/val/images/000000508269.jpg
#   inflating: /content/file/dataset/val/images/000000508548.jpg
#   inflating: /content/file/dataset/val/images/000000508840.jpg
#   inflating: /content/file/dataset/val/images/000000508855.jpg
#   inflating: /content/file/dataset/val/images/000000510211.jpg
#   inflating: /content/file/dataset/val/images/000000510626.jpg
#   inflating: /content/file/dataset/val/images/000000512418.jpg
#   inflating: /content/file/dataset/val/images/000000513015.jpg
#   inflating: /content/file/dataset/val/images/000000513124.jpg
#   inflating: /content/file/dataset/val/images/000000515274.jpg
#   inflating: /content/file/dataset/val/images/000000515638.jpg
#   inflating: /content/file/dataset/val/images/000000516034.jpg
#   inflating: /content/file/dataset/val/images/000000517005.jpg
#   inflating: /content/file/dataset/val/images/000000517113.jpg
#   inflating: /content/file/dataset/val/images/000000519483.jpg
#   inflating: /content/file/dataset/val/images/000000519950.jpg
#   inflating: /content/file/dataset/val/images/000000520769.jpg
#   inflating: /content/file/dataset/val/images/000000521382.jpg
#   inflating: /content/file/dataset/val/images/000000521482.jpg
#   inflating: /content/file/dataset/val/images/000000522233.jpg
#   inflating: /content/file/dataset/val/images/000000522256.jpg
#   inflating: /content/file/dataset/val/images/000000524118.jpg
#   inflating: /content/file/dataset/val/images/000000524559.jpg
#   inflating: /content/file/dataset/val/images/000000525714.jpg
#   inflating: /content/file/dataset/val/images/000000525990.jpg
#   inflating: /content/file/dataset/val/images/000000526968.jpg
#   inflating: /content/file/dataset/val/images/000000527194.jpg
#   inflating: /content/file/dataset/val/images/000000527446.jpg
#   inflating: /content/file/dataset/val/images/000000529036.jpg
#   inflating: /content/file/dataset/val/images/000000529248.jpg
#   inflating: /content/file/dataset/val/images/000000529303.jpg
#   inflating: /content/file/dataset/val/images/000000529665.jpg
#   inflating: /content/file/dataset/val/images/000000530293.jpg
#   inflating: /content/file/dataset/val/images/000000531266.jpg
#   inflating: /content/file/dataset/val/images/000000531453.jpg
#   inflating: /content/file/dataset/val/images/000000532719.jpg
#   inflating: /content/file/dataset/val/images/000000533396.jpg
#   inflating: /content/file/dataset/val/images/000000534391.jpg
#   inflating: /content/file/dataset/val/images/000000534412.jpg
#   inflating: /content/file/dataset/val/images/000000534555.jpg
#   inflating: /content/file/dataset/val/images/000000535212.jpg
#   inflating: /content/file/dataset/val/images/000000535234.jpg
#   inflating: /content/file/dataset/val/images/000000536087.jpg
#   inflating: /content/file/dataset/val/images/000000536969.jpg
#   inflating: /content/file/dataset/val/images/000000537543.jpg
#   inflating: /content/file/dataset/val/images/000000538470.jpg
#   inflating: /content/file/dataset/val/images/000000540439.jpg
#   inflating: /content/file/dataset/val/images/000000540575.jpg
#   inflating: /content/file/dataset/val/images/000000542200.jpg
#   inflating: /content/file/dataset/val/images/000000542412.jpg
#   inflating: /content/file/dataset/val/images/000000543155.jpg
#   inflating: /content/file/dataset/val/images/000000543379.jpg
#   inflating: /content/file/dataset/val/images/000000543389.jpg
#   inflating: /content/file/dataset/val/images/000000543480.jpg
#   inflating: /content/file/dataset/val/images/000000543635.jpg
#   inflating: /content/file/dataset/val/images/000000545116.jpg
#   inflating: /content/file/dataset/val/images/000000545165.jpg
#   inflating: /content/file/dataset/val/images/000000545493.jpg
#   inflating: /content/file/dataset/val/images/000000546183.jpg
#   inflating: /content/file/dataset/val/images/000000546518.jpg
#   inflating: /content/file/dataset/val/images/000000546864.jpg
#   inflating: /content/file/dataset/val/images/000000547513.jpg
#   inflating: /content/file/dataset/val/images/000000547726.jpg
#   inflating: /content/file/dataset/val/images/000000548177.jpg
#   inflating: /content/file/dataset/val/images/000000548186.jpg
#   inflating: /content/file/dataset/val/images/000000548802.jpg
#   inflating: /content/file/dataset/val/images/000000549804.jpg
#   inflating: /content/file/dataset/val/images/000000549910.jpg
#   inflating: /content/file/dataset/val/images/000000550049.jpg
#   inflating: /content/file/dataset/val/images/000000550455.jpg
#   inflating: /content/file/dataset/val/images/000000551936.jpg
#   inflating: /content/file/dataset/val/images/000000552116.jpg
#   inflating: /content/file/dataset/val/images/000000552184.jpg
#   inflating: /content/file/dataset/val/images/000000552630.jpg
#   inflating: /content/file/dataset/val/images/000000553046.jpg
#   inflating: /content/file/dataset/val/images/000000553446.jpg
#   inflating: /content/file/dataset/val/images/000000553623.jpg
#   inflating: /content/file/dataset/val/images/000000553849.jpg
#   inflating: /content/file/dataset/val/images/000000554238.jpg
#   inflating: /content/file/dataset/val/images/000000554301.jpg
#   inflating: /content/file/dataset/val/images/000000554464.jpg
#   inflating: /content/file/dataset/val/images/000000555294.jpg
#   inflating: /content/file/dataset/val/images/000000556108.jpg
#   inflating: /content/file/dataset/val/images/000000556342.jpg
#   inflating: /content/file/dataset/val/images/000000557952.jpg
#   inflating: /content/file/dataset/val/images/000000558066.jpg
#   inflating: /content/file/dataset/val/images/000000559053.jpg
#   inflating: /content/file/dataset/val/images/000000559350.jpg
#   inflating: /content/file/dataset/val/images/000000561593.jpg
#   inflating: /content/file/dataset/val/images/000000562325.jpg
#   inflating: /content/file/dataset/val/images/000000562428.jpg
#   inflating: /content/file/dataset/val/images/000000563122.jpg
#   inflating: /content/file/dataset/val/images/000000563628.jpg
#   inflating: /content/file/dataset/val/images/000000564153.jpg
#   inflating: /content/file/dataset/val/images/000000565149.jpg
#   inflating: /content/file/dataset/val/images/000000565600.jpg
#   inflating: /content/file/dataset/val/images/000000566746.jpg
#   inflating: /content/file/dataset/val/images/000000566993.jpg
#   inflating: /content/file/dataset/val/images/000000567630.jpg
#   inflating: /content/file/dataset/val/images/000000568420.jpg
#   inflating: /content/file/dataset/val/images/000000568462.jpg
#   inflating: /content/file/dataset/val/images/000000569996.jpg
#   inflating: /content/file/dataset/val/images/000000570629.jpg
#   inflating: /content/file/dataset/val/images/000000570738.jpg
#   inflating: /content/file/dataset/val/images/000000572012.jpg
#   inflating: /content/file/dataset/val/images/000000572194.jpg
#   inflating: /content/file/dataset/val/images/000000572348.jpg
#   inflating: /content/file/dataset/val/images/000000572467.jpg
#   inflating: /content/file/dataset/val/images/000000573360.jpg
#   inflating: /content/file/dataset/val/images/000000573873.jpg
#   inflating: /content/file/dataset/val/images/000000574370.jpg
#   inflating: /content/file/dataset/val/images/000000575305.jpg
#   inflating: /content/file/dataset/val/images/000000575526.jpg
#   inflating: /content/file/dataset/val/images/000000576188.jpg
#   inflating: /content/file/dataset/val/images/000000576518.jpg
#   inflating: /content/file/dataset/val/images/000000577817.jpg
#   inflating: /content/file/dataset/val/images/000000577843.jpg
#   inflating: /content/file/dataset/val/images/000000578770.jpg
#   inflating: /content/file/dataset/val/images/000000579404.jpg
#   inflating: /content/file/dataset/val/images/000000579419.jpg
#   inflating: /content/file/dataset/val/images/000000580651.jpg
#   inflating: /content/file/dataset/val/images/000000580695.jpg
#   inflating: /content/file/dataset/val/images/000000580933.jpg
#   inflating: /content/file/dataset/val/images/000000581096.jpg
#   inflating: /content/file/dataset/val/images/000000581297.jpg

# %% [markdown]
# **Xử lý dataset**

# %%
def create_text_data(folder_path):
  text_data = []

  captions_file = f'{folder_path}/captions.txt'
  with open(captions_file, 'r', encoding='UTF-8') as file:
    lines = file.readlines()

  for line in lines:
    image_path, caption = line.strip().split('\t')[:2]
    caption = "<start> " + caption.strip() + " <end>"
    text_data.append(caption)

  return text_data


text_data = []
for folder_path in ['/content/dataset/train',
                    '/content/dataset/val',
                    '/content/dataset/test']:
                    text_data += create_text_data(folder_path)

text_data[:5]
# Out:
# ['<start> Người đàn ông đang đánh tennis ngoài sân. <end>',
#  '<start> Một vận động viên tennis đang vung vợt đánh bóng. <end>',
#  '<start> Một cầu thủ tennis đang vung vợt tennis đỡ bóng. <end>',
#  '<start> Người đàn ông đang đứng ngoài biên cầm vợt sẵn sàng đỡ bóng. <end>',
#  '<start> Vận động viên tennis nam đang trong tư thế chuẩn bị đỡ bóng. <end>']

# %%
def create_caption_mapping(folder_path):
  caption_mapping = {}
  captions_file = f'{folder_path}/captions.txt'
  with open(captions_file, 'r', encoding='UTF-8') as file:
    lines = file.readlines()

  for line in lines:
    image_path, caption = line.strip().split('\t')[:2]
    caption = "<start> " + caption.strip() + " <end>"
    image_path = image_path[1:]  #----- remove "/" at beginning.
    if image_path not in caption_mapping:
      caption_mapping[image_path] = []
    caption_mapping[image_path].append(caption)


  for image_path in caption_mapping:
    if len(caption_mapping[image_path]) > 5:
      caption_mapping[image_path] = caption_mapping[image_path][:5]
    elif len(caption_mapping[image_path]) < 5:
      extra_captions = [caption_mapping[image_path][-1]] * (5 - len(caption_mapping[image_path]))
      caption_mapping[image_path] += extra_captions

  return caption_mapping


train_data = create_caption_mapping(folder_path='/content/dataset/train')
valid_data = create_caption_mapping(folder_path='/content/dataset/val')
test_data = create_caption_mapping(folder_path='/content/dataset/test')

# %%
train_data
# Out:
# {'dataset/train/images/000000157656.jpg': ['<start> Người đàn ông đang đánh tennis ngoài sân. <end>',
#   '<start> Một vận động viên tennis đang vung vợt đánh bóng. <end>',
#   '<start> Một cầu thủ tennis đang vung vợt tennis đỡ bóng. <end>',
#   '<start> Người đàn ông đang đứng ngoài biên cầm vợt sẵn sàng đỡ bóng. <end>',
#   '<start> Vận động viên tennis nam đang trong tư thế chuẩn bị đỡ bóng. <end>'],
#  'dataset/train/images/000000049860.jpg': ['<start> Một màn hình máy tính trắng đang đặt trên chiếc bàn gỗ. <end>',
#   '<start> Một cái bàn bừa bộn và có một quả bóng nảy màu vàng dưới đất. <end>',
#   '<start> Hình ảnh một quả bóng bự bên cạnh bàn gỗ. <end>',
#   '<start> Một quả bóng nảy vàng đang đặt dưới đất cạnh chiếc bàn gỗ. <end>',
#   '<start> Một quả bóng yoga vàng đang đặt dưới đất cạnh chiếc bàn. <end>'],
#  'dataset/train/images/000000053702.jpg': ['<start> Một người đàn ông đang chơi ném dĩa ngoài sân. <end>',
#   '<start> Một số người đàn ông đang chơi ném dĩa ngoài sân. <end>',
#   '<start> Những người đàn ông đang luyện tập ném dĩa. <end>',
#   '<start> Một số người đàn ông đang cùng nhau chơi ném dĩa. <end>',
#   '<start> Một số người đàn ông đang luyện tập ném dĩa cùng nhau. <end>'],
#  'dataset/train/images/000000487198.jpg': ['<start> Người phụ nữ đang cầm vợt tennis trên sân. <end>',
#   '<start> Vận động viên tennis nữ đang vung vợt đỡ bóng tennis. <end>',
#   '<start> Người phụ nữ đang vung vợt tennis chuẩn bị đánh bóng. <end>',
#   '<start> Người phụ nữ đang cầm vợt tennis thi đấu trên sân. <end>',
#   '<start> Người phụ nữ đang vung vợt về phía quả bóng tennis. <end>'],
#  'dataset/train/images/000000487204.jpg': ['<start> Người phụ nữ áo trắng đang vung vợt đánh bóng tennis. <end>',
#   '<start> Vận động viên tennis nữ đang cầm vợt đánh bóng trên sân. <end>',
#   '<start> Vận động viên tennis nữ đang vung vợt đỡ bóng. <end>',
#   '<start> Người phụ nữ đang đánh tennis trước nhiều người đang quan sát. <end>',
#   '<start> Người phụ nữ đang thi đấu tennis trước đông đảo khán giả. <end>'],
#  'dataset/train/images/000000487266.jpg': ['<start> Hình ảnh trắng đen một nhóm vận động viên tennis. <end>',
#   '<start> Một nhóm người đàn ông đang cầm vợt tennis chụp ảnh <end>',
#   '<start> Một nhóm vận động viên tennis đang chụp ảnh trên sân tennis. <end>',
#   '<start> Hình ảnh một nhóm vận động viên tennis. <end>',
#   '<start> Hình ảnh trắng đen một nhóm vận động viên tennis trên sân. <end>'],
#  'dataset/train/images/000000487607.jpg': ['<start> Người đàn ông và người phụ nữ đang đứng người vườn. <end>',
#   '<start> Hình ảnh người phụ nữ và người đàn ông cầm vợt tennis đứng ngoài vườn. <end>',
#   '<start> Hình ảnh trắng đen hai người cầm vợt tennis đứng ngoài vườn <end>',
#   '<start> Người phụ nữ và người đàn ông cầm vợt tennis tạo dáng chụp ảnh. <end>',
#   '<start> Hai người đang cầm vợt tennis đứng ngoài vườn chụp ảnh. <end>'],
#  'dataset/train/images/000000487630.jpg': ['<start> Người đàn ông cầm vợt với đánh bóng tennis. <end>',
#   '<start> Vận động viên tennis nam đang vươn vợt đánh bóng tennis. <end>',
#   '<start> Vận động viên tennis nam đang chạy tới vươn vợt đỡ bóng. <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt chạy trên sân. <end>',
#   '<start> Vận động viên tennis nam đang cố gắng đỡ bóng tennis. <end>'],
#  'dataset/train/images/000000487659.jpg': ['<start> Người đàn ông áo trắng đang cầm vợt tennis đứng trên sân. <end>',
#   '<start> Vận động viên tennis nam đang thi đấu trước đông đảo khán giả đang quan sát. <end>',
#   '<start> Một người đàn ông đang vung vợt đỡ bóng tennis. <end>',
#   '<start> Vận động viên tennis nam trong tư thế chuẩn bị đánh bóng. <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt chuẩn bị đỡ bóng thấp. <end>'],
#  'dataset/train/images/000000487788.jpg': ['<start> Người đàn ông và bé gái đang chơi bóng đá trên sân cỏ. <end>',
#   '<start> Người đàn ông đứng trên sân cỏ cùng quả bóng và bé gái. <end>',
#   '<start> Một bé gái đang chơi ném dĩa và người đàn ông quan sát. <end>',
#   '<start> Một bé gái đang chơi ném dĩa và người đàn ông đang chơi bóng. <end>',
#   '<start> Người đàn ông đang quan sát một bé gái chơi ném dĩa <end>'],
#  'dataset/train/images/000000487851.jpg': ['<start> Hình ảnh chiếc dù, con chó và một quả bóng cam. <end>',
#   '<start> Cây dù đang đè lên cổ một con chó đang chơi bóng. <end>',
#   '<start> Cây dù đang đè lên một con chó đang quan sát quả bóng. <end>',
#   '<start> Một con chó đang chơi bóng dưới một cây dù. <end>',
#   '<start> Một con chó đang chơi với quả bóng và cây dù. <end>'],
#  'dataset/train/images/000000487931.jpg': ['<start> Hình ảnh những cậu bé đang chơi bóng đá trên sân. <end>',
#   '<start> Một nhóm các cậu bé đang tranh giành quả bóng đá bên hàng rào. <end>',
#   '<start> Những cậu bé đang chơi bóng đá bên hàng rào. <end>',
#   '<start> Những đứa trẻ mặc đồ đá bóng đang tụ tập trên sân cỏ. <end>',
#   '<start> Những đứa trẻ đang cùng nhau đá bóng trên sân cỏ. <end>'],
#  'dataset/train/images/000000488500.jpg': ['<start> Người phụ nữ áo trắng đang cầm vợt và bóng tennis. <end>',
#   '<start> Vận động viên tennis nữ đang cầm vợt chuẩn bị giao bóng. <end>',
#   '<start> Vận động viên tennis nữ đang cầm vợt và bóng trên tay. <end>',
#   '<start> Một người phụ nữ đang chơi một trận tennis. <end>',
#   '<start> Một người phụ nữ đang trong tư thế chuẩn bị giao bóng. <end>'],
#  'dataset/train/images/000000488750.jpg': ['<start> Hình ảnh một người phụ nữ đang chơi một trận tennis. <end>',
#   '<start> Vận động viên tennis nữ đang bay đến đón bóng. <end>',
#   '<start> Người phụ nữ đang chạy trên sân đón bóng tennis. <end>',
#   '<start> Vận động viên tennis nữ đang thi đấu trên sân và những người đang quan sát. <end>',
#   '<start> Vận động viên tennis nữ đang chạy ngoài biên chuẩn bị đánh bóng tennis. <end>'],
#  'dataset/train/images/000000489023.jpg': ['<start> Một cầu thủ bóng đá đang nhảy lên đánh bóng bằng đầu. <end>',
#   '<start> Cầu thủ bóng đá nam đang nhảy lên tranh bóng. <end>',
#   '<start> Cầu thủ bóng đá nam đang tranh bóng trên không. <end>',
#   '<start> Cầu thủ bóng đá nam đang nhảy lên đón bóng. <end>',
#   '<start> Cầu thủ bóng đá nam đang bật lên đánh đầu. <end>'],
#  'dataset/train/images/000000489799.jpg': ['<start> Hình ảnh ba người đàn ông đang chơi một trận bóng đá. <end>',
#   '<start> Những người đàn ông đang chơi bóng đá trên sân. <end>',
#   '<start> Một thủ môn đang phát bóng lên và một cầu thủ đang chạy trên sân. <end>',
#   '<start> Hình ảnh một thủ môn đang ném bóng về phía trước. <end>',
#   '<start> Hai người đàn ông đang chơi bóng đá và một trọng tài đang quan sát. <end>'],
#  'dataset/train/images/000000489818.jpg': ['<start> Một bé gái đang đeo găng tay bóng chày cầm quả bóng chày. <end>',
#   '<start> Một bé gái đang dùng găng tay bóng chày che mặt. <end>',
#   '<start> Người phụ nữ đang che mặt bằng găng tay bóng chày và quả bóng. <end>',
#   '<start> Người phụ nữ đeo găng tay bóng chày và cầm bóng chuẩn bị phát bóng. <end>',
#   '<start> Người phụ nữ cầm quả bóng chày chuẩn bị phát bóng. <end>'],
#  'dataset/train/images/000000490126.jpg': ['<start> Hình ảnh một trận tennis đang diễn ra. <end>',
#   '<start> Một trận tennis đang diễn ra với nhiều khán giả đang quan sát. <end>',
#   '<start> Vận động viên tennis đang nhảy lên đỡ bóng trong một trận tennis. <end>',
#   '<start> Vận động viên tennis đang giao bóng trong một trận tennis. <end>',
#   '<start> Hai người đang chơi tennis trên sân trước đông đảo khán giả quan sát. <end>'],
#  'dataset/train/images/000000491107.jpg': ['<start> Hai đứa trẻ đang chơi trên chiếc phao. <end>',
#   '<start> Hai đứa trẻ đang ngồi trên cái phao trong nhà banh. <end>',
#   '<start> Hai đứa trẻ đang đùa giỡn trên ghế phao trong nhà banh. <end>',
#   '<start> Hai đứa trẻ đang ngồi trên ghế phao chơi đùa. <end>',
#   '<start> Hai đứa trẻ đang chơi cùng nhau trên chiếc ghế phao. <end>'],
#  'dataset/train/images/000000492723.jpg': ['<start> Con hải cẩu trắng đang chơi với hai quả bóng dưới nước. <end>',
#   '<start> Một con hải cẩu đang chơi với quả bóng xanh và vàng. <end>',
#   '<start> Một con hải cầu đang ngậm dây chơi cùng quả bóng. <end>',
#   '<start> Một con hải cẩu đang bơi dưới nước cùng quả bóng. <end>',
#   '<start> Hình ảnh con hải cẩu đang chơi với 2 quả bóng phao trên mặt nước. <end>'],
#  'dataset/train/images/000000493067.jpg': ['<start> Một côn hải cẩu đang chơi với những quả bóng trên mặt nước. <end>',
#   '<start> Một con hải cẩu đang bơi trên nước cùng những quả bóng. <end>',
#   '<start> Một con hải cẩu đang ngậm dây chơi với những quả bóng. <end>',
#   '<start> Một con hải cẩu đang chơi với bóng trên mặt nước. <end>',
#   '<start> Con hải cẩu đang chơi với những quả phao miệng ngậm dây. <end>'],
#  'dataset/train/images/000000493293.jpg': ['<start> Hình ảnh người đàn ông đang lướt ván trên biển. <end>',
#   '<start> Người đàn ông đang lướt ván trên biển cùng quả bóng. <end>',
#   '<start> Người đàn ông đang lướt ván chơi với một quả bóng. <end>',
#   '<start> Người đàn ông cầm dây lướt ván trên biển. <end>',
#   '<start> Người đang ông đang lướt ván trên mặt nước. <end>'],
#  'dataset/train/images/000000498940.jpg': ['<start> Những người đàn ông đang chơi đá bóng trên sân đá. <end>',
#   '<start> Những người lính đang cùng nhau chơi đá bóng. <end>',
#   '<start> Những người lính và những người đàn ông đang cùng nhau đá bóng. <end>',
#   '<start> Người lính và người đàn ông đang tranh bóng ngoài sân. <end>',
#   '<start> Một người lính đang đá một quả bóng. <end>'],
#  'dataset/train/images/000000499168.jpg': ['<start> Hai con ngựa con đang trong chuồn cùng quả bóng. <end>',
#   '<start> Hình ảnh hai con ngựa con ngoài vườn cùng ảu bóng đỏ. <end>',
#   '<start> Hai con ngựa con đang đứng trong rào. <end>',
#   '<start> Hai con ngựa con đang nhìn quả bóng đỏ. <end>',
#   '<start> Hai con ngựa con đang đứng cùng nhau trên sân cát. <end>'],
#  'dataset/train/images/000000515056.jpg': ['<start> Ba người đang cầm dụng cự tennis băng qua đường. <end>',
#   '<start> Người đàn ông cầm giỏ bóng tennis cùng hai người phụ nữ băng qua đường. <end>',
#   '<start> Ba người đang dắt tay nhau băng qua đường. <end>',
#   '<start> Ba người đang cùng nhau qua đường cầm dụng cụ tennis. <end>',
#   '<start> Người đàn ông cùng hai người phụ nữ đang băng qua đường. <end>'],
#  'dataset/train/images/000000517931.jpg': ['<start> Những người đàn ông đang ngồi trên băng ghế chờ đợi. <end>',
#   '<start> Các cầu thủ bóng rổ đang ngồi trên băng ghế chờ đợi. <end>',
#   '<start> Những cầu thủ bóng rổ nam đang ngồi trên ghế. <end>',
#   '<start> Những người đàn ông đang cùng nhau ngồi trên băng ghế. <end>',
#   '<start> Những cầu thủ bóng rổ nam đang ngồi trên ghế quan sát. <end>'],
#  'dataset/train/images/000000520585.jpg': ['<start> Những người đàn ông đang ngồi quan sát. <end>',
#   '<start> Một người đàn ông đang ngồi trên ghế cầm quả bóng trên tay. <end>',
#   '<start> Một người đang ông đang ngồi quan sát tay cầm quả bóng. <end>',
#   '<start> Một người đàn ông ngồi cầm bóng và một người quan sát. <end>',
#   '<start> Một số người đang ngồi quan sát trong phòng. <end>'],
#  'dataset/train/images/000000532769.jpg': ['<start> Một chú chó đang chơi cùng quả bóng tennis. <end>',
#   '<start> Một chú chó đang ngậm quả bóng tennis. <end>',
#   '<start> Một chú tró leo trèo ngậm quả bóng tennis. <end>',
#   '<start> Một chú chó đang ngậm bóng tennis leo trèo. <end>',
#   '<start> Một chú chó đang chơi với quả bóng tennis trong miệng. <end>'],
#  'dataset/train/images/000000534734.jpg': ['<start> Cảnh quan một công viên với nhiều người đang chơi tennis. <end>',
#   '<start> Một caaju bé đang cầm vợt tennis chơi  ngoài sân. <end>',
#   '<start> Một số người đang chơi tennis trên sân gạch. <end>',
#   '<start> Ngoài sân có một số lưới tennis đang giăng sẵn. <end>',
#   '<start> Một số người đang chơi tennis ngoài sân. <end>'],
#  'dataset/train/images/000000540092.jpg': ['<start> Hai con chó đang chơi với dĩa trên sân cỏ. <end>',
#   '<start> Một con chó đang nằm nghĩ và một con chó đang ngậm dĩa. <end>',
#   '<start> Một con chó đang chơi với con chó khác với dĩa. <end>',
#   '<start> Hai con chó đang chơi dĩa cùng nhau. <end>',
#   '<start> Một con chó đang ngậm dĩa chơi cùng con chó khác. <end>'],
#  'dataset/train/images/000000549915.jpg': ['<start> Người đàn ông áo trắng đang chơi tennis trên sân. <end>',
#   '<start> Vận động viên tennis nam đang thi đấu trên sân. <end>',
#   '<start> Vận động viên tennis nam cầm vợt chạy tới vị trí bóng. <end>',
#   '<start> Vận động viên tennis nam chạy tới đỡ bóng thấp. <end>',
#   '<start> Vận động viên tennis nam đang thi đấu một trận tennis. <end>'],
#  'dataset/train/images/000000550955.jpg': ['<start> Hình ảnh người đàn ông đang trong tư thế đỡ bóng tennis. <end>',
#   '<start> Vận động viên tennis nam đang vung vợt đỡ bóng tennis. <end>',
#   '<start> Vận động viên tennis nam đang thi đấu trước nhiều người đang quan sát. <end>',
#   '<start> Người đàn ông đang vung vợt tennis đỡ bóng tennis. <end>',
#   '<start> Người đàn ông đang vung vợt tennis đỡ bóng thấp. <end>'],
#  'dataset/train/images/000000551001.jpg': ['<start> Hình ảnh bốn người phụ nữ đang cầm vợt tennis đứng trên sân. <end>',
#   '<start> Bốn người phụ nữ cầm vợt và bóng tennis đứng cạnh lưới. <end>',
#   '<start> Bốn người phụ nữ cầm vợt tennis tạo dáng chụp hình. <end>',
#   '<start> Bốn người phụ nữ đang đứng cùng nhau trên sân tennis. <end>',
#   '<start> Một số người phụ nữ đang cầm vợt tennis đứng trên sân tennis chụp hình. <end>'],
#  'dataset/train/images/000000551372.jpg': ['<start> Hình ảnh trận bóng chày đang diễn ra với một vận động viên đang vung gậy đỡ bóng. <end>',
#   '<start> Cầu thủ bóng chày đang vung gậy bóng chày đỡ bóng thấp. <end>',
#   '<start> Cầu thủ bóng chày đang chuẩn bị đỡ bóng trước nhiều người quan sát. <end>',
#   '<start> Cầu thủ bóng chày cầm gậy bóng chày bước tới đánh bóng. <end>',
#   '<start> Cầu thủ bóng chày đang trong tư thế chuẩn bị đỡ bóng. <end>'],
#  'dataset/train/images/000000551752.jpg': ['<start> Hình ảnh người phụ nữ áo xanh dương đang chơi tennis. <end>',
#   '<start> Người phụ nữ đang cầm vợt tennis chuẩn bị đỡ bóng. <end>',
#   '<start> Người phụ nữ trong tư thế chuẩn bị đánh bóng tennis. <end>',
#   '<start> Người phụ nữ đang cầm vợt tennis chuẩn bị đỡ bóng thấp. <end>',
#   '<start> Hình ảnh người phụ nữ cầm vợt tennis chuẩn bị đón bóng. <end>'],
#  'dataset/train/images/000000552254.jpg': ['<start> Hình ảnh người phụ nữ đang cầm vợt đánh bóng tennis. <end>',
#   '<start> Người phụ nữ đang vung vợt đỡ bóng tennis. <end>',
#   '<start> Người phụ nữ đang chạy tới vung vợt đánh bóng tennis.q <end>',
#   '<start> Vận động viên tennis nữ đang vướng người vung vợt đỡ bóng. <end>',
#   '<start> Người phụ nữ đang vướng người vung vợt đánh trả bóng tennis. <end>'],
#  'dataset/train/images/000000552304.jpg': ['<start> Hình ảnh một trận bóng chày đang diễn ra. <end>',
#   '<start> Trận bóng chày đang diễn ra với một cầu thủ đứng trên sân nhà chuẩn bị đánh bóng. <end>',
#   '<start> Cầu thủ đánh bóng cầm gậy bóng chày chuẩn bị đỡ bóng. <end>',
#   '<start> Hình ảnh trọng tài quan sát trận bóng chày đang diễn ra. <end>',
#   '<start> Trọng tài đang quan sát các cầu thủ bóng chày thi đấu. <end>'],
#  'dataset/train/images/000000553760.jpg': ['<start> Một số người đang chơi bóng chày ngoài sân. <end>',
#   '<start> Những đứa trẻ đang thi đấu bóng chày trước trọng tài đang quan sát. <end>',
#   '<start> Đứa trẻ áo đỏ đang cầm gậy bóng chày chuẩn bị đỡ bóng <end>',
#   '<start> Một đứa trẻ cầm gậy bóng chày đón bóng đang gbay tới. <end>',
#   '<start> Người đàn ông đang quan sát ba đứa trẻ cùng chơi bóng chày. <end>'],
#  'dataset/train/images/000000554664.jpg': ['<start> Một người đàn ông đang đứng trên sân bóng chày thi đấu. <end>',
#   '<start> Hình ảnh một cầu thủ bóng chày đang ném bóng. <end>',
#   '<start> Một cầu thủ bóng chày đang ném bóng về phía trước. <end>',
#   '<start> Một cầu thủ bóng chày đang ném bóng trong trận đấu. <end>',
#   '<start> Một cầu thủ bóng chày đang bước tới ném bóng. <end>'],
#  'dataset/train/images/000000554886.jpg': ['<start> Hai người phụ nữ đang thi đấu bóng chày. <end>',
#   '<start> Trận bóng chày đang diễn ra với một người đang nhặt bóng và một người đang chạy. <end>',
#   '<start> Hai người phụ nữ đang cùng nhau chơi bóng chày trên sân <end>',
#   '<start> Một người phụ nữ nhặt quả bóng chày và một người phụ nữ chạy. <end>',
#   '<start> Hai người phụ nữ đang chơi bóng chày trước nhiều người quan sát. <end>'],
#  'dataset/train/images/000000554943.jpg': ['<start> Hình ảnh một số người đang chơi bóng chày. <end>',
#   '<start> Các cầu thủ bóng chày đang thi đấu trên sân. <end>',
#   '<start> Một cầu thủ bóng chày đang chuẩn bị ném bóng về phía trước. <end>',
#   '<start> Một cầu thủ bóng chày đang ném bóng về phía đồng đối thủ. <end>',
#   '<start> Một cầu thủ bóng chày đang trong tư thế ném bóng. <end>'],
#  'dataset/train/images/000000561901.jpg': ['<start> Một bé gái đang chơi ngoài bãi cỏ. <end>',
#   '<start> Một số người đang thả diều ngoài bãi cỏ. <end>',
#   '<start> Một số người đang thả diều và một bé gái đang chơi bóng tennis. <end>',
#   '<start> Một bé gái đang cầm bóng tạo dáng trên bãi cỏ. <end>',
#   '<start> Nhiều người đang cùng nhau thả diều trên bãi cỏ. <end>'],
#  'dataset/train/images/000000565522.jpg': ['<start> Một con voi đang chơi với quả bóng đá <end>',
#   '<start> Một con voi đang đạp lên quả bóng đá. <end>',
#   '<start> Con với đang đá quả bóng màu vàng trên đất. <end>',
#   '<start> Con voi đang chơi với quả bóng bằng chân. <end>',
#   '<start> Con voi đang dùng vòi và chân dẫn bóng. <end>'],
#  'dataset/train/images/000000566324.jpg': ['<start> Hình ảnh một căn phòng có hai màn hình và cái giường. <end>',
#   '<start> Màn hình máy tính đang đặt cạnh tivi. <end>',
#   '<start> Một phòng ngủ với giường, bàn làm việc và các màn hình. <end>',
#   '<start> Một phòng ngủ nhỏ với không gian làm việc và giường ngủ. <end>',
#   '<start> Trong phòng ngủ có tivi, màn hình, quạt, và giường ngủ. <end>'],
#  'dataset/train/images/000000566975.jpg': ['<start> Một cửa hàng bán dù và các dụng cụ thể thao. <end>',
#   '<start> HÌnh ảnh một cửa hàng bán dù, các trái bóng và vợt tennis nhựa. <end>',
#   '<start> Hình ảnh một cửa hàng bán bóng, những cái ô và vợt. <end>',
#   '<start> Một cửa hàng bán bóng đồ chơi, ô và vợ <end>',
#   '<start> Một cửa hàng bán những cái dù có màu sắc sặc sỡ. <end>'],
#  'dataset/train/images/000000571219.jpg': ['<start> Hình ảnh hai von voi đang chơi bóng. <end>',
#   '<start> Hai con voi đang chơi cùng quả bóng dưới trời nắng. <end>',
#   '<start> Hai con voi đang đứng cạnh nhau cùng quả bóng. <end>',
#   '<start> Hai con voi đang đứng sát nhau trên sân cát. <end>',
#   '<start> Hai con voi đang chơi cùng nhau trên sân cát. <end>'],
#  'dataset/train/images/000000574236.jpg': ['<start> Người đàn ông đang thả diều ngoài bãi cỏ. <end>',
#   '<start> Có một người đứng trên bãi cỏ thả diều. <end>',
#   '<start> Có một người đang đứng trên bãi cỏ ngắm diều. <end>',
#   '<start> Một thanh niên đang thả diều trên bãi có. <end>',
#   '<start> Một người đang thả diều trên bãi cỏ. <end>'],
#  'dataset/train/images/000000575594.jpg': ['<start> Hai con gấu bông đồ chơi trong túi ni nhựa. <end>',
#   '<start> Một con gấu bông ôm bóng và một con gấu bông cầu hoa. <end>',
#   '<start> Hình ảnh một số gấu bông đang được bày bán. <end>',
#   '<start> Hình ảnh một con gấu bông cầm bóng cạnh gấu bống cầu hoa. <end>',
#   '<start> Hình ảnh hai con gấu bống trong túi nhựa đang được trưng bày. <end>'],
#  'dataset/train/images/000000295241.jpg': ['<start> Hình ảnh của hai người đàn ông đang chơi bóng đá trên sân cỏ . <end>',
#   '<start> Phía dưới chân hai người đàn ông là quả bóng màu vàng . <end>',
#   '<start> Phía sau hai người đàn ông đang chơi bóng có một người đàn ông áo đó đang đi bộ . <end>',
#   '<start> Người đàn ông áo đỏ đang tranh bóng của người đàn ông áo vàng . <end>',
#   '<start> Phía sau sân bóng là hàng rào màu trắng . <end>'],
#  'dataset/train/images/000000318937.jpg': ['<start> Hai vận động viên tennis đang đứng chờ đối thủ phát bóng . <end>',
#   '<start> Hai người đồng đội tennis đang thảo luận với nhau . <end>',
#   '<start> Một số người đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis đang đưa bóng cho động đội . <end>',
#   '<start> Vận đồng viên tennis cầm vợt đang nhận bóng từ đồng đội . <end>'],
#  'dataset/train/images/000000566448.jpg': ['<start> Một người phụ nữ đang chuẩn bị đánh quả bóng tennis . <end>',
#   '<start> Một người phụ nữ đang xoay người để đánh quả bóng tennis . <end>',
#   '<start> Một nữ vận động viên tennis đang chuẩn bị đánh bóng . <end>',
#   '<start> Một người phụ nữ đang vung vợt để đánh quả bóng tennis . <end>',
#   '<start> Một nữ vận động viên tennis đang xoay người để đánh bóng . <end>'],
#  'dataset/train/images/000000274509.jpg': ['<start> Một số người đang ngồi quan sát trận bóng chày trên tivi . <end>',
#   '<start> Mọi người đang cùng nhau theo dõi trận bóng chày trên tivi . <end>',
#   '<start> Mọi người đang cùng nhau xem bóng chày trên tivi . <end>',
#   '<start> Mọi người đang ngồi trong phòng khách xem bóng chày trên tivi . <end>',
#   '<start> Mọi người đang cùng nhau ngồi trong phòng khách xem bóng chày trên tivi . <end>'],
#  'dataset/train/images/000000211163.jpg': ['<start> Cầu thủ bóng chày nam đang đứng khum người trên sân quan sát . <end>',
#   '<start> Người đàn ông đang chơi bóng chày trên sân . <end>',
#   '<start> Cầu thủ bóng chày đang đứng khum người chuẩn bị ném bóng . <end>',
#   '<start> Cầu thủ bóng chày đang thi đấu trên sân . <end>',
#   '<start> Cầu thủ ném bóng đang đứng trên sân quan sát . <end>'],
#  'dataset/train/images/000000329394.jpg': ['<start> Vận động viên tennis đang cầm vợt nhảy tới đỡ bóng . <end>',
#   '<start> Vận động viên tennis đang bước dài tới đánh bóng . <end>',
#   '<start> Người đàn ông áo xanh dương đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis chuyên nghiejp đang thi đấu trên sân . <end>',
#   '<start> Người đàn ông áo xanh dương đang vung vợt tennis về phía bóng . <end>'],
#  'dataset/train/images/000000413382.jpg': ['<start> Cầu thủ bắt bóng và trọng tài đang theo dõi cú đánh bóng của cầu thủ đánh bóng . <end>',
#   '<start> Một cầu thủ đánh bóng đang xoay người để đánh bóng . <end>',
#   '<start> Một người đàn ông với cái gậy đang xoay người ở gôn . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở trên sân . <end>',
#   '<start> Các cầu thủ bóng chày đang thi đấu ở trên sân . <end>'],
#  'dataset/train/images/000000448463.jpg': ['<start> Một nam vận động viên tennis đang chuẩn bị đánh bóng . <end>',
#   '<start> Một người đàn ông đang ngửa người để đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang đưa vợt ra sau để đánh quả bóng tennis . <end>',
#   '<start> Một nam vận động viên tennis đang ngửa người để đánh bóng . <end>',
#   '<start> Một người đàn ông đang chuẩn bị đánh quả bóng tennis . <end>'],
#  'dataset/train/images/000000186606.jpg': ['<start> Một cô bé đang cầm quả bóng bằng găng tay của mình . <end>',
#   '<start> Thầy giáo thể dục đang theo dõi trận thi đấu bóng chày của học sinh . <end>',
#   '<start> Thầy giáo thể dục đang theo dõi buổi luyện tập bóng chày của học sinh . <end>',
#   '<start> Một trận thi đấu bóng chày ở trường học đang diễn ra . <end>',
#   '<start> Giải thi đấu bóng chày được trường tổ chức cho học sinh đang diễn ra . <end>'],
#  'dataset/train/images/000000221609.jpg': ['<start> Hai vận động viên tennis đang đấu đôi trên sân . <end>',
#   '<start> Hai người đàn ông áo trắng đang chơi tennis trên sân . <end>',
#   '<start> Hai vận động viên tennis đang cùng nhau thi đấu trên sân . <end>',
#   '<start> Hai người đàn ông đang chơi tennis chung đội trên sân . <end>',
#   '<start> Hai vận động viên tennis đang thi đấu chung đội trên sân . <end>'],
#  'dataset/train/images/000000044178.jpg': ['<start> Một trận thi đấu bóng chày nam đang diễn ra ở trên sân . <end>',
#   '<start> Một cầu thủ áo đỏ đang nghiêng người để đánh quả bóng . <end>',
#   '<start> Khán giả đang theo dõi một trận thi đấu bóng chày nam ở trên sân . <end>',
#   '<start> Một cầu thủ đánh bóng đang dùng gậy của mình để đánh bóng . <end>',
#   '<start> Trọng tài và cầu thủ áo xám đang theo dõi động tác đánh bóng của cầu thủ áo đỏ . <end>'],
#  'dataset/train/images/000000425208.jpg': ['<start> Một nam vận động viên tennis đang nhảy lên để đánh bóng . <end>',
#   '<start> Một người đàn ông đang dùng vợt để đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang nhảy lên để đánh quả bóng tennis . <end>',
#   '<start> Một nam vận động viên tennis đang vươn người để đánh bóng . <end>',
#   '<start> Một người đàn ông đang vươn người để đánh quả bóng tennis . <end>'],
#  'dataset/train/images/000000521663.jpg': ['<start> Các cầu thủ bóng chày đang thi đấu trên sân trước đông đảo khán giả . <end>',
#   '<start> Cầu thủ bóng chày đang cầm gậy thi đấu trên sân . <end>',
#   '<start> Cầu thủ đánh bóng đứng trước cầu thủ bắt bóng cầm gậy sẵn sàng đỡ bóng . <end>',
#   '<start> Hình ảnh trận bóng chày đang diễn ra trước đông đảo khán giả quan sát . <end>',
#   '<start> Cầu thủ bóng chày đang vung gậy đánh trả bóng . <end>'],
#  'dataset/train/images/000000534876.jpg': ['<start> Đứa trẻ áo đen đang chơi bóng chày trên sân . <end>',
#   '<start> Đứa trẻ đang cầm gậy bóng chày chơi bóng chày trên sân . <end>',
#   '<start> Đứa trẻ đang vung gậy bóng chày đánh bóng . <end>',
#   '<start> Đứa tẻ đang đỡ bóng bằng gậy bóng chày . <end>',
#   '<start> Đứa trẻ đang vung gậy bóng chày đỡ bóng ngoài sân . <end>'],
#  'dataset/train/images/000000471762.jpg': ['<start> Thanh niên trẻ đang cầm vợt tennis đỡ bóng cao . <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt đánh tennis trên sân . <end>',
#   '<start> Người đàn ông áo trắng đang chơi tennis trên sân . <end>',
#   '<start> Một người đang giơ vợt tennis lên cao đỡ bóng . <end>',
#   '<start> Thanh niên trẻ áo trắng đang vung vợt tennis đánh trả bóng . <end>'],
#  'dataset/train/images/000000349282.jpg': ['<start> Người phụ nữ mặc váy trắng đen đang cầm vợt tennis đứng trên sân . <end>',
#   '<start> Người phụ nữ đeo kính đen đang cầm vợt chơi tennis . <end>',
#   '<start> Người phụ nữ đeo kính đen đang chơi tennis ngoài sân . <end>',
#   '<start> Người phụ nữ đang vung vợt tennis về phía bóng . <end>',
#   '<start> Người phụ nữ đang cầm vợt tennis đứng trên sân đánh bóng . <end>'],
#  'dataset/train/images/000000188445.jpg': ['<start> Cầu thủ bắt bóng đang chuẩn bị bắt bóng bằng găng tay . <end>',
#   '<start> Một người đàn ông đang giơ gậy lên để chuẩn bị đánh quả bóng chày . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở trên sân . <end>',
#   '<start> Cầu thủ đánh bóng đang giơ gậy lên để chuẩn bị đánh bóng . <end>',
#   '<start> Các cầu thủ bóng chày đang quan sát đường bay của quả bóng . <end>'],
#  'dataset/train/images/000000540681.jpg': ['<start> Vận động viên tennis nam cầm vợt thi đấu trên sân . <end>',
#   '<start> Vận động viên tennis nam với người đỡ bóng bằng vợt . <end>',
#   '<start> Người đàn ông áo trắng đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt chạy tới vị trí bóng . <end>',
#   '<start> Vận động viên tennis nam với người sang phải đỡ bóng . <end>'],
#  'dataset/train/images/000000332013.jpg': ['<start> Trọng tài đang đứng trên sân quan sát trận đấu bóng chày . <end>',
#   '<start> Một số người đang thi đấu bóng chày trên sân . <end>',
#   '<start> Cầu thủ bóng chày đang cầm gậy chuẩn bị đỡ bóng . <end>',
#   '<start> Cầu thủ bóng chày vừa ném bóng về phía trước . <end>',
#   '<start> Cầu thủ ném bóng vừa thực hiện cú ném bóng . <end>'],
#  'dataset/train/images/000000070913.jpg': ['<start> Một người đàn ông đang vung vợt để đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang nghiêng người để đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang chơi tennis ở trên sân . <end>',
#   '<start> Một người đàn ông đang dùng vợt để đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang luyện tập tennis ở trên sân . <end>'],
#  'dataset/train/images/000000430341.jpg': ['<start> Một người đàn ông đang cầm cái vợt tennis và đứng cạnh hai quả bóng tennis . <end>',
#   '<start> Một người đang thả cái vợt tennis xuống đất . <end>',
#   '<start> Một người đàn ông đang thả cái vợt tennis xuống đất . <end>',
#   '<start> Một người phụ nữ đang thả cái vợt tennis xuống đất . <end>',
#   '<start> Một người phụ nữ đang cầm cái vợt tennis và đứng cạnh hai quả bóng tennis . <end>'],
#  'dataset/train/images/000000112604.jpg': ['<start> Một nữ vận động viên tennis đang xoạc chân để đánh bóng . <end>',
#   '<start> Một nữ vận động viên tennis đang di chuyển để đánh bóng . <end>',
#   '<start> Một người phụ nữ đang chuẩn bị đánh quả bóng tennis . <end>',
#   '<start> Một người phụ nữ đang di chuyển để đánh quả bóng tennis . <end>',
#   '<start> Một người phụ nữ đang xoạc chân để đánh quả bóng tennis . <end>'],
#  'dataset/train/images/000000367872.jpg': ['<start> Cầu thủ đánh bóng bóng đang cầm gậy đỡ bóng trước đám đông . <end>',
#   '<start> Cầu thủ bóng chày đang bước tới vung gậy đánh bóng , <end>',
#   '<start> Cầu thủ bóng chày đang cầm gậy thi đấu trên sân với đám đông đang quan sát . <end>',
#   '<start> Người đàn ông áo đen đang chơi bóng chày trên sân dưới trời nắng . <end>',
#   '<start> Cầu thủ bóng chày đang cầm gậy bước tới đỡ bóng . <end>'],
#  'dataset/train/images/000000504091.jpg': ['<start> Người đàn ông cầm vợt tennis thảy bóng lên giao bóng . <end>',
#   '<start> Người đàn ông cầm vợt tennis và bóng tennis trên sân . <end>',
#   '<start> Người đàn ông đeo kính đen đang cầm vợt tennis thảy bóng lên cao . <end>',
#   '<start> Người đàn ông cầm vợt tennis chuẩn bị giao bóng . <end>',
#   '<start> Người đàn ông áo cam đang chơi tennis trên sân . <end>'],
#  'dataset/train/images/000000426807.jpg': ['<start> Nữ vận động viên váy xanh đang đưa vợt ra sau trong khi nữ vận động viên áo xám đang chuẩn bị phát bóng . <end>',
#   '<start> Hai nữ vận động viên tennis đang luyện tập ở trên sân . <end>',
#   '<start> Một người phụ áo xám đang cầm vợt tennis và bước đi ở trên sân . <end>',
#   '<start> Một người phụ nữ váy xanh dương đang đưa vợt tennis ra sau lưng ở trên sân . <end>',
#   '<start> Hai người phụ nữ đang chơi tennis ở trên sân . <end>'],
#  'dataset/train/images/000000129568.jpg': ['<start> Một nam vận động viên tennis đang chuẩn bị đánh bóng . <end>',
#   '<start> Một nam vận động viên tennis đang xoay người để đánh bóng . <end>',
#   '<start> Một người đàn ông đang chuẩn bị đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang xoay người để đánh quả bóng tennis . <end>',
#   '<start> Khán giả đang theo dõi chuyển động của nam vận động viên tennis . <end>'],
#  'dataset/train/images/000000338164.jpg': ['<start> Người đàn ông áo trắng đang cầm vợt tennis chuẩn bị giao bóng . <end>',
#   '<start> Người đàn ông áo trắng đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Vận động viên tennis đang cầm vợt đứng ngoài biên phát bóng . <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt và bóng tennis . <end>'],
#  'dataset/train/images/000000309916.jpg': ['<start> Cậu bé đang giơ chân chuẩn bị sút bóng . <end>',
#   '<start> Thanh niên trẻ đang chơi với quả bóng màu đỏ trên sân . <end>',
#   '<start> Thanh niên trẻ đang kiểm soát bóng trên không . <end>',
#   '<start> Cậu bé áo xanh lá đang thực hiện cú sút bóng . <end>',
#   '<start> Thanh niên trẻ đang chơi bóng đá trên sân . <end>'],
#  'dataset/train/images/000000284064.jpg': ['<start> Người đàn ông đang vung vợt tennis đánh trả bóng . <end>',
#   '<start> Người đàn ông đang cầm vợt tennis đỡ bóng cao . <end>',
#   '<start> Người đàn ông đang giơ vợt tennis lên cao đánh trả bóng . <end>',
#   '<start> Người đàn ông đang cầm vợt tennis đánh tennis trên sân . <end>',
#   '<start> Người đàn ông áo xám đang chơi tennis trên sân . <end>'],
#  'dataset/train/images/000000065383.jpg': ['<start> Những người đàn ông đang chơi bóng đá ở trên sân . <end>',
#   '<start> Những người đàn ông đang chơi bóng đá ở cạnh những chiếc ô tô . <end>',
#   '<start> Người đàn ông áo trắng đang dắt bóng ở trên sân . <end>',
#   '<start> Người đàn ông áo trắng đang chạy theo quả bóng ở trên sân . <end>',
#   '<start> Những người đàn ông đang luyện tập bóng đá ở trên sân . <end>'],
#  'dataset/train/images/000000375989.jpg': ['<start> Người đàn ông đang đứng trên sân bóng chày ném bóng . <end>',
#   '<start> Người đàn ông đang ném bóng cho cầu thủ bóng chày áo đỏ . <end>',
#   '<start> Cầu thủ bóng chày áo đỏ đang bắt bóng từ tay người đàn ông áo đen . <end>',
#   '<start> Người hâm mộ áo đen đang ném bóng cho cầu thủ bóng chày . <end>',
#   '<start> Người đàn ông đang ném bóng chuyền cho cầu thủ bóng chày . <end>'],
#  'dataset/train/images/000000323930.jpg': ['<start> Đứa trẻ đang đưa gậy bóng chày ra phía sau chuẩn bị đỡ bóng . <end>',
#   '<start> Người đàn ông đang chơi bóng chày cùng đứa trẻ trên sân . <end>',
#   '<start> Người đàn ông mặc áo đen đang dạy đứa trẻ chơi bóng chày . <end>',
#   '<start> Người đàn ông đang đeo găng tay bóng chày đứng ngoài sân . <end>',
#   '<start> Cậu bé đang cầm gậy bóng chày màu xanh dương đứng trên sân . <end>'],
#  'dataset/train/images/000000572081.jpg': ['<start> Một nam vận động viên tennis đang giơ vợt lên để chuẩn bị đánh bóng . <end>',
#   '<start> Trọng tài đang theo dõi chuyển động của nma vận động viên tennis . <end>',
#   '<start> Một người đàn ông đang giơ vợt lên để chuẩn bị đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang chuẩn bị đánh quả bóng tennis . <end>',
#   '<start> Một nam vận động viên tennis đang chuẩn bị đánh bóng . <end>'],
#  'dataset/train/images/000000338207.jpg': ['<start> Vận động viên bóng chày áo cam đang thảo luận với trọng tài trên sân . <end>',
#   '<start> Vận động viên bóng chày đang đứng kế bên trọng tài trên sân . <end>',
#   '<start> Khán giả đang ngồi phía trên quan sát trận bóng chày đang diễn ra . <end>',
#   '<start> Cầu thủ bóng chày đang đứng trên sân nói chuyện với trọng tài . <end>',
#   '<start> Một số người đang chơi bóng chày trên sân . <end>'],
#  'dataset/train/images/000000529515.jpg': ['<start> Cầu thủ bóng chày đứng trên sân nhà cầm gậy chuẩn bị đỡ bóng . <end>',
#   '<start> Cầu thủ đánh bóng đứng trước cầu thủ bắt bóng cầm gậy chuẩn bị đánh bóng . <end>',
#   '<start> Người đàn ông áo trắng đang chơi bóng chày trên sân . <end>',
#   '<start> Trận bóng chày đang diễn ra với một cầu thủ vung gậy đỡ bóng . <end>',
#   '<start> Cầu thủ bóng chày đang cầm gậy thi đấu trên sân . <end>'],
#  'dataset/train/images/000000351610.jpg': ['<start> Người đàn ông cởi trần đang cầm vợt tennis đứng trên sân . <end>',
#   '<start> Người đàn ông đang cầm vợt tennis thi đấu trên sân . <end>',
#   '<start> Người đàn ông cầm vợt tennis đang chuẩn bị đỡ bóng . <end>',
#   '<start> Người đàn ông đang cầm vợt đứng ngoài biên đánh bóng . <end>',
#   '<start> Người đàn ông đang đứng ngoài biên vung vợt tennis về phía bóng . <end>'],
#  'dataset/train/images/000000459665.jpg': ['<start> Những cậu bé đang chơi bóng chày ở trên sân vào ngày âm u . <end>',
#   '<start> Một cầu thủ bắt bóng đang ngồi trên vũng nước và đưa tay ra để bắt bóng . <end>',
#   '<start> Ở cạnh vũng nước , một cậu bé đang giơ gậy bóng chày lên cao . <end>',
#   '<start> Một cậu bé đang ngồi trên vũng nước và đưa tay ra để bắt quả bóng chày . <end>',
#   '<start> Những cậu bé đang chơi bóng chày ở trên sân vào lúc trời âm u . <end>'],
#  'dataset/train/images/000000435718.jpg': ['<start> Một nam vận động viên tennis đang chuẩn bị phát bóng . <end>',
#   '<start> Một nam vận động viên tennis đang tung quả bóng lên cao để phát bóng . <end>',
#   '<start> Khán giả đang theo dõi cú phát bóng của nam vận động viên tennis . <end>',
#   '<start> Một người đàn ông đang chuẩn bị phát bóng ở trên sân tennis . <end>',
#   '<start> Một người đàn ông đang tung quả bóng tennis lên cao để phát bóng . <end>'],
#  'dataset/train/images/000000295499.jpg': ['<start> Bạn mặc áo hồng trắng đang trong tư thế lên bóng . <end>',
#   '<start> Trái bóng rổ đang chạm vào bảng rổ . <end>',
#   '<start> Xung quanh sân bóng rổ có những người khán giả đang quan sát . <end>',
#   '<start> Phía ngoài sân bóng rổ có những căn nhà mái đỏ . <end>',
#   '<start> Hình ảnh của các bạn nữ đang chơi bóng rổ trên sân xi măng . <end>'],
#  'dataset/train/images/000000079503.jpg': ['<start> Một cậu bé đang ném quả bóng chày ở trên sân . <end>',
#   '<start> Một cậu bé đang luyện tập ném bóng ở trên sân . <end>',
#   '<start> Một cầu thủ ném bóng nhí đang luyện tập ở trên sân . <end>',
#   '<start> Một cậu bé đang chơi bóng chày ở trên sân . <end>',
#   '<start> Một cầu thủ ném bóng nhí đang ném bóng ở trên sân . <end>'],
#  'dataset/train/images/000000477144.jpg': ['<start> Trận bóng chày đang diễn ra với quả bóng chày đang bay về phía cầu thủ đánh bóng . <end>',
#   '<start> Trận bóng chày đang diễn ra với quả bóng chày đang bay về phía sân nhà . <end>',
#   '<start> Hình ảnh trận đấu bóng chày đang diễn ra trước đông đảo khán giả . <end>',
#   '<start> Cầu thủ đánh bóng đứng trước cầu thủ bắt bóng chuẩn bị đánh trả bóng . <end>',
#   '<start> Cầu thủ đánh bóng đứng trên sân nhà cầm gậy chuẩn bị dỡ bóng . <end>'],
#  'dataset/train/images/000000097048.jpg': ['<start> Các trọng tài đang theo dõi chuyển động của nam vận động viên tennis . <end>',
#   '<start> Một nam vận động viên tennis đang chuẩn bị đánh bóng . <end>',
#   '<start> Một nam vận động viên tennis đang vung vợt để đánh bóng . <end>',
#   '<start> Một nam vận động viên tennis đang xoay người để đánh bóng . <end>',
#   '<start> Một người đàn ông đang chuẩn bị đánh quả bóng tennis ở trên sân đất nện . <end>'],
#  'dataset/train/images/000000306667.jpg': ['<start> Cô bé áo đen đang chuẩn bị sút bóng . <end>',
#   '<start> Một vài người và cáo hoá trang đang đứng trên sân . <end>',
#   '<start> Những người xung quan đang quan sát cô bé đá banh . <end>',
#   '<start> Một số người và cáo hóa trang đang xem cô bé chơi bóng . <end>',
#   '<start> Hình ảnh của cô bé đang thực hiện cú sút bóng . <end>'],
#  'dataset/train/images/000000474953.jpg': ['<start> Một người đàn ông cầm gậy bóng chày trong tư thế sẵn sàng đánh bóng . <end>',
#   '<start> Hai người đàn ông đang chơi bóng chày trên sân cát . <end>',
#   '<start> Một người đàn ông đang ném bóng về phía người đàn ông đang cầm gậy bóng chày . <end>',
#   '<start> Một người đàn ông cầm gậy bóng chày đứng trên sân sẵn sàng đỡ bóng . <end>',
#   '<start> Hai người đàn ông đang cùng nhau đánh bóng chày ngoài sân cát . <end>'],
#  'dataset/train/images/000000409468.jpg': ['<start> Một người đàn ông đang chơi bóng chày ở trên sân . <end>',
#   '<start> Một người đàn ông đang xoay người để đánh quả bóng chày ở trên sân . <end>',
#   '<start> Một người đàn ông đang giơ gậy lên để đánh quả bóng chày ở trên sân . <end>',
#   '<start> Một người đàn ông đang chuẩn bị đánh quả bóng chày . <end>',
#   '<start> Một cầu thủ đánh bóng đang xoay người để đánh bóng . <end>'],
#  'dataset/train/images/000000421187.jpg': ['<start> Các cầu thủ bóng đá đang thi đấu ở trên sân . <end>',
#   '<start> Khán giả đang theo dõi pha tranh bóng của hai nam cầu thủ . <end>',
#   '<start> Cầu thủ áo trắng đang dẫn bóng ở trên sân . <end>',
#   '<start> Những người đàn ông đang chơi bóng đá ở trên sân . <end>',
#   '<start> Cầu thủ áo tím đang đứng trước mặt cầu thủ áo trắng để cản bóng . <end>'],
#  'dataset/train/images/000000195829.jpg': ['<start> Một số người đang chơi bóng đá trên sân cỏ . <end>',
#   '<start> Hai đội áo trắng và áo cam đang thi đấu bóng đá trên sân cỏ . <end>',
#   '<start> Các cầu thủ bóng đá đang thi đấu trên sân cỏ . <end>',
#   '<start> Cầu thủ bóng đá của hai đội đang thi đấu trên sânl ` <end>',
#   '<start> Cầu thủ bóng đá áo cam đang tranh bóng của cầu thủ bóng đá áo trắng . <end>'],
#  'dataset/train/images/000000501311.jpg': ['<start> Trận bóng chày đang diễn ra với một cầu thủ đang ném bóng về phía trước . <end>',
#   '<start> Hình ảnh trận đấu bóng chày đang diễn ra . <end>',
#   '<start> Các cầu thủ bóng chày đang thi đấu trên sân . <end>',
#   '<start> Cầu thủ ném bóng đang ném bóng về phía trước . <end>',
#   '<start> Một cầu thủ bóng chày đang bước dài tới ném bóng trong trận đấu . <end>'],
#  'dataset/train/images/000000068408.jpg': ['<start> Các cầu thủ đang thi đấu bóng đá ở trong nhà . <end>',
#   '<start> Những người đàn ông đang chơi bóng đá ở trong nhà . <end>',
#   '<start> Những người đàn ông đang tranh bóng ở trên sân . <end>',
#   '<start> Các cầu thủ của hai đội đang tranh chấp bóng ở trên sân . <end>',
#   '<start> Cầu thủ áo xanh dương đang tranh bóng với các cầu thủ áo đối thủ . <end>'],
#  'dataset/train/images/000000192345.jpg': ['<start> Một vận động viên trượt ván đang luyện tập ở trong công viên . <end>',
#   '<start> Một người đàn ông đang trượt ván ở trong công viên . <end>',
#   '<start> Một vận động viên trượt ván đang luyện tập ở trên đường . <end>',
#   '<start> Một người đàn ông đang nghiêng người trên cái ván trượt . <end>',
#   '<start> Một người đàn ông đang trượt ván ở trên đường . <end>'],
#  'dataset/train/images/000000432432.jpg': ['<start> Các cầu thủ bóng chày đang thi đấu ở trên sân . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở trên sân . <end>',
#   '<start> Một người đàn ông đang xoay người để đánh quả bóng chày . <end>',
#   '<start> Các cầu thủ bóng chày và trọng tài đang theo dõi cú đánh bóng của cầu thủ đánh bóng . <end>',
#   '<start> Một cầu thủ đánh bóng đang xoay người để đánh bóng . <end>'],
#  'dataset/train/images/000000160899.jpg': ['<start> Các nữ cầu thủ áo trắng đang dắt bóng ở trên sân . <end>',
#   '<start> Nữ cầu thủ áo xanh đang quan sát chuyển động của các nữ cầu thủ áo trắng . <end>',
#   '<start> Các nữ cầu thủ đang thi đấu bóng đá ở trên sân . <end>',
#   '<start> Những cô gái đang chơi bóng đá ở trên sân . <end>',
#   '<start> Nữ cầu thủ áo xanh đang di chuyển ở cạnh các nữ cầu thủ áo trắng . <end>'],
#  'dataset/train/images/000000001682.jpg': ['<start> Hình ảnh phong cảnh có con thuyền , quả bóng và ngọn núi . <end>',
#   '<start> Phía bên phải của con thuyền và quả bóng là một ngọn núi . <end>',
#   '<start> Một quả bóng đang nổi trên mặt nước , phía sau có một con thuyền . <end>',
#   '<start> Trên mặt biển , có một quả bóng và một con thuyền đang nổi . <end>',
#   '<start> Trên mặt hồ , có một quả bóng và một con thuyền đang nổi . <end>'],
#  'dataset/train/images/000000224197.jpg': ['<start> Đứa trẻ đang cầm gậy bóng chày và cầm bóng đặt lên trụ . <end>',
#   '<start> Đứa trẻ cầm gậy bóng chày đang đặt quả bóng chày lên trụ với đứa trẻ khác đang quan sát . <end>',
#   '<start> Đứa trẻ đang đặt quả bóng chày lên trụ và tay phải cầm gậy bóng chày . <end>',
#   '<start> Đứa trẻ đang cầm gậy bóng chày đặt bóng lên trụ . <end>',
#   '<start> Đứa trẻ đang cầm gậy bóng chày và quả bóng chày đứng trên sân cỏ . <end>'],
#  'dataset/train/images/000000134558.jpg': ['<start> Một cậu bé đang cầm vợt tennis và đứng ở trên sân . <end>',
#   '<start> Một cậu bé đang chơi tennis ở trên sân . <end>',
#   '<start> Một cậu bé đang luyện tập tennis ở trên sân . <end>',
#   '<start> Một cậu bé đang xoay người để đánh bóng ở trên sân tennis . <end>',
#   '<start> Một cậu bé đang vung vợt tennis để đánh bóng ở trên sân . <end>'],
#  'dataset/train/images/000000240739.jpg': ['<start> Vận động viên tennis nam đang vung vợt đánh trả bóng . <end>',
#   '<start> Vận động viên tennis đang cầm vợt đỡ bóng thấp . <end>',
#   '<start> Vận động viên tennis đan đứng trên sân đánh trả bóng bằng vợt . <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Người đàn ông áo trắng đang chơi tennis trên sân . <end>'],
#  'dataset/train/images/000000183973.jpg': ['<start> Một cầu thủ đánh bóng đang vung gậy để đánh bóng . <end>',
#   '<start> Một người đàn ông đang vung gậy để đánh quả bóng chày . <end>',
#   '<start> Các cầu thủ khác và trọng tài đang theo dõi cú đánh bóng của cầu thủ đánh bóng . <end>',
#   '<start> Một cầu thủ đánh bóng đang xoay người để đánh bóng . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở ngoài trời . <end>'],
#  'dataset/train/images/000000048554.jpg': ['<start> Những đứa trẻ đang chơi bóng rổ và trượt ván ở cạnh những toà nhà . <end>',
#   '<start> Những đứa trẻ đang theo dõi cú ném quả bóng rổ của bạn mình . <end>',
#   '<start> Những đứa trẻ đang chơi bóng rổ và trượt ván ở trong trường học . <end>',
#   '<start> Những đứa trẻ đang chơi bóng rổ và trượt ván ở trên sân . <end>',
#   '<start> Những đứa trẻ đang chơi bóng rổ và trượt ván trong giờ ra chơi . <end>'],
#  'dataset/train/images/000000166093.jpg': ['<start> Một người phụ nữ đang đưa vợt lên cao để đánh quả bóng tennis . <end>',
#   '<start> Một người phụ nữ đang chuẩn bị đánh quả bóng tennis . <end>',
#   '<start> Một người phụ nữ đang dùng vợt để đánh quả bóng tennis . <end>',
#   '<start> Một người phụ nữ đang vung vợt để đánh quả bóng tennis . <end>',
#   '<start> Bức ảnh bị xoay ngang của một người phụ nữ đang chơi tennis . <end>'],
#  'dataset/train/images/000000174594.jpg': ['<start> Các cầu thủ bóng chày đang thi đấu ở trên sân . <end>',
#   '<start> Cầu thủ đánh bóng đang giơ gậy lên cao để chuẩn bị đánh bóng . <end>',
#   '<start> Khán giả đang theo dõi cú đánh bóng của cầu thủ đánh bóng . <end>',
#   '<start> Cầu thủ đánh bóng đang xoay người để chuẩn bị đánh bóng . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở trên sân . <end>'],
#  'dataset/train/images/000000458085.jpg': ['<start> Một người phụ nữ đang cầm vợt và đứng ở trên sân tennis . <end>',
#   '<start> Một nữ vận động viên tennis đang cầm vợt và đứng ở trên sân . <end>',
#   '<start> Một người phụ nữ đang chơi tennis ở trên sân . <end>',
#   '<start> Một người phụ nữ đang luyện tập tennis ở trên sân . <end>',
#   '<start> Một nữ vận động viên tennis đang thi đấu ở trên sân . <end>'],
#  'dataset/train/images/000000331196.jpg': ['<start> Người phụ nữ đang cầm vợt tennis với lên đánh bóng . <end>',
#   '<start> Vận động viên tennis nữ đang đưa vợt lên cao đánh bóng . <end>',
#   '<start> Người phụ nữ mặc đồ trắng đang chwoi tennis trên sân . <end>',
#   '<start> Người phụ nữ đang đứng trên sân cầm vợt tennis đỡ bóng cao . <end>',
#   '<start> Người phụ nữ đang đứng trên sân cầm vợt tennis đánh bóng . <end>'],
#  'dataset/train/images/000000556669.jpg': ['<start> Ba người đàn ông đang quan sát quả bóng chày ở trên không . <end>',
#   '<start> Hai người đàn ông còn lại đang theo dõi chuyển động của cầu thủ đánh bóng . <end>',
#   '<start> Một người đàn ông đang giơ gậy bóng chày ra sau và quan sát quả bóng ở trên không . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở trên sân . <end>',
#   '<start> Một người đàn ông đang giơ gậy bóng chày ra và chuẩn bị đánh quả bóng chày . <end>'],
#  'dataset/train/images/000000555683.jpg': ['<start> Những quả bóng tennis đang nằm rải rác ở phía bên phải của đứa trẻ . <end>',
#   '<start> Những quả bóng tennis và những cái vợt đang nằm rải rác ở phía bên phải của đứa trẻ . <end>',
#   '<start> Một đứa trẻ đang ngồi cạnh những quả bóng tennis ở trên sân . <end>',
#   '<start> Một đứa trẻ đang ngồi ở trước cái lưới với những quả bóng ở trên sân . <end>',
#   '<start> Một đứa trẻ đang ngồi trên sân với những quả bóng tennis . <end>'],
#  'dataset/train/images/000000357967.jpg': ['<start> Vận động viên tennis đang cầm vợt đỡ bóng trong trận đấu . <end>',
#   '<start> Vận động viên tennis đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Vận động viên tennis đang cầm vợt thi đấu trước đám đông . <end>',
#   '<start> Người đàn ông áo đỏ đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis nam đang đứng ngoài biên vung vợt . <end>'],
#  'dataset/train/images/000000283264.jpg': ['<start> Cầu thủ bóng chày bước dài về phía trước chuẩn bị ném bóng . <end>',
#   '<start> Người đàn ông đeo găng tay bóng chày thi đấu trên sân . <end>',
#   '<start> Người đàn ông áo đen đang chơi bóng chày trên sân . <end>',
#   '<start> Cầu thủ bóng chày đang đứng trên sân thực hiện động tác ném bóng . <end>',
#   '<start> Cầu thủ bóng chày đang ném bóng về phía trước . <end>'],
#  'dataset/train/images/000000574775.jpg': ['<start> Một người phụ nữ đang nhảy lên để đánh quả bóng tennis . <end>',
#   '<start> Một người phụ nữ đang vung vợt để đánh quả bóng tennis . <end>',
#   '<start> Một nữ vận động viên tennis đang nhảy lên để đánh bóng trong khi một nữ vận động viên khác đang đứng ở trên sân . <end>',
#   '<start> Một nữ vận động viên tennis đang vung vợt để đánh bóng . <end>',
#   '<start> Một nữ vận động viên tennis đang nhảy lên để đánh bóng . <end>'],
# ...
#   '<start> Những nữ cầu thủ đang thi đấu bóng đá ở trên sân . <end>',
#   '<start> Cô bé áo xanh dương đang tranh chấp bóng với cô bé áo xanh dạ quang . <end>'],
#  'dataset/train/images/000000062613.jpg': ['<start> Một người đàn ông đang dùng vợt để đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang chơi tennis ở trong vườn . <end>',
#   '<start> Một người đàn ông đang đánh quả bóng tennis ở trên sân . <end>',
#   '<start> Một người đàn ông đang luyện tennis ở trong vườn . <end>',
#   '<start> Một người đàn ông đang dùng vợt để đỡ quả bóng tennis . <end>'],
#  'dataset/train/images/000000415569.jpg': ['<start> Những người đàn ông đang chơi bóng chày ở trên sân . <end>',
#   '<start> Quang cảnh một trận thi đấu bóng chày nam từ trên cao . <end>',
#   '<start> Một cầu thủ ném bóng đang thực hiện động tác ném bóng . <end>',
#   '<start> Một cầu thủ đánh bóng đang giơ gậy lên cao ở gôn . <end>',
#   '<start> Khán giả đang theo dõi diễn biến của trận thi đấu bóng chày nam . <end>'],
#  'dataset/train/images/000000203878.jpg': ['<start> Vận động viên tennis nam đang vung vợt đánh bóng . <end>',
#   '<start> Người đàn ông áo đỏ đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Vận động viên tennis đang đứng trên sân cầm vợt đánh bóng . <end>',
#   '<start> Vận động viên tennis đang đánh bóng bằng vợt tennis . <end>'],
#  'dataset/train/images/000000431208.jpg': ['<start> Một người đàn ông đang chuẩn bị ném quả bóng chày ở trong tay . <end>',
#   '<start> Một người đàn ông đang lấy đà để ném quả bóng chày ở trong tay . <end>',
#   '<start> Một cầu thủ ném bóng đang lấy đà bị ném bóng . <end>',
#   '<start> Một cầu thủ ném bóng đang chuẩn bị ném bóng . <end>',
#   '<start> Một cầu thủ ném bóng đang luyện tập bị ném bóng ở trên sân . <end>'],
#  'dataset/train/images/000000085298.jpg': ['<start> Một cô bé đang giơ vợt tennis lên trên cao ở trên sân . <end>',
#   '<start> Hai cô bé đang chơi đùa với vợt tennis ở trên sân . <end>',
#   '<start> Một cô bé đang cầm vợt trong khi một cô bé khác đang giơ vợt lên cao . <end>',
#   '<start> Hai cô bé đang cầm vợt tennis và đứng ở trên sân . <end>',
#   '<start> Hai cô bé đang đứng trên sân tennis với những cây vợt . <end>'],
#  'dataset/train/images/000000065057.jpg': ['<start> Người phụ nữ áo xanh đang đuổi theo người phụ nữ áo cam với quả bóng . <end>',
#   '<start> Hai cầu thủ bóng bầu dục đang tranh bóng ở trên sân . <end>',
#   '<start> Một trận thi đấu bóng bầu dục đang diễn ra ở trên sân . <end>',
#   '<start> Người phụ nữ áo cam đang ôm quả bóng và chạy trên sân . <end>',
#   '<start> Hai người đang chơi bóng bầu dục ở trên sân . <end>'],
#  'dataset/train/images/000000313372.jpg': ['<start> Vận động viên tennis áo trắng đang cầm vợt quan sát đối thủ . <end>',
#   '<start> Người đàn ông áo đỏ cầm vợt tennis đang nhảy lên đỡ bóng . <end>',
#   '<start> Vận động viên tennis áo đỏ đang đánh bóng . <end>',
#   '<start> Hai người đàn ông đang chơi tennis trên sân . <end>',
#   '<start> Hai vận động viên tennis đang thi đấu trên sân . <end>'],
#  'dataset/train/images/000000328068.jpg': ['<start> Người phụ nữ cầm vợt tennis đứng trên sân cùng đứa trẻ . <end>',
#   '<start> Người phụ nữ mặc váy đỏ đang đưa đứa trẻ vợt tennis . <end>',
#   '<start> Người phụ nữ đang cầm vợt tennis cùng đứa trẻ trên sân . <end>',
#   '<start> Người phụ nữ đang đưa vợt tennis cho đứa trẻ <end>',
#   '<start> Người phụ nữ đang giao vợt tennis cho đứa trẻ . <end>'],
#  'dataset/train/images/000000531929.jpg': ['<start> Hai vận động viên tennis nam đang đánh đôi . <end>',
#   '<start> Hai người đàn ông đang cùng nhau đánh tennis trên sân . <end>',
#   '<start> Hai vận động viên tennis nam đang thi đấu cùng đội và đang đánh trả bóng . <end>',
#   '<start> Hai người đàn ông đang chơi tennis trên sân . <end>',
#   '<start> Hai vận động viên tennis nam đang thi đấu cùng đội . <end>'],
#  'dataset/train/images/000000181886.jpg': ['<start> Các nữ vận động viên tennis đang di chuyển ở trên sân . <end>',
#   '<start> Những cô gái đang luyện tập tennis ở trên sân . <end>',
#   '<start> Một trận thi đấu tennis đôi nữ đang diễn ra ở trên sân . <end>',
#   '<start> Những cô gái đang di chuyển ở trên sân tennis . <end>',
#   '<start> Một cô gái đang đưa vợt lên cao để đánh bóng ở cuối sân tennis . <end>'],
#  'dataset/train/images/000000523098.jpg': ['<start> Những đứa trẻ đang chơi bóng đá trên sân cỏ . <end>',
#   '<start> Những đứa trẻ đang cùng nhau đá bóng trên sân cỏ . <end>',
#   '<start> Những cầu thủ bóng đá trẻ của hai đội đang tranh chấp bóng trên sân . <end>',
#   '<start> Những cầu thủ bóng đá trẻ của hai đội đang thi đấu trên sân . <end>',
#   '<start> Hai đội bóng trẻ đang thi đấu bóng đá trên sân cỏ . <end>'],
#  'dataset/train/images/000000391971.jpg': ['<start> Vận động viên tennis đang cầm vợt nhảy lên đánh bóng . <end>',
#   '<start> Vận động viên tennis đang cầm vợt đỡ bóng trong trận đáu . a <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Người đàn ông áo đen đang cầm vợt tennis chơi trên sân . <end>',
#   '<start> Người đàn ông áo đen đang chơi tennis trên sân . <end>'],
#  'dataset/train/images/000000517945.jpg': ['<start> Trận bóng chày đang diễn ra dưới trời nắng . <end>',
#   '<start> Nhiều khán giả đang ngồi trên khán đài quan sát trận bóng chày . <end>',
#   '<start> Trận bóng chày đang diễn ra với quả bóng đang bay trên không . <end>',
#   '<start> Hình ảnh trận bóng chày đang diễn ra trước đông đảo khán giả quan sát . <end>',
#   '<start> Hình ảnh trận bóng chày đang diễn ra . <end>'],
#  'dataset/train/images/000000313278.jpg': ['<start> Một số người phụ nữ đang chơi bóng đá trên sân cỏ . <end>',
#   '<start> Cầu thủ bóng đá nữ đang kiểm dẫn bóng trên sân . <end>',
#   '<start> Người phụ nữ áo đen số 26 đang chạy theo bóng . <end>',
#   '<start> Những cầu thủ áo đen đang cố giành bóng của cầu thủ áo trắng . <end>',
#   '<start> Người phụ nữ áo trắng số 7 đang kiểm soát bóng . <end>'],
#  'dataset/train/images/000000256221.jpg': ['<start> Vận động viên tennis đang cầm vợt chạy tới vị trí bóng . <end>',
#   '<start> Người đàn ông áo xanh lá đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis nam đang chạy trên sân tay cầm vợt tennis . <end>',
#   '<start> Vận động viên tennis nam đang càm vợt chạy tới đỡ bóng . <end>',
#   '<start> Vận động viên tennis nam đang cầm vợt chạy trên sân . <end>'],
#  'dataset/train/images/000000486847.jpg': ['<start> Cầu thủ bóng chày đang thi đấu trên sân . <end>',
#   '<start> Người đàn ông áo trắng đang chơi bóng chày trên sân . <end>',
#   '<start> Cầu thủ bóng chày đứng trong tư thế chuẩn bị ném bóng . <end>',
#   '<start> Cầu thủ bóng chày đang trong tư thế ném bóng . <end>',
#   '<start> Cầu thủ bóng chày đang ném bóng về phía trước . <end>'],
#  'dataset/train/images/000000149615.jpg': ['<start> Một nam vận động viên tennis đang xoay người để đánh bóng . <end>',
#   '<start> Một nam vận động viên tennis đang vung vợt để đánh bóng . <end>',
#   '<start> Một người đàn ông đang vung vợt để đánh quả bóng tennis . <end>',
#   '<start> Một người đàn ông đang dùng vợt để đánh quả bóng tennis . <end>',
#   '<start> Một nam vận động viên tennis đang dùng vợt để đánh bóng . <end>'],
#  'dataset/train/images/000000029146.jpg': ['<start> Hai cậu bé đang đứng cạnh nhau ở trên bãi biển cùng với quả bóng . <end>',
#   '<start> Một cậu bé đang giữ quả bóng bằng chân và đứng tựa vào bạn mình . <end>',
#   '<start> Hai cậu bé đang chơi bóng đá cùng nhau ở trên bãi biển . <end>',
#   '<start> Hai cậu bé đang đứng trên bãi biển cùng với quả bóng . <end>',
#   '<start> Hai cậu bé đang bàn bạc cùng với nhau ở trên bãi biển . <end>'],
#  'dataset/train/images/000000063307.jpg': ['<start> Một cậu bé đang cầm gậy bóng chày và đứng ở trên sân . <end>',
#   '<start> Một đứa trẻ đang giơ gậy bóng chày lên cao ở trên sân . <end>',
#   '<start> Một đứa trẻ đang cầm gậy bóng chày và đứng ở trên sân . <end>',
#   '<start> Một đứa trẻ đang chơi bóng chày ở trên sân . <end>',
#   '<start> Một đứa trẻ đang luyện tập bóng chày ở trên sân . <end>'],
#  'dataset/train/images/000000521943.jpg': ['<start> Đứa trẻ đang chơi bóng chày trên sân cỏ . <end>',
#   '<start> Đứa trẻ đang vung gậy bóng chày đánh bóng đặt trên trụ . <end>',
#   '<start> Đứa trẻ đang đánh quả bóng đặt trên trụ bằng gậy bóng chày . <end>',
#   '<start> Đứa trẻ đang vung gậy đánh quả bóng chày đặt trên trụ . <end>',
#   '<start> Đứa trẻ cầm gậy bóng chày chơi ngoài trời . <end>'],
#  'dataset/train/images/000000012069.jpg': ['<start> Một cầu thủ đánh bóng đang nghiêng người để đánh bóng . <end>',
#   '<start> Cầu thủ đánh bóng đang chuẩn bị đánh quả bóng chày . <end>',
#   '<start> Một cầu thủ đánh bóng đang vung gậy để chuẩn bị đánh quả bóng . <end>',
#   '<start> Khán giả đang theo dõi động tác đánh bóng của cầu thủ đánh bóng . <end>',
#   '<start> Khán giả đang theo dõi trận thi đấu bóng chày ở trên sân . <end>'],
#  'dataset/train/images/000000492605.jpg': ['<start> Một cầu thủ bóng chày đang cầm gậy chuẩn bị đỡ bóng . <end>',
#   '<start> Hai người đàn ông đang chơi bóng chày trên sân . <end>',
#   '<start> Hai cầu thủ bóng chày đang cùng nhau thi đấu trên sân . <end>',
#   '<start> Cầu thủ bóng chày áo số 18 đang cầm gậy đỡ bóng thấp . <end>',
#   '<start> Cầu thủ ném bóng đang phát bóng về phía cầu thủ đánh bóng . <end>'],
#  'dataset/train/images/000000510871.jpg': ['<start> Vận động viên tennis nam đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Người đàn ông áo trắng đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis nam cầm vợt nhảy lên đánh bóng . <end>',
#   '<start> Vận động viên tennis nam cầm vợt nhảy lên đánh trả bóng . <end>',
#   '<start> Vận động viên tennis cầm vợt tennis đỡ bóng cao . <end>'],
#  'dataset/train/images/000000046331.jpg': ['<start> Một nam cầu thủ ném bóng đang chuẩn bị ném bóng . <end>',
#   '<start> Một người đàn ông đang thực hiện động tác ném quả bóng chày . <end>',
#   '<start> Một nam cầu thủ ném bóng đang thực hiện động tác ném bóng . <end>',
#   '<start> Một người đàn ông đang chuẩn bị ném quả bóng chày . <end>',
#   '<start> Một nam cầu thủ ném bóng đang giơ quả bóng lên cao để ném . <end>'],
#  'dataset/train/images/000000062657.jpg': ['<start> Một cậu bé đang chuẩn bị sút bóng ở trên sân . <end>',
#   '<start> Những đứa trẻ đang luyện tập bóng đá ở trên sân . <end>',
#   '<start> Những đứa trẻ đang đứng trên sân cùng với những quả bóng . <end>',
#   '<start> Những đứa trẻ đang chơi bóng đá ở trên sân . <end>',
#   '<start> Một cậu bé đang bước về phía quả bóng ở trên sân . <end>'],
#  'dataset/train/images/000000378126.jpg': ['<start> Hai cầu thủ của hai đội bóng nữ đang thi đấu bóng đá trên sân . <end>',
#   '<start> Hai cầu thủ bóng đá nữ đang thi đấu bóng đá trên sân . <end>',
#   '<start> Hai người pụ nữ mặc đồ bóng đá đang đá bóng trên sân . <end>',
#   '<start> Hai cầu thủ bóng đá nữ của hai đội đang tranh bóng trên sân . <end>',
#   '<start> Hai người phụ nữ đang chơi bóng đá trên sân . <end>'],
#  'dataset/train/images/000000245566.jpg': ['<start> Vận động viên tennis nữ đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Vận động viên tennis nữ đang vung vợt tennis đánh trả bóng . <end>',
#   '<start> Vận động viên tennis nữ đang vung vợt đỡ bóng trong trận . <end>',
#   '<start> người phụ nữ áo trắng đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis đang cầm vợt đứng ngoài biên đỡ bóng . <end>'],
#  'dataset/train/images/000000442245.jpg': ['<start> Hai cầu thủ áo cam đang tranh bóng với nữ cầu thủ áo xanh . <end>',
#   '<start> Những đứa trẻ đang chơi bóng đá ở trên sân . <end>',
#   '<start> Một cô bé áo xang đang tranh bóng với hai cậu bé áo cam . <end>',
#   '<start> Các cầu thủ bóng đá đang thi đấu ở trên sân . <end>',
#   '<start> Một cô bé áo xang đang ngã người ở giữa hai cậu bé áo cam . <end>'],
#  'dataset/train/images/000000043657.jpg': ['<start> Một cầu thủ đánh bóng vừa đánh hụt quả bóng . <end>',
#   '<start> Một cầu thủ đánh bóng đang giơ gậy lên cao để chuẩn bị đánh bóng . <end>',
#   '<start> Một cầu thủ bắt bóng đang chuẩn bị bắt bóng . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở ngoài trời . <end>',
#   '<start> Quả bóng đang bay về phía cầu thủ bắt bóng và trọng tài . <end>'],
#  'dataset/train/images/000000324366.jpg': ['<start> Hai vận động viên tennis đang thi đấu trên sân . <end>',
#   '<start> Hai người đàn ông đang chơi tennis trên sân . <end>',
#   '<start> Người đàn ông áo trắng đang cầm vợt tennis đứng ngoài sân . <end>',
#   '<start> Vận động viên tennis đang cầm vợt chuẩn bị đỡ bóng . <end>',
#   '<start> Vận động viên tennis áo trắng đang đứng ngoài biên quan sát bóng . <end>'],
#  'dataset/train/images/000000029752.jpg': ['<start> Hai tư thế khác nhau của nữ thủ môn khi tham gia trận đấu . <end>',
#   '<start> Hình ảnh của nữ thủ môn khi tham gia hai trận đấu khác nhau . <end>',
#   '<start> Hình ảnh hai cầu thủ bóng đá đang đứng trước khung thành . <end>',
#   '<start> Hai nữ thủ môn đang bảo vệ khung thành của mình . <end>',
#   '<start> Một nữ thủ môn đang bay người để bắt bóng ở phía sau thủ môn khác . <end>'],
#  'dataset/train/images/000000259338.jpg': ['<start> Vận động viên tennis nữ đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Người phụ nữ áo xanh lá đang chơi tennis trên sân . <end>',
#   '<start> Vận động viên tennis nữ đang cầm vợt tennis đỡ bóng cao . <end>',
#   '<start> Vận động viên tennis nữ đang cầm vợt tennis nhảy lên đánh bóng . <end>',
#   '<start> Vận động viên tennis nữ đang vung vợt tennis đánh bóng . <end>'],
#  'dataset/train/images/000000035211.jpg': ['<start> Con chó đang ngồi trong lòng cô bé với cái vợt và quả bóng tennis . <end>',
#   '<start> Cô bé đang ôm con chó trong lòng và cầm vợt tennis ở trên tay . <end>',
#   '<start> Con chó đang ngồi lên đùi của cô bé ở trên ghế . <end>',
#   '<start> Cô bé đang ngồi trên ghế cùng với con chó . <end>',
#   '<start> Cô bé đang ngồi trên ghế cùng với con chó và cái vợt tennis . <end>'],
#  'dataset/train/images/000000377319.jpg': ['<start> Vận động viên tennis nam đang cầm vợt đứng ngoài biên đỡ bóng . <end>',
#   '<start> Vận động viên tennis đang cầm vợt đỡ bóng cao . <end>',
#   '<start> Vận động viên tennis đang cầm vợt đứng trên sân đánh bóng . <end>',
#   '<start> Vận động viên tennis đang cầm vợt thi đấu trên sân . <end>',
#   '<start> Người đàn ông áo trắng đang chơi tennis trên sân . <end>'],
#  'dataset/train/images/000000080808.jpg': ['<start> Những đứa trẻ đang chơi bóng chày ở trong công viên cùng với bố mẹ . <end>',
#   '<start> Một gia đình đang chơi bóng chày ở trong công viên . <end>',
#   '<start> Những đứa trẻ đang chơi bóng chày ở trên sân cùng với bố mẹ . <end>',
#   '<start> Một gia đình đang chơi bóng chày ở trên sân . <end>',
#   '<start> Phụ huynh đang hướng dẫn cách chơi bóng chày cho những đứa con . <end>'],
#  'dataset/train/images/000000491732.jpg': ['<start> Hình ảnh trận đấu tennis đang diễn ra . <end>',
#   '<start> Bốn vận động viên tennis đang đấu đơn trên sân . <end>',
#   '<start> Các vận động viên tennis đang thi đấu trên sân theo đội . <end>',
#   '<start> Hình ảnh trận đấu tennis đôi đang diễn ra trên sân . <end>',
#   '<start> Các vận động viên tennis đang thi đấu đôi trên sân . <end>'],
#  'dataset/train/images/000000421250.jpg': ['<start> Những người đàn ông đang theo dõi đường bay của quả bóng chày . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày ở trên sân . <end>',
#   '<start> Những người đàn ông đang chơi bóng chày vào ban ngày . <end>',
#   '<start> Một người đàn ông đang giơ gậy lên cao ở gần gôn . <end>',
#   '<start> Một cầu thủ đánh bóng đang giơ gậy lên cao ở gần gôn . <end>'],
#  'dataset/train/images/000000460254.jpg': ['<start> Một người đàn ông đang cầm vợt tennis và quan sát quả bóng . <end>',
#   '<start> Một nam vnaja động viên tennis đang đứng bằng một chân và nhìn quả bóng bay vào lưới . <end>',
#   '<start> Một nam vnaja động viên tennis đang cầm vợt tennis và đứng nhìn quả bóng bay vào lưới . <end>',
#   '<start> Một người đàn ông đang đứng bằng một chân và quan sát quả bóng tennis . <end>',
#   '<start> Một nam vnaja động viên tennis đang nhìn quả bóng bay vào lưới . <end>'],
#  ...}

# %%
# Desired image dimensions
IMAGE_SIZE = (299, 299)

# Vocabulary size
VOCAB_SIZE = 10000

# Fixed length allowed for any sequence
SEQ_LENGTH = 25

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters
BATCH_SIZE = 64
EPOCHS = 30
AUTOTUNE = tf.data.AUTOTUNE

# %%
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  2695
# Number of validation samples:  924

# %% [markdown]
# **Vectorizing the text data**

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %% [markdown]
# **Building a tf.data.Dataset pipeline for training**

# %%
len(train_data.keys())
# Out:
# 2695

# %%
len(train_data.values())
# Out:
# 2695

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

# %% [markdown]
# **Building the model**

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(
        input_shape=(*IMAGE_SIZE, 3),
        include_top=False,
        weights="imagenet",
    )
    # We freeze our feature extractor
    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model


class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM,
            sequence_length=SEQ_LENGTH,
            vocab_size=VOCAB_SIZE,
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [
                tf.expand_dims(batch_size, -1),
                tf.constant([1, 1], dtype=tf.int32),
            ],
            axis=0,
        )
        return tf.tile(mask, mult)


class ImageCaptioningModel(keras.Model):
    def __init__(
        self,
        cnn_model,
        encoder,
        decoder,
        num_captions_per_image=5,
        image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {
            "loss": self.loss_tracker.result(),
            "acc": self.acc_tracker.result(),
        }

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]


cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model,
    encoder=encoder,
    decoder=decoder,
    image_aug=image_augmentation,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %% [markdown]
# **Model training**

# %%
# Define the loss function
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False,
    reduction='auto',
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)


# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# Fit the model
caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/30
# 43/43 [==============================] - 79s 1s/step - loss: 25.3464 - acc: 0.1280 - val_loss: 12.2937 - val_acc: 0.5259
# Epoch 2/30
# 43/43 [==============================] - 33s 756ms/step - loss: 10.5010 - acc: 0.5492 - val_loss: 9.2296 - val_acc: 0.5991
# Epoch 3/30
# 43/43 [==============================] - 33s 770ms/step - loss: 8.5485 - acc: 0.6087 - val_loss: 8.1048 - val_acc: 0.6288
# Epoch 4/30
# 43/43 [==============================] - 34s 782ms/step - loss: 7.6645 - acc: 0.6363 - val_loss: 7.6733 - val_acc: 0.6356
# Epoch 5/30
# 43/43 [==============================] - 33s 757ms/step - loss: 7.0859 - acc: 0.6522 - val_loss: 7.1885 - val_acc: 0.6572
# Epoch 6/30
# 43/43 [==============================] - 33s 751ms/step - loss: 6.7016 - acc: 0.6661 - val_loss: 7.0691 - val_acc: 0.6623
# Epoch 7/30
# 43/43 [==============================] - 37s 860ms/step - loss: 6.3952 - acc: 0.6724 - val_loss: 6.7783 - val_acc: 0.6697
# Epoch 8/30
# 43/43 [==============================] - 33s 754ms/step - loss: 6.1522 - acc: 0.6834 - val_loss: 6.5676 - val_acc: 0.6799
# Epoch 9/30
# 43/43 [==============================] - 37s 854ms/step - loss: 5.9014 - acc: 0.6918 - val_loss: 6.5699 - val_acc: 0.6770
# Epoch 10/30
# 43/43 [==============================] - 36s 826ms/step - loss: 5.7112 - acc: 0.6960 - val_loss: 6.3788 - val_acc: 0.6859
# Epoch 11/30
# 43/43 [==============================] - 38s 876ms/step - loss: 5.5359 - acc: 0.7021 - val_loss: 6.3876 - val_acc: 0.6845
# Epoch 12/30
# 43/43 [==============================] - 37s 860ms/step - loss: 5.4320 - acc: 0.7122 - val_loss: 6.3248 - val_acc: 0.6851
# Epoch 13/30
# 43/43 [==============================] - 37s 859ms/step - loss: 5.2580 - acc: 0.7135 - val_loss: 6.3195 - val_acc: 0.6877
# Epoch 14/30
# 43/43 [==============================] - 37s 862ms/step - loss: 5.1353 - acc: 0.7179 - val_loss: 6.2805 - val_acc: 0.6872
# Epoch 15/30
# 12/43 [=======>......................] - ETA: 18s - loss: 5.2281 - acc: 0.7154

# %%
caption_model.save('/content/caption_model.keras')

# %% [markdown]
# **Check sample predictions**

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == "<end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()
