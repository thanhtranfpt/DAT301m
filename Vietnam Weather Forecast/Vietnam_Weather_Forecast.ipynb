# %% [markdown]
# # Download the dataset

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)

# %% [markdown]
# https://drive.google.com/file/d/12zu1MF8dScx0Y200dno6yGmY2Ql5s10-/view?usp=sharing

# %%
pip install -U gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Collecting gdown
#   Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# Successfully installed gdown-5.1.0

# %%
# !gdown 12zu1MF8dScx0Y200dno6yGmY2Ql5s10-
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12zu1MF8dScx0Y200dno6yGmY2Ql5s10-
# To: /content/kaggle.json
# 100% 69.0/69.0 [00:00<00:00, 275kB/s]

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# Download Dataset
# !kaggle datasets download -d vanviethieuanh/vietnam-weather-data
# Out:
# Downloading vietnam-weather-data.zip to /content
#   0% 0.00/1.88M [00:00<?, ?B/s]
# 100% 1.88M/1.88M [00:00<00:00, 173MB/s]

# %%
# !unzip /content/vietnam-weather-data.zip
# Out:
# Archive:  /content/vietnam-weather-data.zip
#   inflating: weather.csv

# %% [markdown]
# # Imports

# %%
import csv
import pickle
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from dataclasses import dataclass
from absl import logging
logging.set_verbosity(logging.ERROR)

# %% [markdown]
# # Utilities

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %% [markdown]
# # Preview the Dataset

# %%
weather_df = pd.read_csv('/content/weather.csv')
weather_df
# Out:
#          province  max  min  wind wind_d  rain  humidi  cloud  pressure  \
# 0        Bac Lieu   27   22    17    NNE   6.9      90     71      1010
# 1        Bac Lieu   31   25    20    ENE   0.0      64     24      1010
# 2        Bac Lieu   29   24    14      E   0.0      75     45      1008
# 3        Bac Lieu   30   24    30      E   0.0      79     52      1012
# 4        Bac Lieu   31   25    20    ENE   0.0      70     24      1010
# ...           ...  ...  ...   ...    ...   ...     ...    ...       ...
# 181955  Soc Trang   28   23     8    SSW   0.0      75     50      1011
# 181956  Soc Trang   30   24    21    ENE   7.2      81     50      1011
# 181957  Soc Trang   26   24     9    ENE   1.3      91     75      1009
# 181958  Soc Trang   30   23    11      E   0.0      74      6      1012
# 181959  Soc Trang   29   24     9    ESE   0.7      84     43      1009
#
#               date
# 0       2009-01-01
# 1       2010-01-01
# 2       2011-01-01
# 3       2012-01-01
# 4       2013-01-01
# ...            ...
# 181955  2016-12-28
# 181956  2017-12-28
# 181957  2018-12-28
# 181958  2019-12-28
# 181959  2020-12-28
#
# [181960 rows x 10 columns]

# %% [markdown]
# **Filter to get only the city of Viet Tri**

# %%
weather_df = weather_df[weather_df['province'] == 'Viet Tri']
weather_df
# Out:
#         province  max  min  wind wind_d  rain  humidi  cloud  pressure  \
# 104611  Viet Tri   18   12     6     NE   0.1      70     41      1025
# 104612  Viet Tri   15   11     5    ESE   0.2      69     32      1025
# 104617  Viet Tri   17   16     5     NE   6.2      92    100      1015
# 104618  Viet Tri   18   15     4      E   1.1      87     82      1015
# 104619  Viet Tri   19   14     4    ENE   0.3      70     71      1021
# ...          ...  ...  ...   ...    ...   ...     ...    ...       ...
# 109340  Viet Tri   20   11     4    ESE   0.0      60      8      1025
# 109341  Viet Tri   20   14     4     SE   0.2      81     86      1020
# 109342  Viet Tri   14   11     7     NE  10.0      85    100      1025
# 109343  Viet Tri   22   14     5     NW   0.2      68     48      1018
# 109344  Viet Tri   24   21    12    ESE   1.7      81     74      1013
#
#               date
# 104611  2009-01-01
# 104612  2009-01-02
# 104617  2010-01-01
# 104618  2011-01-01
# 104619  2012-01-01
# ...            ...
# 109340  2016-12-29
# 109341  2017-12-29
# 109342  2018-12-29
# 109343  2019-12-29
# 109344  2020-12-29
#
# [4549 rows x 10 columns]

# %%
weather_df.to_csv('viet_tri.csv', index = False)

# %%
TEMPERATURES_CSV = '/content/viet_tri.csv'

with open(TEMPERATURES_CSV, 'r') as csvfile:
    print(f"Header looks like this:\n\n{csvfile.readline()}")
    print(f"First data point looks like this:\n\n{csvfile.readline()}")
    print(f"Second data point looks like this:\n\n{csvfile.readline()}")
# Out:
# Header looks like this:
#
# province,max,min,wind,wind_d,rain,humidi,cloud,pressure,date
#
# First data point looks like this:
#
# Viet Tri,18,12,6,NE,0.1,70,41,1025,2009-01-01
#
# Second data point looks like this:
#
# Viet Tri,15,11,5,ESE,0.2,69,32,1025,2009-01-02

# %% [markdown]
# # Parsing the raw data

# %%
def parse_data_from_file(filename):

    times = []
    min_temperatures = []
    max_temperatures = []

    with open(filename) as csvfile:

        ### START CODE HERE

        reader = csv.reader(csvfile, delimiter=',')

        next(reader)

        # Initialize a counter for timestamps
        timestamp = 0

        for row in reader:
            times.append(timestamp)
            max_temperatures.append(float(row[1]))
            min_temperatures.append(float(row[2]))
            timestamp += 1

        ### END CODE HERE

    return times, min_temperatures, max_temperatures

# %% [markdown]
# # With series of max_temperatures:

# %%
# Test your function and save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    TEMPERATURES_CSV = '/content/viet_tri.csv'
    times, min_temperatures, max_temperatures = parse_data_from_file(TEMPERATURES_CSV)
    TIME = np.array(times)
    SERIES = np.array(max_temperatures)
    SPLIT_TIME = 2500
    WINDOW_SIZE = 64
    BATCH_SIZE = 32
    SHUFFLE_BUFFER_SIZE = 1000


plt.figure(figsize=(10, 6))
plot_series(G.TIME, G.SERIES)
plt.show()

# %% [markdown]
# # Processing the data

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid


# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds


# Apply the transformation to the training set
train_set = windowed_dataset(series_train, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE)

# %% [markdown]
# # Defining the model architecture

# %%
def create_uncompiled_model():

    ### START CODE HERE

    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[G.WINDOW_SIZE, 1]),
        tf.keras.layers.LSTM(64, return_sequences=True),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(30, activation="relu"),
        tf.keras.layers.Dense(10, activation="relu"),
        tf.keras.layers.Dense(1)
    ])

    ### END CODE HERE

    return model

# %%
# Test your uncompiled model

# Create an instance of the model
uncompiled_model = create_uncompiled_model()

# Get one batch of the training set(X = input, y = label)
for X, y in train_set.take(1):

    # Generate a prediction
    print(f'Testing model prediction with input of shape {X.shape}...')
    y_pred = uncompiled_model.predict(X)

# Compare the shape of the prediction and the label y (remove dimensions of size 1)
y_pred_shape = y_pred.squeeze().shape

assert y_pred_shape == y.shape, (f'Squeezed predicted y shape = {y_pred_shape} '
                                           f'whereas actual y shape = {y.shape}.')

print("Your current architecture is compatible with the windowed dataset! :)")
# Out:
# Testing model prediction with input of shape (32, 64)...
# 1/1 [==============================] - 2s 2s/step
# Your current architecture is compatible with the windowed dataset! :)

# %% [markdown]
# # Adjusting the learning rate

# %%
def adjust_learning_rate(dataset):

    model = create_uncompiled_model()

    lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch / 20))

    ### START CODE HERE

    # Select your optimizer
    optimizer = tf.keras.optimizers.SGD(momentum=0.9)

    # Compile the model passing in the appropriate loss
    model.compile(loss=tf.keras.losses.Huber(),
                  optimizer=optimizer,
                  metrics=["mae"])

    ### END CODE HERE

    history = model.fit(dataset, epochs=100, callbacks=[lr_schedule])

    return history

# %%
# Run the training with dynamic LR
lr_history = adjust_learning_rate(train_set)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 7s 14ms/step - loss: 26.9877 - mae: 27.4877 - lr: 1.0000e-04
# Epoch 2/100
# 77/77 [==============================] - 1s 11ms/step - loss: 22.7280 - mae: 23.2280 - lr: 1.1220e-04
# Epoch 3/100
# 77/77 [==============================] - 1s 12ms/step - loss: 7.6579 - mae: 8.1458 - lr: 1.2589e-04
# Epoch 4/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8012 - mae: 5.2797 - lr: 1.4125e-04
# Epoch 5/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5638 - mae: 5.0380 - lr: 1.5849e-04
# Epoch 6/100
# 77/77 [==============================] - 2s 18ms/step - loss: 4.0557 - mae: 4.5316 - lr: 1.7783e-04
# Epoch 7/100
# 77/77 [==============================] - 2s 20ms/step - loss: 3.6339 - mae: 4.1047 - lr: 1.9953e-04
# Epoch 8/100
# 77/77 [==============================] - 1s 12ms/step - loss: 3.0066 - mae: 3.4708 - lr: 2.2387e-04
# Epoch 9/100
# 77/77 [==============================] - 1s 11ms/step - loss: 2.9372 - mae: 3.4032 - lr: 2.5119e-04
# Epoch 10/100
# 77/77 [==============================] - 1s 12ms/step - loss: 3.0236 - mae: 3.4908 - lr: 2.8184e-04
# Epoch 11/100
# 77/77 [==============================] - 1s 11ms/step - loss: 2.9496 - mae: 3.4142 - lr: 3.1623e-04
# Epoch 12/100
# 77/77 [==============================] - 1s 12ms/step - loss: 2.9125 - mae: 3.3790 - lr: 3.5481e-04
# Epoch 13/100
# 77/77 [==============================] - 1s 14ms/step - loss: 3.1274 - mae: 3.5958 - lr: 3.9811e-04
# Epoch 14/100
# 77/77 [==============================] - 2s 19ms/step - loss: 3.1127 - mae: 3.5786 - lr: 4.4668e-04
# Epoch 15/100
# 77/77 [==============================] - 1s 11ms/step - loss: 2.9967 - mae: 3.4619 - lr: 5.0119e-04
# Epoch 16/100
# 77/77 [==============================] - 1s 12ms/step - loss: 2.9024 - mae: 3.3668 - lr: 5.6234e-04
# Epoch 17/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.0253 - mae: 3.4900 - lr: 6.3096e-04
# Epoch 18/100
# 77/77 [==============================] - 1s 12ms/step - loss: 3.5556 - mae: 4.0275 - lr: 7.0795e-04
# Epoch 19/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.5488 - mae: 4.0184 - lr: 7.9433e-04
# Epoch 20/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.1538 - mae: 3.6197 - lr: 8.9125e-04
# Epoch 21/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.4418 - mae: 3.9132 - lr: 0.0010
# Epoch 22/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.3935 - mae: 3.8685 - lr: 0.0011
# Epoch 23/100
# 77/77 [==============================] - 1s 17ms/step - loss: 3.4627 - mae: 3.9350 - lr: 0.0013
# Epoch 24/100
# 77/77 [==============================] - 1s 16ms/step - loss: 3.1104 - mae: 3.5801 - lr: 0.0014
# Epoch 25/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.3322 - mae: 4.8083 - lr: 0.0016
# Epoch 26/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.7763 - mae: 4.2513 - lr: 0.0018
# Epoch 27/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.6569 - mae: 4.1318 - lr: 0.0020
# Epoch 28/100
# 77/77 [==============================] - 1s 12ms/step - loss: 3.5663 - mae: 4.0379 - lr: 0.0022
# Epoch 29/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.9345 - mae: 4.4088 - lr: 0.0025
# Epoch 30/100
# 77/77 [==============================] - 1s 11ms/step - loss: 3.8115 - mae: 4.2876 - lr: 0.0028
# Epoch 31/100
# 77/77 [==============================] - 1s 17ms/step - loss: 3.6595 - mae: 4.1316 - lr: 0.0032
# Epoch 32/100
# 77/77 [==============================] - 2s 16ms/step - loss: 3.3569 - mae: 3.8259 - lr: 0.0035
# Epoch 33/100
# 77/77 [==============================] - 1s 16ms/step - loss: 3.9326 - mae: 4.4089 - lr: 0.0040
# Epoch 34/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.3035 - mae: 4.7786 - lr: 0.0045
# Epoch 35/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8388 - mae: 5.3210 - lr: 0.0050
# Epoch 36/100
# 77/77 [==============================] - 1s 11ms/step - loss: 5.0230 - mae: 5.5041 - lr: 0.0056
# Epoch 37/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.8819 - mae: 5.3599 - lr: 0.0063
# Epoch 38/100
# 77/77 [==============================] - 1s 11ms/step - loss: 5.0802 - mae: 5.5641 - lr: 0.0071
# Epoch 39/100
# 77/77 [==============================] - 1s 11ms/step - loss: 5.3949 - mae: 5.8774 - lr: 0.0079
# Epoch 40/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7529 - mae: 5.2347 - lr: 0.0089
# Epoch 41/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.8368 - mae: 5.3163 - lr: 0.0100
# Epoch 42/100
# 77/77 [==============================] - 1s 15ms/step - loss: 5.1352 - mae: 5.6148 - lr: 0.0112
# Epoch 43/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8789 - mae: 5.3582 - lr: 0.0126
# Epoch 44/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.4849 - mae: 4.9612 - lr: 0.0141
# Epoch 45/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7082 - mae: 5.1834 - lr: 0.0158
# Epoch 46/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7631 - mae: 5.2436 - lr: 0.0178
# Epoch 47/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.5951 - mae: 5.0713 - lr: 0.0200
# Epoch 48/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7180 - mae: 5.1977 - lr: 0.0224
# Epoch 49/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5278 - mae: 5.0052 - lr: 0.0251
# Epoch 50/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.4924 - mae: 4.9699 - lr: 0.0282
# Epoch 51/100
# 77/77 [==============================] - 1s 17ms/step - loss: 4.8954 - mae: 5.3767 - lr: 0.0316
# Epoch 52/100
# 77/77 [==============================] - 2s 17ms/step - loss: 4.8056 - mae: 5.2867 - lr: 0.0355
# Epoch 53/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7045 - mae: 5.1838 - lr: 0.0398
# Epoch 54/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8042 - mae: 5.2813 - lr: 0.0447
# Epoch 55/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7996 - mae: 5.2798 - lr: 0.0501
# Epoch 56/100
# 77/77 [==============================] - 1s 11ms/step - loss: 5.2755 - mae: 5.7547 - lr: 0.0562
# Epoch 57/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.4768 - mae: 4.9546 - lr: 0.0631
# Epoch 58/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.9655 - mae: 5.4473 - lr: 0.0708
# Epoch 59/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5201 - mae: 4.9986 - lr: 0.0794
# Epoch 60/100
# 77/77 [==============================] - 2s 18ms/step - loss: 5.0834 - mae: 5.5639 - lr: 0.0891
# Epoch 61/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.6581 - mae: 5.1361 - lr: 0.1000
# Epoch 62/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7297 - mae: 5.2092 - lr: 0.1122
# Epoch 63/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8934 - mae: 5.3748 - lr: 0.1259
# Epoch 64/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.8824 - mae: 5.3648 - lr: 0.1413
# Epoch 65/100
# 77/77 [==============================] - 1s 17ms/step - loss: 4.8461 - mae: 5.3263 - lr: 0.1585
# Epoch 66/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.8197 - mae: 5.2984 - lr: 0.1778
# Epoch 67/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8045 - mae: 5.2843 - lr: 0.1995
# Epoch 68/100
# 77/77 [==============================] - 2s 18ms/step - loss: 4.8942 - mae: 5.3698 - lr: 0.2239
# Epoch 69/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8327 - mae: 5.3140 - lr: 0.2512
# Epoch 70/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.9098 - mae: 5.3890 - lr: 0.2818
# Epoch 71/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.6399 - mae: 5.1189 - lr: 0.3162
# Epoch 72/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5992 - mae: 5.0779 - lr: 0.3548
# Epoch 73/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7071 - mae: 5.1851 - lr: 0.3981
# Epoch 74/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7389 - mae: 5.2216 - lr: 0.4467
# Epoch 75/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.7056 - mae: 5.1843 - lr: 0.5012
# Epoch 76/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.6612 - mae: 5.1405 - lr: 0.5623
# Epoch 77/100
# 77/77 [==============================] - 1s 13ms/step - loss: 4.7193 - mae: 5.1948 - lr: 0.6310
# Epoch 78/100
# 77/77 [==============================] - 2s 26ms/step - loss: 4.6349 - mae: 5.1130 - lr: 0.7079
# Epoch 79/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7153 - mae: 5.1939 - lr: 0.7943
# Epoch 80/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5973 - mae: 5.0739 - lr: 0.8913
# Epoch 81/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5760 - mae: 5.0543 - lr: 1.0000
# Epoch 82/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.5344 - mae: 5.0104 - lr: 1.1220
# Epoch 83/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7066 - mae: 5.1855 - lr: 1.2589
# Epoch 84/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8137 - mae: 5.2936 - lr: 1.4125
# Epoch 85/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.9472 - mae: 5.4257 - lr: 1.5849
# Epoch 86/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.6457 - mae: 5.1261 - lr: 1.7783
# Epoch 87/100
# 77/77 [==============================] - 1s 13ms/step - loss: 4.8566 - mae: 5.3377 - lr: 1.9953
# Epoch 88/100
# 77/77 [==============================] - 2s 19ms/step - loss: 4.9000 - mae: 5.3766 - lr: 2.2387
# Epoch 89/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7606 - mae: 5.2387 - lr: 2.5119
# Epoch 90/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.5611 - mae: 5.0405 - lr: 2.8184
# Epoch 91/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.8730 - mae: 5.3546 - lr: 3.1623
# Epoch 92/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7441 - mae: 5.2244 - lr: 3.5481
# Epoch 93/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.6625 - mae: 5.1417 - lr: 3.9811
# Epoch 94/100
# 77/77 [==============================] - 1s 11ms/step - loss: 5.2669 - mae: 5.7504 - lr: 4.4668
# Epoch 95/100
# 77/77 [==============================] - 1s 12ms/step - loss: 5.3016 - mae: 5.7817 - lr: 5.0119
# Epoch 96/100
# 77/77 [==============================] - 1s 11ms/step - loss: 4.6763 - mae: 5.1579 - lr: 5.6234
# Epoch 97/100
# 77/77 [==============================] - 1s 14ms/step - loss: 4.9924 - mae: 5.4723 - lr: 6.3096
# Epoch 98/100
# 77/77 [==============================] - 2s 18ms/step - loss: 5.5068 - mae: 5.9873 - lr: 7.0795
# Epoch 99/100
# 77/77 [==============================] - 1s 12ms/step - loss: 4.9740 - mae: 5.4529 - lr: 7.9433
# Epoch 100/100
# 77/77 [==============================] - 1s 11ms/step - loss: 6.1674 - mae: 6.6517 - lr: 8.9125

# %%
plt.semilogx(lr_history.history["lr"], lr_history.history["loss"])
plt.axis([1e-4, 10, 0, 10])
# Out:
# (0.0001, 10.0, 0.0, 10.0)

# %% [markdown]
# # Compiling the model

# %%
def create_model():


    model = create_uncompiled_model()

    ### START CODE HERE

    model.compile(loss=tf.keras.losses.Huber(),
                  optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0.9),
                  metrics=["mae"])


    ### END CODE HERE

    return model

# %%
# Save an instance of the model
model = create_model()

# Train it
history = model.fit(train_set, epochs=50)
# Out:
# Epoch 1/50
# 77/77 [==============================] - 4s 12ms/step - loss: 22.7087 - mae: 23.2065
# Epoch 2/50
# 77/77 [==============================] - 2s 19ms/step - loss: 5.2059 - mae: 5.6848
# Epoch 3/50
# 77/77 [==============================] - 1s 13ms/step - loss: 4.5418 - mae: 5.0208
# Epoch 4/50
# 77/77 [==============================] - 2s 20ms/step - loss: 4.3101 - mae: 4.7816
# Epoch 5/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.4915 - mae: 4.9669
# Epoch 6/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5216 - mae: 4.9971
# Epoch 7/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.6432 - mae: 5.1225
# Epoch 8/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.7131 - mae: 5.1906
# Epoch 9/50
# 77/77 [==============================] - 1s 14ms/step - loss: 4.6379 - mae: 5.1155
# Epoch 10/50
# 77/77 [==============================] - 2s 20ms/step - loss: 4.7125 - mae: 5.1907
# Epoch 11/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.7885 - mae: 5.2684
# Epoch 12/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5843 - mae: 5.0612
# Epoch 13/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7989 - mae: 5.2779
# Epoch 14/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.9116 - mae: 5.3900
# Epoch 15/50
# 77/77 [==============================] - 1s 16ms/step - loss: 4.4646 - mae: 4.9429
# Epoch 16/50
# 77/77 [==============================] - 1s 16ms/step - loss: 4.6778 - mae: 5.1553
# Epoch 17/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7945 - mae: 5.2707
# Epoch 18/50
# 77/77 [==============================] - 2s 18ms/step - loss: 4.7503 - mae: 5.2294
# Epoch 19/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.8892 - mae: 5.3656
# Epoch 20/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.6052 - mae: 5.0825
# Epoch 21/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.6329 - mae: 5.1091
# Epoch 22/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.6150 - mae: 5.0921
# Epoch 23/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.8353 - mae: 5.3153
# Epoch 24/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.8200 - mae: 5.2984
# Epoch 25/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.7350 - mae: 5.2128
# Epoch 26/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.6728 - mae: 5.1517
# Epoch 27/50
# 77/77 [==============================] - 1s 18ms/step - loss: 4.7360 - mae: 5.2168
# Epoch 28/50
# 77/77 [==============================] - 2s 17ms/step - loss: 4.9055 - mae: 5.3879
# Epoch 29/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.7945 - mae: 5.2715
# Epoch 30/50
# 77/77 [==============================] - 1s 15ms/step - loss: 4.7955 - mae: 5.2781
# Epoch 31/50
# 77/77 [==============================] - 2s 17ms/step - loss: 4.5647 - mae: 5.0447
# Epoch 32/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.5593 - mae: 5.0374
# Epoch 33/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7664 - mae: 5.2444
# Epoch 34/50
# 77/77 [==============================] - 1s 14ms/step - loss: 4.8875 - mae: 5.3672
# Epoch 35/50
# 77/77 [==============================] - 2s 21ms/step - loss: 4.5907 - mae: 5.0671
# Epoch 36/50
# 77/77 [==============================] - 2s 25ms/step - loss: 4.7688 - mae: 5.2482
# Epoch 37/50
# 77/77 [==============================] - 2s 16ms/step - loss: 4.7599 - mae: 5.2400
# Epoch 38/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.6476 - mae: 5.1251
# Epoch 39/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.5899 - mae: 5.0671
# Epoch 40/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.7521 - mae: 5.2324
# Epoch 41/50
# 77/77 [==============================] - 2s 16ms/step - loss: 5.0299 - mae: 5.5100
# Epoch 42/50
# 77/77 [==============================] - 2s 17ms/step - loss: 4.7368 - mae: 5.2143
# Epoch 43/50
# 77/77 [==============================] - 1s 13ms/step - loss: 4.5902 - mae: 5.0659
# Epoch 44/50
# 77/77 [==============================] - 2s 26ms/step - loss: 4.8688 - mae: 5.3471
# Epoch 45/50
# 77/77 [==============================] - 1s 14ms/step - loss: 4.8943 - mae: 5.3751
# Epoch 46/50
# 77/77 [==============================] - 1s 12ms/step - loss: 4.7873 - mae: 5.2703
# Epoch 47/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7220 - mae: 5.2032
# Epoch 48/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7360 - mae: 5.2139
# Epoch 49/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.6657 - mae: 5.1449
# Epoch 50/50
# 77/77 [==============================] - 1s 11ms/step - loss: 4.7088 - mae: 5.1899

# %% [markdown]
# # Evaluating the forecast

# %%
def compute_metrics(true_series, forecast):

    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %% [markdown]
# # Faster model forecasts

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
# Compute the forecast for all the series
rnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE).squeeze()

# Slice the forecast to get only the predictions for the validation set
rnn_forecast = rnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]

# Plot the forecast
plt.figure(figsize=(10, 6))
plot_series(time_valid, series_valid)
plot_series(time_valid, rnn_forecast)
# Out:
# 141/141 [==============================] - 1s 7ms/step

# %%
mse, mae = compute_metrics(series_valid, rnn_forecast)

print(f"mse: {mse:.2f}, mae: {mae:.2f} for forecast")
# Out:
# mse: 38.46, mae: 4.63 for forecast

# %% [markdown]
# # Save the model

# %%
# Save your model in the SavedModel format
model.save('saved_model/max_temperatures')

# Compress the directory using tar
! tar -czvf saved_model.tar.gz saved_model/
# Out:
# saved_model/
# saved_model/max_temperatures/
# saved_model/max_temperatures/assets/
# saved_model/max_temperatures/variables/
# saved_model/max_temperatures/variables/variables.data-00000-of-00001
# saved_model/max_temperatures/variables/variables.index
# saved_model/max_temperatures/saved_model.pb
# saved_model/max_temperatures/fingerprint.pb
# saved_model/max_temperatures/keras_metadata.pb

# %% [markdown]
# # Download model saved

# %%
# !zip -r max_temperatures.zip /content/saved_model/max_temperatures
# Out:
#   adding: content/saved_model/max_temperatures/ (stored 0%)
#   adding: content/saved_model/max_temperatures/assets/ (stored 0%)
#   adding: content/saved_model/max_temperatures/variables/ (stored 0%)
#   adding: content/saved_model/max_temperatures/variables/variables.data-00000-of-00001 (deflated 11%)
#   adding: content/saved_model/max_temperatures/variables/variables.index (deflated 62%)
#   adding: content/saved_model/max_temperatures/saved_model.pb (deflated 90%)
#   adding: content/saved_model/max_temperatures/fingerprint.pb (stored 0%)
#   adding: content/saved_model/max_temperatures/keras_metadata.pb (deflated 91%)

# %% [markdown]
# # Try different hyperparameters

# %%
# Test your function and save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    TEMPERATURES_CSV = '/content/viet_tri.csv'
    times, min_temperatures, max_temperatures = parse_data_from_file(TEMPERATURES_CSV)
    TIME = np.array(times)
    SERIES = np.array(max_temperatures)
    SPLIT_TIME = 4000
    WINDOW_SIZE = 30
    BATCH_SIZE = 32
    SHUFFLE_BUFFER_SIZE = 500


plt.figure(figsize=(10, 6))
plot_series(G.TIME, G.SERIES)
plt.show()

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid


# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds


# Apply the transformation to the training set
train_set = windowed_dataset(series_train, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE)

# %%
def create_uncompiled_model():

    ### START CODE HERE

    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[G.WINDOW_SIZE, 1]),
        tf.keras.layers.LSTM(64, return_sequences=True),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(30, activation="relu"),
        tf.keras.layers.Dense(10, activation="relu"),
        tf.keras.layers.Dense(1)
    ])

    ### END CODE HERE

    return model

# %%
# Test your uncompiled model

# Create an instance of the model
uncompiled_model = create_uncompiled_model()

# Get one batch of the training set(X = input, y = label)
for X, y in train_set.take(1):

    # Generate a prediction
    print(f'Testing model prediction with input of shape {X.shape}...')
    y_pred = uncompiled_model.predict(X)

# Compare the shape of the prediction and the label y (remove dimensions of size 1)
y_pred_shape = y_pred.squeeze().shape

assert y_pred_shape == y.shape, (f'Squeezed predicted y shape = {y_pred_shape} '
                                           f'whereas actual y shape = {y.shape}.')

print("Your current architecture is compatible with the windowed dataset! :)")
# Out:
# Testing model prediction with input of shape (32, 30)...
# 1/1 [==============================] - 1s 790ms/step
# Your current architecture is compatible with the windowed dataset! :)

# %%
def create_model():


    model = create_uncompiled_model()

    ### START CODE HERE

    model.compile(loss=tf.keras.losses.Huber(),
                  optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0.9),
                  metrics=["mae"])


    ### END CODE HERE

    return model

# %%
# Save an instance of the model
model = create_model()

# Train it
history = model.fit(train_set, epochs=50)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 5s 11ms/step - loss: 13.3091 - mae: 13.7947
# Epoch 2/50
# 125/125 [==============================] - 1s 10ms/step - loss: 3.1900 - mae: 3.6564
# Epoch 3/50
# 125/125 [==============================] - 1s 11ms/step - loss: 3.2299 - mae: 3.6969
# Epoch 4/50
# 125/125 [==============================] - 3s 25ms/step - loss: 3.1191 - mae: 3.5849
# Epoch 5/50
# 125/125 [==============================] - 2s 15ms/step - loss: 3.2528 - mae: 3.7237
# Epoch 6/50
# 125/125 [==============================] - 1s 11ms/step - loss: 3.1781 - mae: 3.6447
# Epoch 7/50
# 125/125 [==============================] - 2s 14ms/step - loss: 3.0945 - mae: 3.5607
# Epoch 8/50
# 125/125 [==============================] - 2s 15ms/step - loss: 3.0791 - mae: 3.5448
# Epoch 9/50
# 125/125 [==============================] - 3s 21ms/step - loss: 3.1422 - mae: 3.6087
# Epoch 10/50
# 125/125 [==============================] - 2s 18ms/step - loss: 3.0435 - mae: 3.5101
# Epoch 11/50
# 125/125 [==============================] - 2s 13ms/step - loss: 3.0938 - mae: 3.5579
# Epoch 12/50
# 125/125 [==============================] - 2s 13ms/step - loss: 3.1585 - mae: 3.6254
# Epoch 13/50
# 125/125 [==============================] - 2s 11ms/step - loss: 3.1009 - mae: 3.5652
# Epoch 14/50
# 125/125 [==============================] - 2s 15ms/step - loss: 3.2119 - mae: 3.6779
# Epoch 15/50
# 125/125 [==============================] - 2s 12ms/step - loss: 2.9948 - mae: 3.4608
# Epoch 16/50
# 125/125 [==============================] - 1s 10ms/step - loss: 3.0460 - mae: 3.5085
# Epoch 17/50
# 125/125 [==============================] - 1s 10ms/step - loss: 3.0489 - mae: 3.5138
# Epoch 18/50
# 125/125 [==============================] - 1s 9ms/step - loss: 2.9746 - mae: 3.4383
# Epoch 19/50
# 125/125 [==============================] - 1s 10ms/step - loss: 3.0049 - mae: 3.4719
# Epoch 20/50
# 125/125 [==============================] - 2s 13ms/step - loss: 3.0011 - mae: 3.4670
# Epoch 21/50
# 125/125 [==============================] - 2s 14ms/step - loss: 2.9734 - mae: 3.4389
# Epoch 22/50
# 125/125 [==============================] - 1s 10ms/step - loss: 3.0350 - mae: 3.4993
# Epoch 23/50
# 125/125 [==============================] - 1s 10ms/step - loss: 3.2772 - mae: 3.7437
# Epoch 24/50
# 125/125 [==============================] - 2s 14ms/step - loss: 3.0520 - mae: 3.5197
# Epoch 25/50
# 125/125 [==============================] - 2s 11ms/step - loss: 3.0142 - mae: 3.4767
# Epoch 26/50
# 125/125 [==============================] - 2s 14ms/step - loss: 3.0594 - mae: 3.5232
# Epoch 27/50
# 125/125 [==============================] - 2s 14ms/step - loss: 3.0572 - mae: 3.5224
# Epoch 28/50
# 125/125 [==============================] - 1s 10ms/step - loss: 2.9590 - mae: 3.4262
# Epoch 29/50
# 125/125 [==============================] - 2s 12ms/step - loss: 3.0551 - mae: 3.5193
# Epoch 30/50
# 125/125 [==============================] - 2s 15ms/step - loss: 3.0085 - mae: 3.4759
# Epoch 31/50
# 125/125 [==============================] - 4s 30ms/step - loss: 2.8429 - mae: 3.3069
# Epoch 32/50
# 125/125 [==============================] - 3s 21ms/step - loss: 2.9963 - mae: 3.4616
# Epoch 33/50
# 125/125 [==============================] - 1s 10ms/step - loss: 2.9607 - mae: 3.4253
# Epoch 34/50
# 125/125 [==============================] - 2s 13ms/step - loss: 3.0236 - mae: 3.4899
# Epoch 35/50
# 125/125 [==============================] - 2s 15ms/step - loss: 2.9658 - mae: 3.4300
# Epoch 36/50
# 125/125 [==============================] - 2s 15ms/step - loss: 2.8696 - mae: 3.3309
# Epoch 37/50
# 125/125 [==============================] - 2s 17ms/step - loss: 3.0098 - mae: 3.4741
# Epoch 38/50
# 125/125 [==============================] - 1s 10ms/step - loss: 2.9282 - mae: 3.3925
# Epoch 39/50
# 125/125 [==============================] - 1s 10ms/step - loss: 2.8747 - mae: 3.3381
# Epoch 40/50
# 125/125 [==============================] - 1s 10ms/step - loss: 2.8438 - mae: 3.3084
# Epoch 41/50
# 125/125 [==============================] - 3s 27ms/step - loss: 2.9011 - mae: 3.3630
# Epoch 42/50
# 125/125 [==============================] - 3s 26ms/step - loss: 2.9022 - mae: 3.3657
# Epoch 43/50
# 125/125 [==============================] - 2s 13ms/step - loss: 2.8778 - mae: 3.3424
# Epoch 44/50
# 125/125 [==============================] - 2s 11ms/step - loss: 2.9103 - mae: 3.3746
# Epoch 45/50
# 125/125 [==============================] - 2s 16ms/step - loss: 3.0369 - mae: 3.5029
# Epoch 46/50
# 125/125 [==============================] - 1s 11ms/step - loss: 2.8379 - mae: 3.3033
# Epoch 47/50
# 125/125 [==============================] - 2s 13ms/step - loss: 2.8674 - mae: 3.3308
# Epoch 48/50
# 125/125 [==============================] - 3s 20ms/step - loss: 2.9439 - mae: 3.4083
# Epoch 49/50
# 125/125 [==============================] - 2s 19ms/step - loss: 2.9496 - mae: 3.4136
# Epoch 50/50
# 125/125 [==============================] - 3s 20ms/step - loss: 2.9224 - mae: 3.3862

# %%
def compute_metrics(true_series, forecast):

    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %%
# Compute the forecast for all the series
rnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE).squeeze()

# Slice the forecast to get only the predictions for the validation set
rnn_forecast = rnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]

# Plot the forecast
plt.figure(figsize=(10, 6))
plot_series(time_valid, series_valid)
plot_series(time_valid, rnn_forecast)
# Out:
# 142/142 [==============================] - 2s 6ms/step

# %% [markdown]
# # With the series of min_temperatures:

# %%
# Test your function and save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    TEMPERATURES_CSV = '/content/viet_tri.csv'
    times, min_temperatures, max_temperatures = parse_data_from_file(TEMPERATURES_CSV)
    TIME = np.array(times)
    SERIES = np.array(min_temperatures)
    SPLIT_TIME = 3500
    WINDOW_SIZE = 30
    BATCH_SIZE = 32
    SHUFFLE_BUFFER_SIZE = 500


plt.figure(figsize=(10, 6))
plot_series(G.TIME, G.SERIES)
plt.show()

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid


# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds


# Apply the transformation to the training set
train_set = windowed_dataset(series_train, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE)

# %%
def create_uncompiled_model():

    ### START CODE HERE

    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[G.WINDOW_SIZE, 1]),
        tf.keras.layers.LSTM(64, return_sequences=True),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(30, activation="relu"),
        tf.keras.layers.Dense(10, activation="relu"),
        tf.keras.layers.Dense(1)
    ])

    ### END CODE HERE

    return model

# %%
# Test your uncompiled model

# Create an instance of the model
uncompiled_model = create_uncompiled_model()

# Get one batch of the training set(X = input, y = label)
for X, y in train_set.take(1):

    # Generate a prediction
    print(f'Testing model prediction with input of shape {X.shape}...')
    y_pred = uncompiled_model.predict(X)

# Compare the shape of the prediction and the label y (remove dimensions of size 1)
y_pred_shape = y_pred.squeeze().shape

assert y_pred_shape == y.shape, (f'Squeezed predicted y shape = {y_pred_shape} '
                                           f'whereas actual y shape = {y.shape}.')

print("Your current architecture is compatible with the windowed dataset! :)")
# Out:
# Testing model prediction with input of shape (32, 30)...
# 1/1 [==============================] - 1s 704ms/step
# Your current architecture is compatible with the windowed dataset! :)

# %%
def create_model():


    model = create_uncompiled_model()

    ### START CODE HERE

    model.compile(loss=tf.keras.losses.Huber(),
                  optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0.9),
                  metrics=["mae"])


    ### END CODE HERE

    return model

# %%
# Save an instance of the model
model = create_model()

# Train it
history = model.fit(train_set, epochs=50)
# Out:
# Epoch 1/50
# 109/109 [==============================] - 5s 14ms/step - loss: 7.9956 - mae: 8.4683
# Epoch 2/50
# 109/109 [==============================] - 1s 12ms/step - loss: 2.2911 - mae: 2.7376
# Epoch 3/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.2217 - mae: 2.6652
# Epoch 4/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.1418 - mae: 2.5846
# Epoch 5/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.2268 - mae: 2.6716
# Epoch 6/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.1875 - mae: 2.6348
# Epoch 7/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.3035 - mae: 2.7524
# Epoch 8/50
# 109/109 [==============================] - 1s 12ms/step - loss: 2.2317 - mae: 2.6761
# Epoch 9/50
# 109/109 [==============================] - 2s 16ms/step - loss: 2.1869 - mae: 2.6333
# Epoch 10/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.1632 - mae: 2.6084
# Epoch 11/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.2316 - mae: 2.6789
# Epoch 12/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.2112 - mae: 2.6516
# Epoch 13/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.1202 - mae: 2.5648
# Epoch 14/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.1731 - mae: 2.6164
# Epoch 15/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.2086 - mae: 2.6538
# Epoch 16/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.1775 - mae: 2.6201
# Epoch 17/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.1582 - mae: 2.6061
# Epoch 18/50
# 109/109 [==============================] - 2s 13ms/step - loss: 2.2186 - mae: 2.6616
# Epoch 19/50
# 109/109 [==============================] - 2s 16ms/step - loss: 2.0826 - mae: 2.5248
# Epoch 20/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.0357 - mae: 2.4772
# Epoch 21/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.9893 - mae: 2.4306
# Epoch 22/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.0197 - mae: 2.4661
# Epoch 23/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.0502 - mae: 2.4939
# Epoch 24/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.0794 - mae: 2.5268
# Epoch 25/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.0182 - mae: 2.4592
# Epoch 26/50
# 109/109 [==============================] - 1s 10ms/step - loss: 2.0472 - mae: 2.4943
# Epoch 27/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.8900 - mae: 2.3301
# Epoch 28/50
# 109/109 [==============================] - 2s 16ms/step - loss: 1.9740 - mae: 2.4189
# Epoch 29/50
# 109/109 [==============================] - 2s 17ms/step - loss: 1.8589 - mae: 2.3033
# Epoch 30/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.7824 - mae: 2.2248
# Epoch 31/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.7662 - mae: 2.2086
# Epoch 32/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.7794 - mae: 2.2238
# Epoch 33/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.8559 - mae: 2.2994
# Epoch 34/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.8412 - mae: 2.2828
# Epoch 35/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.8096 - mae: 2.2487
# Epoch 36/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.7701 - mae: 2.2115
# Epoch 37/50
# 109/109 [==============================] - 1s 11ms/step - loss: 1.7804 - mae: 2.2219
# Epoch 38/50
# 109/109 [==============================] - 2s 15ms/step - loss: 1.7640 - mae: 2.2076
# Epoch 39/50
# 109/109 [==============================] - 1s 12ms/step - loss: 1.6506 - mae: 2.0911
# Epoch 40/50
# 109/109 [==============================] - 1s 11ms/step - loss: 1.5965 - mae: 2.0375
# Epoch 41/50
# 109/109 [==============================] - 1s 12ms/step - loss: 1.6265 - mae: 2.0658
# Epoch 42/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.5988 - mae: 2.0391
# Epoch 43/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.5934 - mae: 2.0314
# Epoch 44/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.6091 - mae: 2.0497
# Epoch 45/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.6079 - mae: 2.0500
# Epoch 46/50
# 109/109 [==============================] - 2s 14ms/step - loss: 1.6860 - mae: 2.1275
# Epoch 47/50
# 109/109 [==============================] - 2s 14ms/step - loss: 1.6014 - mae: 2.0413
# Epoch 48/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.5783 - mae: 2.0175
# Epoch 49/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.5833 - mae: 2.0250
# Epoch 50/50
# 109/109 [==============================] - 1s 10ms/step - loss: 1.6918 - mae: 2.1321

# %%
def compute_metrics(true_series, forecast):

    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %%
# Compute the forecast for all the series
rnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE).squeeze()

# Slice the forecast to get only the predictions for the validation set
rnn_forecast = rnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]

# Plot the forecast
plt.figure(figsize=(10, 6))
plot_series(time_valid, series_valid)
plot_series(time_valid, rnn_forecast)
# Out:
# 142/142 [==============================] - 1s 6ms/step

# %%
mse, mae = compute_metrics(series_valid, rnn_forecast)

print(f"mse: {mse:.2f}, mae: {mae:.2f} for forecast")
# Out:
# mse: 10.81, mae: 2.57 for forecast

# %%
# Save your model in the SavedModel format
model.save('saved_model/min_temperatures')

# %%
# !zip -r min_temperatures.zip /content/saved_model/min_temperatures
# Out:
#   adding: content/saved_model/min_temperatures/ (stored 0%)
#   adding: content/saved_model/min_temperatures/assets/ (stored 0%)
#   adding: content/saved_model/min_temperatures/variables/ (stored 0%)
#   adding: content/saved_model/min_temperatures/variables/variables.data-00000-of-00001 (deflated 11%)
#   adding: content/saved_model/min_temperatures/variables/variables.index (deflated 62%)
#   adding: content/saved_model/min_temperatures/saved_model.pb (deflated 90%)
#   adding: content/saved_model/min_temperatures/fingerprint.pb (stored 0%)
#   adding: content/saved_model/min_temperatures/keras_metadata.pb (deflated 91%)
