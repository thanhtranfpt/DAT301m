# %%
import pandas as pd
import os
from tqdm.notebook import tqdm
data_path = '/kaggle/input/dlai3-hackathon-phase3-covid19-cxr-challenge/DLAI3_Phase3'
import random

# %%
def split_list(data, split_ratio=0.8):
    # Calculate the index to split the list
    split_index = int(len(data) * split_ratio)
    
    # Shuffle the list randomly
    random.shuffle(data)
    
    # Split the list based on the calculated index
    train_data = data[:split_index]
    test_data = data[split_index:]
    
    return train_data, test_data

# %%
import os

def delete_files_in_directory(directory_path):
    # Get the list of files in the directory
    files = os.listdir(directory_path)

    # Iterate through the files and delete each one
    for file_name in tqdm(files):
        file_path = os.path.join(directory_path, file_name)
        try:
            if os.path.isfile(file_path):
                os.remove(file_path)
        except Exception as e:
            print(f"Error deleting {file_path}: {e}")
            
    shutil.rmtree(directory_path)

# Example usage:
# directory_to_clear = '/kaggle/working/val'
# delete_files_in_directory(directory_to_clear)
# print('Done')

# %%
import shutil

os.mkdir('/kaggle/working/train')
os.mkdir('/kaggle/working/val')

for class_name in os.listdir(data_path):
    if not os.path.isdir(os.path.join(data_path, class_name)):
        continue
    print('Processing: ', class_name)
    images_path = os.path.join(data_path, class_name)
    train_files, val_files = split_list(os.listdir(images_path), 0.8)
    train_ds = f'/kaggle/working/train/{class_name}'
    os.mkdir(train_ds)
    for file_name in tqdm(train_files):
        shutil.copy(os.path.join(images_path, file_name), os.path.join(train_ds, file_name))
    val_ds = f'/kaggle/working/val/{class_name}'
    os.mkdir(val_ds)
    for file_name in tqdm(val_files):
        shutil.copy(os.path.join(images_path, file_name), os.path.join(val_ds, file_name))
# Out:
# Processing:  THORAXDISEASE
#   0%|          | 0/2988 [00:00<?, ?it/s]
#   0%|          | 0/748 [00:00<?, ?it/s]
# Processing:  COVID-19
#   0%|          | 0/290 [00:00<?, ?it/s]
#   0%|          | 0/73 [00:00<?, ?it/s]
# Processing:  NOFINDING
#   0%|          | 0/1126 [00:00<?, ?it/s]
#   0%|          | 0/282 [00:00<?, ?it/s]

# %%
import os

# Directory with training horse pictures
train_normal_dir = os.path.join('/kaggle/working/train/THORAXDISEASE')

# Directory with training human pictures
train_covid_dir = os.path.join('/kaggle/working/train/COVID-19')

# Directory with validation horse pictures
validation_normal_dir = os.path.join('/kaggle/working/val/THORAXDISEASE')

# Directory with validation human pictures
validation_covid_dir = os.path.join('/kaggle/working/val/COVID-19')

# %%
train_normal_names = os.listdir(train_normal_dir)
print(f'TRAIN SET NORMALS: {train_normal_names[:10]}')

train_covid_names = os.listdir(train_covid_dir)
print(f'TRAIN SET COVID: {train_covid_names[:10]}')

validation_normal_names = os.listdir(validation_normal_dir)
print(f'VAL SET NORMALS: {validation_normal_names[:10]}')

validation_covid_names = os.listdir(validation_covid_dir)
print(f'VAL SET COVID: {validation_covid_names[:10]}')
# Out:
# TRAIN SET NORMALS: ['person848_bacteria_2769.jpeg', 'person515_bacteria_2186.jpeg', 'person26_bacteria_124.jpeg', 'person322_bacteria_1494.jpeg', 'person482_bacteria_2043.jpeg', 'person428_bacteria_1869.jpeg', 'person57_bacteria_270.jpeg', 'person492_bacteria_2084.jpeg', 'person906_bacteria_2831.jpeg', 'person5_bacteria_19.jpeg']
# TRAIN SET COVID: ['ryct.2020200034.fig5-day7.jpeg', 'CR.1.2.840.113564.1722810170.20200401005822484360.1003000225002.png', 'DX.1.2.840.113564.1722810162.20200325130434611240.1203801020003.png', 'DX.1.2.840.113564.1722810162.20200320150341771440.1203801020003.png', 'DX.1.2.840.113564.1722810162.20200406115235508570.1203801020003.png', 'CR.1.2.840.113564.1722810170.20200320170359875720.1003000225002.png', 'DX.1.2.840.113564.1722810162.20200325180923403640.1203801020003.png', 'DX.1.2.840.113564.1722810162.20200420123349689300.1203801020003.png', '58cb9263f16e94305c730685358e4e_jumbo.jpeg', 'all14238-fig-0002-m-d.jpg']
# VAL SET NORMALS: ['person1112_bacteria_3053.jpeg', 'person963_bacteria_2888.jpeg', 'person1158_virus_1938.jpeg', 'person1045_bacteria_2979.jpeg', 'person974_bacteria_2899.jpeg', 'person1321_bacteria_3359.jpeg', 'person1073_bacteria_3011.jpeg', 'person502_bacteria_2118.jpeg', 'person530_virus_1052.jpeg', 'person1139_bacteria_3082.jpeg']
# VAL SET COVID: ['DX.1.2.840.113564.1722810162.20200331093347514180.1203801020003.png', '85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg', 'ryct.2020200034.fig5-day0.jpeg', 'DX.1.2.840.113564.1722810162.20200322072012224350.1203801020003.png', 'DX.1.2.840.113564.1722810162.20200325133712872360.1203801020003.png', 'DX.1.2.840.113564.1722810162.20200323113158393220.1203801020003.png', 'figure1-5e71be566aa8714a04de3386-98-left.jpeg', 'DX.1.2.840.113564.1722810162.202004171314057425.1203801020003.png', 'DX.1.2.840.113564.1722810162.20200325125743092120.1203801020003.png', 'all14238-fig-0002-m-f.jpg']

# %%
print(f'total training NORMAL images: {len(os.listdir(train_normal_dir))}')
print(f'total training COVID images: {len(os.listdir(train_covid_dir))}')
print(f'total validation NORMAL images: {len(os.listdir(validation_normal_dir))}')
print(f'total validation COVID images: {len(os.listdir(validation_covid_dir))}')
# Out:
# total training NORMAL images: 2988
# total training COVID images: 290
# total validation NORMAL images: 748
# total validation COVID images: 73

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_horse_pix = [os.path.join(train_normal_dir, fname) 
                for fname in train_normal_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_covid_dir, fname) 
                for fname in train_covid_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
print(img.shape)
# Out:
# Traceback (most recent call last):
#
#   File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 16
#     img = mpimg.imread(img_path)
#
#   File /opt/conda/lib/python3.10/site-packages/matplotlib/image.py:1563 in imread
#     with img_open(fname) as image:
#
#   File /opt/conda/lib/python3.10/site-packages/PIL/ImageFile.py:117 in __init__
#     self._open()
#
#   File /opt/conda/lib/python3.10/site-packages/PIL/PngImagePlugin.py:717 in _open
#     raise SyntaxError(msg)
#
#   File <string>
# SyntaxError: not a PNG file

# %%
img.shape
# Out:
# (1969, 2496, 3)

# %%
import os
import random

def find_minimum_files_count(directory):
    # Get the list of files in the directory
    files = os.listdir(directory)
    
    # Return the count of files in the directory
    return len(files)

def equalize_folders(file_root):
    # Get a list of all subdirectories in the given root directory
    subdirectories = [d for d in os.listdir(file_root) if os.path.isdir(os.path.join(file_root, d))]
    
    if not subdirectories:
        print("No subdirectories found.")
        return
    
    # Find the minimum number of files among all subdirectories
    min_files_count = min(find_minimum_files_count(os.path.join(file_root, subdir)) for subdir in subdirectories)
    
    # Equalize the number of files in each subdirectory
    for subdir in subdirectories:
        subdir_path = os.path.join(file_root, subdir)
        files = os.listdir(subdir_path)
        
        while len(files) > min_files_count:
            # Remove random file
            random_file = os.path.join(subdir_path, random.choice(files))
            os.remove(random_file)
            files.remove(os.path.basename(random_file))
            print(f"Deleted: {random_file}")

# Example usage:
# root_directory = 'path/to/root'
# equalize_folders(root_directory)

# %%
for sub in ['train', 'val']:
    sub_folder = f'/kaggle/working/{sub}'
    equalize_folders(sub_folder)
# Out:
# Deleted: /kaggle/working/train/NOFINDING/IM-0497-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000419_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0478-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0915-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0236-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0863-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0486-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0372-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000265_001.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0705-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1037-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0122-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0229-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0725-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0488-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000335_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1118-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000453_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0571-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0214-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000483_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0825-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0509-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1281-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1094-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0007-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0087-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0513-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1300-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0841-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0176-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1326-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000098_000.png
# Deleted: /kaggle/working/train/NOFINDING/00000394_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0029-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0333-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0412-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1294-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0567-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1189-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1223-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0093-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0162-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0191-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1350-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0867-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0511-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0395-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1266-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0837-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0578-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0528-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0306-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0265-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0424-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0684-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0564-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1234-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000380_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1152-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0437-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1311-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0588-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0565-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1157-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0980-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0473-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1033-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0563-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0392-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0525-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0394-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0668-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0501-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000162_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0629-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1335-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0510-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0086-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0451-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0222-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0131-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0227-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1062-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0533-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0545-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1440-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0521-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000006_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1231-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0481-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0562-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0446-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0437-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1113-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0005-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1008-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1197-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0224-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0210-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0945-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0399-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000293_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0501-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0499-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0772-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0497-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0620-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0926-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1194-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0286-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1006-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1242-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1103-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000434_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0552-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0549-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0906-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0127-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0364-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0140-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0354-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1116-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1128-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0187-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0853-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0502-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0059-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1126-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0512-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000191_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0931-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0572-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0445-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0401-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0545-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0128-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0327-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0502-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1162-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1102-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0335-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1038-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0464-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0956-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0962-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0854-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0441-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0011-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0508-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000146_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0933-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0257-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0951-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1196-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1317-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000477_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1280-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0599-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0425-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0811-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0419-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0249-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000516_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0309-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0552-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1285-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1292-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000192_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0408-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0531-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0011-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0821-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0453-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0587-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1302-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0757-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0650-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0459-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0559-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0485-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000140_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1438-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0519-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0693-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0355-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000526_001.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0542-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1064-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0448-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0347-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0312-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0582-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0441-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0280-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1365-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1046-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000496_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0803-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1174-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0243-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0384-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1128-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0983-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000396_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0504-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0325-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0934-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1098-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0324-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0655-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0379-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1041-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1187-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0189-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0796-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0838-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1144-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1055-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0440-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0154-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1004-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1321-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0894-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0511-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0511-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1153-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1022-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0575-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0381-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0727-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0475-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0341-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000007_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0429-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0421-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0860-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0699-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1156-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1272-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0642-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0495-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0686-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0226-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0317-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1356-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0537-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0537-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1128-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000082_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0862-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000309_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0780-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1073-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000094_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1105-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1088-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0548-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1332-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0292-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0135-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1058-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000300_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1258-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000085_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1276-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1294-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0315-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0517-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0348-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0539-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0515-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0487-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1327-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0221-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0560-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000518_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0529-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0690-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000349_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1111-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1202-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0555-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0241-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0291-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0775-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0877-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0967-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000195_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1406-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0544-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0575-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1142-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0425-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000170_000.png
# Deleted: /kaggle/working/train/NOFINDING/00000283_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1396-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1279-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1222-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0946-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0496-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0447-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0998-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0540-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0109-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0413-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0909-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0435-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1116-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0277-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0318-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0702-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0936-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0771-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0404-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0987-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1315-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1177-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0358-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0506-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0423-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0253-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1346-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0818-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0546-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0479-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0255-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0781-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0815-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0555-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000375_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1306-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1136-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1154-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0574-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0235-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0995-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1320-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000328_000.png
# Deleted: /kaggle/working/train/NOFINDING/00000433_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1188-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0089-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0160-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0887-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0741-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0405-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1171-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1155-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000505_001.png
# Deleted: /kaggle/working/train/NOFINDING/00000137_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0746-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1323-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1048-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1282-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0439-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0870-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000504_000.png
# Deleted: /kaggle/working/train/NOFINDING/00000259_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0199-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0643-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0882-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0579-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0497-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0035-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000356_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0110-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0320-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1100-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0583-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0505-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0806-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0272-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0824-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0573-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0451-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0432-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1086-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0453-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0019-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0489-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1145-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0203-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000126_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1376-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0013-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0848-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0442-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0387-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000209_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0598-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0587-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0300-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1240-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0698-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0965-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0553-0001-0003.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0659-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0678-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0152-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0454-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1203-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0653-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0765-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000141_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0303-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000263_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0472-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0477-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0941-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000226_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0692-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0262-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0539-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0486-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1168-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0828-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0041-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1130-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1176-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1277-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000299_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0995-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000438_000.png
# Deleted: /kaggle/working/train/NOFINDING/00000452_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0515-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0636-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0141-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1258-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0458-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0551-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0433-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1005-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0377-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1090-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1167-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000046_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0576-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0491-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1152-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0885-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0978-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0413-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000357_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0478-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0969-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0847-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0555-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0671-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0995-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0512-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0599-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0511-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0473-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0337-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0248-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0588-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0594-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0430-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0554-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000472_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0520-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0536-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0919-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0912-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000437_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1349-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1296-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000425_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1102-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0463-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0649-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1027-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0491-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0999-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000395_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0028-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0577-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1330-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000365_000.png
# Deleted: /kaggle/working/train/NOFINDING/00000018_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1044-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0525-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0279-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0808-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1120-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0111-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1134-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0553-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1151-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1347-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0494-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000356_001.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0535-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000229_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0622-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1341-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0545-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0295-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0400-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0858-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1319-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1170-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000068_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0744-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000474_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1236-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000462_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0616-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0531-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0651-0004.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0429-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0439-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0490-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0809-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0528-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000526_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0922-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0910-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1020-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000320_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0270-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000266_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0525-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1258-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0549-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0435-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0435-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0375-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000279_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0164-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0274-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0723-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0465-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0816-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0856-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000265_003.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0220-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1243-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0564-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1018-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0930-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0871-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0293-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000265_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0812-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0075-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000470_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0652-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0774-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1117-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1256-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0651-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0551-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0988-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0363-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0460-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0351-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1181-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1185-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0414-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1328-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0266-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0661-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0419-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1345-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000507_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0476-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0467-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000110_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0736-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0918-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1178-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0601-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0689-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0006-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000122_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0367-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0530-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0895-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1205-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0297-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0410-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0383-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0332-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0467-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0370-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0217-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0313-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1278-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1116-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0083-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1277-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000152_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0415-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0526-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000014_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0472-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1423-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0687-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0541-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1294-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0143-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0329-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0468-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1295-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0553-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1050-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0050-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0206-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1025-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0081-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0531-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0834-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0570-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0219-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0526-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000198_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0586-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0603-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1173-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0680-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0663-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0855-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000479_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0452-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0499-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0401-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0584-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0881-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1351-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0899-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0647-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1127-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0177-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000222_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0579-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000319_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1149-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000454_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0391-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0523-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1430-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1267-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000260_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0975-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0657-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1190-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0147-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0617-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1344-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1135-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0039-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0907-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1067-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0205-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0345-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0923-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1160-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1019-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0666-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0195-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0460-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0261-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0516-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0971-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0022-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1109-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0406-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0583-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0349-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0499-0001-0002.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0311-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1147-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000161_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0994-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0543-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1039-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0533-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1220-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0695-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0427-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0932-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1427-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0450-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0696-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000106_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0234-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0851-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1345-0001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0156-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0949-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1001-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000265_002.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0428-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000048_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1052-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000354_000.png
# Deleted: /kaggle/working/train/NOFINDING/00000276_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0009-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0069-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0496-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0547-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0503-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1371-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1132-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1304-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0304-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0634-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0609-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0790-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0283-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0798-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0563-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0831-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0073-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1237-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1286-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1227-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0820-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0017-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000519_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0532-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000445_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0003-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0974-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000217_000.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0942-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000225_001.png
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1184-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1014-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0323-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0880-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0463-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1291-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0518-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0301-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0917-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0993-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0276-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0416-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0362-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0621-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0524-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0033-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1228-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/00000095_000.png
# Deleted: /kaggle/working/train/NOFINDING/IM-0030-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0568-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0673-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0102-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0505-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-0523-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0067-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/IM-0519-0001.jpeg
# Deleted: /kaggle/working/train/NOFINDING/NORMAL2-IM-1277-0001-0001.jpeg
# ...
# Deleted: /kaggle/working/val/THORAXDISEASE/person515_bacteria_2185.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1261_bacteria_3219.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person997_bacteria_2926.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person650_bacteria_2542.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person43_bacteria_213.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person540_bacteria_2271.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1209_bacteria_3161.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person91_bacteria_448.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1051_virus_1750.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1458_virus_2502.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person588_bacteria_2422.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person585_bacteria_2414.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person159_bacteria_746.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1019_virus_1708.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person406_bacteria_1818.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person265_bacteria_1235.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person357_bacteria_1639.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person381_bacteria_1731.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1389_bacteria_3531.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person339_bacteria_1572.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person608_bacteria_2471.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1082_bacteria_3022.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person510_bacteria_2148.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person465_bacteria_1976.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1159_virus_1946.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1127_virus_1854.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person375_bacteria_1713.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person565_virus_1105.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person260_bacteria_1222.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1073_bacteria_3011.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person133_bacteria_633.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1483_virus_2574.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person434_bacteria_1877.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person132_bacteria_632.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person19_bacteria_59.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person56_bacteria_268.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person486_bacteria_2052.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person315_bacteria_1466.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person281_bacteria_1330.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1482_bacteria_3874.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person360_bacteria_1647.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person515_virus_1032.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1103_virus_1825.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1082_virus_1794.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person24_bacteria_109.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person515_bacteria_2189.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person989_virus_1667.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person101_bacteria_483.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person832_bacteria_2743.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person779_bacteria_2683.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person348_virus_719.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1272_bacteria_3232.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person995_bacteria_2923.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person461_virus_950.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person567_virus_1107.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person277_bacteria_1301.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person88_virus_163.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person263_bacteria_1227.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1312_bacteria_3318.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person396_virus_789.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1179_bacteria_3127.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person11_virus_38.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person20_bacteria_69.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person104_bacteria_491.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person607_bacteria_2470.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1343_bacteria_3419.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person64_bacteria_310.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person692_bacteria_2589.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person661_virus_1245.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person389_bacteria_1778.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person499_bacteria_2103.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1378_bacteria_3513.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1023_virus_1714.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person48_bacteria_232.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person399_bacteria_1804.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person776_virus_1405.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person300_bacteria_1422.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person888_bacteria_2812.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person58_bacteria_277.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person20_bacteria_64.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person292_virus_600.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1321_virus_2279.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person436_virus_886.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person669_bacteria_2561.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person830_bacteria_2741.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person491_bacteria_2080.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1356_virus_2337.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1476_bacteria_3842.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person487_bacteria_2055.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1169_virus_1968.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person21_bacteria_73.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person299_virus_620.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person23_bacteria_99.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1045_bacteria_2979.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person134_bacteria_644.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person579_bacteria_2381.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1446_bacteria_3739.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person145_virus_294.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1261_virus_2148.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person82_bacteria_403.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person370_bacteria_1688.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person357_virus_735.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person724_bacteria_2626.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person963_bacteria_2888.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person571_virus_1114.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person49_virus_101.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person23_bacteria_86.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1411_virus_2415.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person124_virus_246.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person135_virus_271.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1274_virus_2193.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person980_virus_1655.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person884_virus_1534.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person51_bacteria_239.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person127_bacteria_604.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person159_bacteria_747.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person906_virus_1562.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person71_bacteria_347.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1329_bacteria_3377.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person27_bacteria_135.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person43_virus_92.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1494_virus_2601.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person896_virus_1548.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person922_bacteria_2847.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person86_bacteria_428.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person727_bacteria_2629.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1163_virus_1951.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1302_bacteria_3266.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person109_virus_203.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1052_virus_1751.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1266_bacteria_3225.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person325_virus_661.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person832_virus_1468.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person537_bacteria_2264.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1350_virus_2329.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person53_bacteria_254.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1219_virus_2067.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person27_bacteria_138.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person721_virus_1340.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person101_bacteria_484.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person296_virus_613.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1180_virus_2011.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person834_bacteria_2748.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1063_virus_1765.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person579_bacteria_2384.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person308_bacteria_1443.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person25_bacteria_119.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person957_bacteria_2882.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person120_bacteria_570.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person278_virus_574.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person51_bacteria_240.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person371_bacteria_1695.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person487_virus_991.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1055_bacteria_2989.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person749_bacteria_2652.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person38_virus_84.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1481_bacteria_3865.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person124_virus_237.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person413_bacteria_1828.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person383_bacteria_1747.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person477_bacteria_2029.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person154_bacteria_728.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person811_bacteria_2721.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person298_bacteria_1411.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1312_virus_2261.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1175_virus_1981.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1492_virus_2599.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person128_bacteria_607.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person336_bacteria_1548.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person66_bacteria_325.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person266_virus_549.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person41_bacteria_209.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person583_bacteria_2408.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person138_virus_282.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person707_bacteria_2606.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person275_virus_565.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person458_bacteria_1954.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1039_bacteria_2973.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person762_virus_1390.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person264_bacteria_1233.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person368_bacteria_1668.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person458_virus_945.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person19_virus_50.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person320_virus_647.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person23_bacteria_103.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person333_bacteria_1539.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person659_virus_1243.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1255_virus_2132.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1162_bacteria_3107.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1294_bacteria_3257.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1449_bacteria_3743.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person162_virus_322.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person340_virus_698.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1112_virus_1837.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person36_bacteria_185.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1317_virus_2273.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1067_bacteria_3001.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person290_bacteria_1372.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person512_bacteria_2154.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person264_virus_547.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1493_bacteria_3899.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person577_bacteria_2378.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1243_bacteria_3199.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1439_bacteria_3722.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person979_virus_1654.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person124_virus_233.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1295_virus_2223.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person970_virus_1644.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person62_bacteria_299.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1220_virus_2068.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person55_bacteria_265.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person501_bacteria_2116.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person958_virus_1630.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1453_bacteria_3772.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person441_bacteria_1911.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person675_bacteria_2569.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person596_bacteria_2449.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person55_bacteria_266.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person600_bacteria_2456.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1259_bacteria_3217.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person1037_bacteria_2971.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person379_bacteria_1721.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person348_virus_717.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person491_bacteria_2071.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person466_virus_960.jpeg
# Deleted: /kaggle/working/val/THORAXDISEASE/person175_bacteria_834.jpeg

# %%
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import os

# Load the first example of a happy face
sample_image  = load_img('/kaggle/working/train/COVID-19/ryct.2020200034.fig5-day7.jpeg')

# Convert the image into its numpy array representation
sample_array = img_to_array(sample_image)

print(f"Each image has shape: {sample_array.shape}")

print(f"The maximum pixel value used is: {np.max(sample_array)}")
# Out:
# Each image has shape: (1263, 1184, 3)
# The maximum pixel value used is: 236.0

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') is not None and logs.get('accuracy') > 0.9:
            print("\nReached 90% accuracy so cancelling training!")
            self.model.stop_training = True

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


def image_generator(folder):
    train_datagen = ImageDataGenerator(rescale=1./255)

    # Specify the method to load images from a directory and pass in the appropriate arguments:
    # - directory: should be a relative path to the directory containing the data
    # - targe_size: set this equal to the resolution of each image (excluding the color dimension)
    # - batch_size: number of images the generator yields when asked for a next batch. Set this to 10.
    # - class_mode: How the labels are represented. Should be one of "binary", "categorical" or "sparse".
    #               Pick the one that better suits here given that the labels are going to be 1D binary labels.
    train_generator = train_datagen.flow_from_directory(directory=folder,
                                                        target_size=(256, 256),
                                                        batch_size=10,
                                                        class_mode='categorical')

    return train_generator

# %%
# Save generator in a variable
gen = image_generator('/kaggle/working/train')
val_gen = image_generator('/kaggle/working/val')
# Out:
# Found 870 images belonging to 3 classes.
# Found 219 images belonging to 3 classes.

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('horses') and 1 for the other ('humans')
    tf.keras.layers.Dense(3, activation='sigmoid')
])

# %%
from tensorflow.keras import optimizers, losses, layers

# Instantiate the callback
callbacks = myCallback()

# Define the model
model = tf.keras.models.Sequential([
    # Convolutional Layer 1
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)),
    layers.MaxPooling2D(2, 2),
    # Convolutional Layer 2
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(2, 2),
    # Convolutional Layer 3
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D(2, 2),
    # Flatten the output for the fully connected layers
    layers.Flatten(),
    # Fully Connected Layer 1
    layers.Dense(128, activation='relu'),
    # Output Layer
    layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Adam(lr=0.001),
              metrics=['accuracy'])


# Train the model
history = model.fit(
    gen,
#     steps_per_epoch=15,
    epochs=15,
    verbose=1,
    validation_data = val_gen,
    callbacks = [callbacks])
# Out:
# Epoch 1/15
# 87/87 [==============================] - 36s 350ms/step - loss: 1.0671 - accuracy: 0.6839 - val_loss: 0.3676 - val_accuracy: 0.8767
# Epoch 2/15
# 87/87 [==============================] - 30s 347ms/step - loss: 0.3417 - accuracy: 0.8862 - val_loss: 0.4165 - val_accuracy: 0.8265
# Epoch 3/15
# 87/87 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9230
# Reached 90% accuracy so cancelling training!
# 87/87 [==============================] - 30s 341ms/step - loss: 0.2064 - accuracy: 0.9230 - val_loss: 0.2878 - val_accuracy: 0.9087

# %%
class_names = gen.class_indices
class_names
# Out:
# {'COVID-19': 0, 'NOFINDING': 1, 'THORAXDISEASE': 2}

# %%
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array

path = '/kaggle/working/val/NOFINDING/00000386_000.png'
img = load_img(path, target_size=(256, 256))
x = img_to_array(img)
x /= 255
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
predictions = model.predict(images, batch_size=10)

# Get the predicted class index
predicted_class_index = np.argmax(predictions)

# Get the predicted class label from the 'gen' variable
predicted_class = list(class_names.keys())[list(class_names.values()).index(predicted_class_index)]

# Print the prediction
print("Predicted class:", predicted_class)
# print("Class probabilities:", predictions)

plt.imshow(img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 293ms/step
# Predicted class: NOFINDING
